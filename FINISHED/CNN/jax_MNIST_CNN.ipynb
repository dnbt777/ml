# %%
import jax.numpy as jnp
import jax.random as random
import jax
import optax
import torch
import time
from pprint import pprint
import flax

# %%
# load mnist stuff
batch_size = 4

import torchvision
import torchvision.transforms as transforms
# first load the dataset
train_data = torchvision.datasets.MNIST(root = './', train=True, download=True, transform=transforms.ToTensor())
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, shuffle=True, num_workers=2)
test_data = torchvision.datasets.MNIST(root = './', train=False, download=True, transform=transforms.ToTensor())
test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size, shuffle=True, num_workers=2)


# convert to jnp/np
x_train, y_train = zip(*train_data)
x_train, y_train = jnp.array(x_train), jnp.array(y_train)

x_test, y_test = zip(*test_data)
x_test, y_test = jnp.array(x_test), jnp.array(y_test)

# convert ys to one-hot
classes = len(set(y_train.tolist()))
print(classes)
y_train = jax.nn.one_hot(y_train, classes) # from n -> one-hot of n
y_test = jax.nn.one_hot(y_test, classes)
# Out:
# 10

# %% [markdown]
# Custo model after this CNN: CNN but with skip connections as the first few layers
#
# custom training after this: CNN with 3d convolution for minecraft worlds
#   - single minecraft world
#   - put chunks in
#   - classify biome

# %%
# Util functions
def init_cnn_params(key, input_shape, output_shape):
  keys = random.split(key, 20)
  cnn_params = {}

  # shape: (1, 28, 28) => conv1 => (3, 28-(4-1), 28-(4-1))
  conv1 = {
    #out_channels, in_channels, kernel_row, kernel_col
    # 4x4 kernel. 1 input (mnist), 3 outputs
    "conv1" : jax.nn.initializers.glorot_uniform()(keys[0], (3, 1, 4, 4))
  }
  current_shape = (3, 28-(4-1), 28-(4-1))

  conv2 = {
    "conv2" : jax.nn.initializers.glorot_uniform()(keys[2], (3, 3, 4, 4))
  }
  current_shape = (3, 25, 25) # this conv will have a skip connection and mode will be 'same'

  # shape: (3, 25, 25) => maxpool 2x2 => (3, 25 - (2-1), 25-(2-1))
  current_shape = (3, 24, 24)

  # shape: (3, 24, 24) => conv1 => (7, 24-(10-1), 24-(10-1))
  conv3 = {
    #out_channels, in_channels, kernel_row, kernel_col
    # 4x4 kernel. 1 input (mnist), 3 outputs
    "conv3" : jax.nn.initializers.glorot_uniform()(keys[3], (7, 3, 10, 10))
  }
  current_shape = (7, 15, 15)

  conv4 = {
    "conv4" : jax.nn.initializers.glorot_uniform()(keys[4], (7, 7, 10, 10))
  }
  current_shape = (7, 15, 15) # this conv will have a skip connection and mode will be 'same'
  
  # shape: (7, 15, 15) => ravel => (7 * 15 * 15,)
  current_shape = (7 * 15 * 15,)
  fc1 = {
    # since its xW for batching, W shape=(input, output)
    "fc1" : {
      "w" : random.normal(keys[1], shape=(current_shape[0], 128)) * jnp.sqrt(2 / current_shape[0]),
      'b' : jnp.zeros(shape=128)
      }
  }

  # shape: (7 * 15 * 15,) => fc1 => (128,)
  current_shape = (128,)
  fc2 = {
    "fc2" : {
      "w" : random.normal(keys[5], shape=(current_shape[0], output_shape[0])) * jnp.sqrt(2 / current_shape[0]),
      'b' : jnp.zeros(shape=output_shape)
      }
  }

  cnn_params.update(conv1)
  cnn_params.update(conv2)
  cnn_params.update(conv3)
  cnn_params.update(conv4)
  cnn_params.update(fc1)
  cnn_params.update(fc2)

  return cnn_params



def maxpool(layer, maxpool_shape):
  # just use upper left pixel of kernel as the output for now
  out = jnp.zeros(shape=(layer.shape[0] - maxpool_shape[0] + 1, len(layer[0]) - maxpool_shape[1] + 1))
  for row in range(len(layer) - maxpool_shape[0]):
    for col in range(len(layer[0]) - maxpool_shape[1]):
      max_val = -10000
      for krow in range(maxpool_shape[0]):
        for kcol in range(maxpool_shape[1]):
          max_val = max(max_val, layer[row + krow][col + kcol])
      out = out.at[row, col].set(max_val)
  return out

def maxpool_layers(input_layers, maxpool_shape):
  output_layers = []
  for layer in input_layers:
    output_layers.append(maxpool(layer, maxpool_shape))
  return jnp.array(output_layers)

def crossentropyloss(logits, y):
  yhat = jax.nn.log_softmax(logits)
  return jnp.sum(-yhat * y)

# %%
# training functions

# output logits if classes. convert to yhat in other functions.
def get_loss(cnn_params, x, y):
  logits = cnn_forward(cnn_params, x)
  loss = crossentropyloss(logits, y)
  return loss

# yes i know its inefficient idc
def get_accuracy(cnn_params, xs, ys):
  correct = 0
  for idx in range(len(xs)):
    logits = cnn_forward(cnn_params, xs[idx])
    yhat, y = jnp.argmax(logits), jnp.argmax(ys[idx])
    if yhat == y:
      correct += 1
  return correct / len(xs)


@jax.jit
def cnn_forward(cnn_params, x):
  # do conv, then relu, then maxpool, then fc.
  x = jnp.array([
    jax.scipy.signal.convolve(x, kernel, mode="valid")[0]
    for kernel in cnn_params["conv1"]
  ])
  x = jax.nn.relu(x)
  print(x.shape)

  # residual/skip connnection. mode=same to output the same shape.
  x_residual = jnp.array([
    jax.scipy.signal.convolve(x, kernel, mode='same')[0]
    for kernel in cnn_params["conv2"]
  ])
  x_residual = jax.nn.relu(x_residual)
  x = x + x_residual
  x = jax.nn.relu(x)
  print(x.shape)

  # maxpool 2x2
  x = jnp.array([
    # why do i have to reshape it?
    # channel[:, :, None]  (25, 25) => (25, 25, 1)
    flax.linen.max_pool(channel[:, :, None], window_shape=(2, 2))
    for channel in x
  ])
  x = jnp.squeeze(x, axis=-1) # (24, 24, 1) => (24, 24)
  print(x.shape)

  x = jnp.array([
    jax.scipy.signal.convolve(x, kernel, mode="valid")[0]
    for kernel in cnn_params["conv3"]
  ])
  x = jax.nn.relu(x)
  print(x.shape)

  x_residual = jnp.array([
    jax.scipy.signal.convolve(x, kernel, mode='same')[0]
    for kernel in cnn_params["conv4"]
  ])
  x_residual = jax.nn.relu(x_residual)
  x = x + x_residual
  x = jax.nn.relu(x)
  print(x.shape)


  x = jnp.ravel(x) # all channels to 1 layer
  print(x.shape)
  x = x @ cnn_params["fc1"]["w"] + cnn_params["fc1"]["b"]
  x = jax.nn.relu(x)

  x = x @ cnn_params["fc2"]["w"] + cnn_params["fc2"]["b"]

  return x

# %%
# do training

key = random.PRNGKey(29383)
keys = random.split(key, 100)

input_shape = (1, 28, 28)
output_shape = (10,)
cnn_params = init_cnn_params(keys[0], input_shape, output_shape)

learning_rate = 0.001
optimizer = optax.adam(learning_rate)
opt_state = optimizer.init(cnn_params)

@jax.jit
def train_step(cnn_params, x, y, opt_state):
  loss, grads = jax.value_and_grad(get_loss)(cnn_params, x, y)
  updates, updated_opt_state = optimizer.update(grads, opt_state)
  updated_cnn_params = optax.apply_updates(cnn_params, updates)
  return updated_cnn_params, updated_opt_state, loss

x = x_train[0]
y = y_train[0]
import time
start = time.time()

steps = 400000
print_every = 100
train_indices = random.permutation(keys[2], len(x_train))
test_indices = random.permutation(keys[3], len(x_test))
moving_avg = []
for step in range(steps):
  idx = train_indices[step % len(x_train)]
  cnn_params, opt_state, loss = train_step(cnn_params, x_train[idx], y_train[idx], opt_state)
  test_idx = test_indices[step % len(x_test)]
  val_loss = get_loss(cnn_params, x_test[test_idx], y_test[test_idx])
  moving_avg.append([loss, val_loss])
  if step % print_every == 0:
    loss, val_loss = jnp.mean(jnp.array(moving_avg), axis=0)
    accuracy = get_accuracy(cnn_params, x_test[:print_every], y_test[:print_every])
    print(f"step {step}, loss = {loss:0.4f}, val_loss = {val_loss:0.4f}, val_accuracy={accuracy:0.5f}")
    moving_avg = []
print("total: ", time.time() - start)
# Out:
# step 0, loss = 1.8796, val_loss = 2.5550, val_accuracy=0.08000
# step 100, loss = 2.1550, val_loss = 2.0442, val_accuracy=0.39000
# step 200, loss = 1.3083, val_loss = 1.3555, val_accuracy=0.44000
# step 300, loss = 0.6268, val_loss = 1.0453, val_accuracy=0.78000
# step 400, loss = 0.9674, val_loss = 0.8587, val_accuracy=0.85000
# step 500, loss = 0.8854, val_loss = 0.7839, val_accuracy=0.90000
# step 600, loss = 0.7537, val_loss = 0.4948, val_accuracy=0.86000
# step 700, loss = 0.5497, val_loss = 0.6564, val_accuracy=0.89000
# step 800, loss = 0.3841, val_loss = 0.4677, val_accuracy=0.89000
# step 900, loss = 0.5004, val_loss = 0.7872, val_accuracy=0.78000
# step 1000, loss = 0.5024, val_loss = 0.3308, val_accuracy=0.95000
# step 1100, loss = 0.5568, val_loss = 0.4890, val_accuracy=0.88000
# step 1200, loss = 0.4629, val_loss = 0.2669, val_accuracy=0.94000
# step 1300, loss = 0.2745, val_loss = 0.1886, val_accuracy=0.95000
# step 1400, loss = 0.3162, val_loss = 0.3098, val_accuracy=0.79000
# step 1500, loss = 0.5261, val_loss = 0.3616, val_accuracy=0.87000
# step 1600, loss = 0.3067, val_loss = 0.3573, val_accuracy=0.93000
# step 1700, loss = 0.1632, val_loss = 0.3604, val_accuracy=0.92000
# step 1800, loss = 0.2646, val_loss = 0.2258, val_accuracy=0.89000
# step 1900, loss = 0.2789, val_loss = 0.5471, val_accuracy=0.92000
# step 2000, loss = 0.2243, val_loss = 0.4003, val_accuracy=0.92000
# step 2100, loss = 0.2084, val_loss = 0.4243, val_accuracy=0.90000
# step 2200, loss = 0.4711, val_loss = 0.2037, val_accuracy=0.91000
# step 2300, loss = 0.2868, val_loss = 0.2418, val_accuracy=0.93000
# step 2400, loss = 0.2327, val_loss = 0.2337, val_accuracy=0.93000
# step 2500, loss = 0.2309, val_loss = 0.1727, val_accuracy=0.91000
# step 2600, loss = 0.3791, val_loss = 0.4099, val_accuracy=0.92000
# step 2700, loss = 0.3739, val_loss = 0.2397, val_accuracy=0.91000
# step 2800, loss = 0.2538, val_loss = 0.4250, val_accuracy=0.92000
# step 2900, loss = 0.1099, val_loss = 0.1893, val_accuracy=0.93000
# step 3000, loss = 0.2051, val_loss = 0.2234, val_accuracy=0.90000
# step 3100, loss = 0.4807, val_loss = 0.3022, val_accuracy=0.93000
# step 3200, loss = 0.2746, val_loss = 0.2419, val_accuracy=0.94000
# step 3300, loss = 0.2688, val_loss = 0.1483, val_accuracy=0.93000
# step 3400, loss = 0.2226, val_loss = 0.0820, val_accuracy=0.94000
# step 3500, loss = 0.3734, val_loss = 0.1836, val_accuracy=0.92000
# step 3600, loss = 0.3672, val_loss = 0.0844, val_accuracy=0.93000
# step 3700, loss = 0.1197, val_loss = 0.2521, val_accuracy=0.93000
# step 3800, loss = 0.0725, val_loss = 0.2493, val_accuracy=0.93000
# step 3900, loss = 0.2770, val_loss = 0.1759, val_accuracy=0.93000
# step 4000, loss = 0.2676, val_loss = 0.1698, val_accuracy=0.95000
# step 4100, loss = 0.1580, val_loss = 0.1366, val_accuracy=0.91000
# step 4200, loss = 0.1477, val_loss = 0.1081, val_accuracy=0.96000
# step 4300, loss = 0.1127, val_loss = 0.1549, val_accuracy=0.97000
# step 4400, loss = 0.2389, val_loss = 0.2097, val_accuracy=0.91000
# step 4500, loss = 0.2172, val_loss = 0.1954, val_accuracy=0.92000
# step 4600, loss = 0.3488, val_loss = 0.5340, val_accuracy=0.89000
# step 4700, loss = 0.2771, val_loss = 0.1340, val_accuracy=0.96000
# step 4800, loss = 0.1762, val_loss = 0.2276, val_accuracy=0.96000
# step 4900, loss = 0.1645, val_loss = 0.2662, val_accuracy=0.96000
# step 5000, loss = 0.1628, val_loss = 0.3438, val_accuracy=0.96000
# step 5100, loss = 0.2260, val_loss = 0.2185, val_accuracy=0.96000
# step 5200, loss = 0.3163, val_loss = 0.2481, val_accuracy=0.95000
# step 5300, loss = 0.1000, val_loss = 0.0699, val_accuracy=0.95000
# step 5400, loss = 0.3417, val_loss = 0.1510, val_accuracy=0.96000
# step 5500, loss = 0.1654, val_loss = 0.2381, val_accuracy=0.96000
# step 5600, loss = 0.1025, val_loss = 0.1233, val_accuracy=0.96000
# step 5700, loss = 0.2288, val_loss = 0.2544, val_accuracy=0.95000
# step 5800, loss = 0.1502, val_loss = 0.1549, val_accuracy=0.95000
# step 5900, loss = 0.2497, val_loss = 0.2009, val_accuracy=0.93000
# step 6000, loss = 0.2315, val_loss = 0.1711, val_accuracy=0.93000
# step 6100, loss = 0.1279, val_loss = 0.3835, val_accuracy=0.93000
# step 6200, loss = 0.1290, val_loss = 0.1676, val_accuracy=0.87000
# step 6300, loss = 0.3080, val_loss = 0.1422, val_accuracy=0.97000
# step 6400, loss = 0.1644, val_loss = 0.3096, val_accuracy=0.92000
# step 6500, loss = 0.2351, val_loss = 0.1474, val_accuracy=0.97000
# step 6600, loss = 0.4441, val_loss = 0.0910, val_accuracy=0.92000
# step 6700, loss = 0.1734, val_loss = 0.1744, val_accuracy=0.96000
# step 6800, loss = 0.3182, val_loss = 0.2541, val_accuracy=0.93000
# step 6900, loss = 0.1966, val_loss = 0.1475, val_accuracy=0.94000
# step 7000, loss = 0.1645, val_loss = 0.0237, val_accuracy=0.93000
# step 7100, loss = 0.0792, val_loss = 0.1723, val_accuracy=0.96000
# step 7200, loss = 0.1825, val_loss = 0.1660, val_accuracy=0.95000
# step 7300, loss = 0.2020, val_loss = 0.1557, val_accuracy=0.94000
# step 7400, loss = 0.1351, val_loss = 0.2134, val_accuracy=0.97000
# step 7500, loss = 0.1083, val_loss = 0.2751, val_accuracy=0.94000
# step 7600, loss = 0.1435, val_loss = 0.1796, val_accuracy=0.96000
# step 7700, loss = 0.2465, val_loss = 0.4484, val_accuracy=0.94000
# step 7800, loss = 0.2774, val_loss = 0.0786, val_accuracy=0.96000
# step 7900, loss = 0.0788, val_loss = 0.2359, val_accuracy=0.98000
# step 8000, loss = 0.3502, val_loss = 0.1786, val_accuracy=0.96000
# step 8100, loss = 0.1489, val_loss = 0.1539, val_accuracy=0.96000
# step 8200, loss = 0.3098, val_loss = 0.2756, val_accuracy=0.95000
# step 8300, loss = 0.0689, val_loss = 0.0772, val_accuracy=0.96000
# step 8400, loss = 0.3322, val_loss = 0.2186, val_accuracy=0.97000
# step 8500, loss = 0.2169, val_loss = 0.1481, val_accuracy=0.96000
# step 8600, loss = 0.3233, val_loss = 0.1099, val_accuracy=0.97000
# step 8700, loss = 0.1205, val_loss = 0.1252, val_accuracy=0.98000
# step 8800, loss = 0.2761, val_loss = 0.1050, val_accuracy=0.99000
# step 8900, loss = 0.0810, val_loss = 0.0910, val_accuracy=0.98000
# step 9000, loss = 0.1044, val_loss = 0.1199, val_accuracy=0.98000
# step 9100, loss = 0.0593, val_loss = 0.1292, val_accuracy=0.96000
# step 9200, loss = 0.3223, val_loss = 0.2223, val_accuracy=0.91000
# step 9300, loss = 0.2033, val_loss = 0.1792, val_accuracy=0.96000
# step 9400, loss = 0.1326, val_loss = 0.1592, val_accuracy=0.97000
# step 9500, loss = 0.1554, val_loss = 0.0831, val_accuracy=0.96000
# step 9600, loss = 0.0846, val_loss = 0.2049, val_accuracy=0.93000
# step 9700, loss = 0.0622, val_loss = 0.2134, val_accuracy=0.96000
# step 9800, loss = 0.2210, val_loss = 0.1573, val_accuracy=0.92000
# step 9900, loss = 0.1890, val_loss = 0.1443, val_accuracy=0.95000
# step 10000, loss = 0.1497, val_loss = 0.1830, val_accuracy=0.95000
# step 10100, loss = 0.2249, val_loss = 0.0741, val_accuracy=0.94000
# step 10200, loss = 0.2745, val_loss = 0.1996, val_accuracy=0.94000
# step 10300, loss = 0.1274, val_loss = 0.1627, val_accuracy=0.92000
# step 10400, loss = 0.0657, val_loss = 0.0649, val_accuracy=0.97000
# step 10500, loss = 0.2231, val_loss = 0.1911, val_accuracy=0.97000
# step 10600, loss = 0.2592, val_loss = 0.1442, val_accuracy=0.97000
# step 10700, loss = 0.1661, val_loss = 0.1373, val_accuracy=0.98000
# step 10800, loss = 0.0716, val_loss = 0.1093, val_accuracy=0.97000
# step 10900, loss = 0.0718, val_loss = 0.2244, val_accuracy=0.96000
# step 11000, loss = 0.2276, val_loss = 0.1296, val_accuracy=0.99000
# step 11100, loss = 0.1580, val_loss = 0.2418, val_accuracy=0.96000
# step 11200, loss = 0.1294, val_loss = 0.1720, val_accuracy=0.95000
# step 11300, loss = 0.1707, val_loss = 0.1964, val_accuracy=0.97000
# step 11400, loss = 0.5005, val_loss = 0.2207, val_accuracy=0.95000
# step 11500, loss = 0.1147, val_loss = 0.0790, val_accuracy=0.95000
# step 11600, loss = 0.1258, val_loss = 0.2347, val_accuracy=0.96000
# step 11700, loss = 0.1255, val_loss = 0.1097, val_accuracy=0.97000
# step 11800, loss = 0.1606, val_loss = 0.0726, val_accuracy=0.98000
# step 11900, loss = 0.2310, val_loss = 0.1704, val_accuracy=0.94000
# step 12000, loss = 0.1955, val_loss = 0.2199, val_accuracy=0.94000
# step 12100, loss = 0.3501, val_loss = 0.0969, val_accuracy=0.98000
# step 12200, loss = 0.1917, val_loss = 0.0895, val_accuracy=0.97000
# step 12300, loss = 0.1241, val_loss = 0.1063, val_accuracy=0.98000
# step 12400, loss = 0.2026, val_loss = 0.1233, val_accuracy=0.97000
# step 12500, loss = 0.0651, val_loss = 0.0657, val_accuracy=0.97000
# step 12600, loss = 0.2313, val_loss = 0.0563, val_accuracy=0.97000
# step 12700, loss = 0.1053, val_loss = 0.0346, val_accuracy=0.98000
# step 12800, loss = 0.0869, val_loss = 0.2700, val_accuracy=0.97000
# step 12900, loss = 0.2060, val_loss = 0.1290, val_accuracy=0.96000
# step 13000, loss = 0.2011, val_loss = 0.2276, val_accuracy=0.92000
# step 13100, loss = 0.1241, val_loss = 0.1987, val_accuracy=0.95000
# step 13200, loss = 0.0910, val_loss = 0.1029, val_accuracy=0.95000
# step 13300, loss = 0.1140, val_loss = 0.1947, val_accuracy=0.96000
# step 13400, loss = 0.2670, val_loss = 0.0794, val_accuracy=0.94000
# step 13500, loss = 0.2177, val_loss = 0.2154, val_accuracy=0.95000
# step 13600, loss = 0.2569, val_loss = 0.0510, val_accuracy=0.94000
# step 13700, loss = 0.1067, val_loss = 0.3131, val_accuracy=0.96000
# step 13800, loss = 0.0592, val_loss = 0.1410, val_accuracy=0.95000
# step 13900, loss = 0.0816, val_loss = 0.1107, val_accuracy=0.93000
# step 14000, loss = 0.1682, val_loss = 0.1609, val_accuracy=0.97000
# step 14100, loss = 0.0659, val_loss = 0.2713, val_accuracy=0.96000
# step 14200, loss = 0.1043, val_loss = 0.1097, val_accuracy=0.97000
# step 14300, loss = 0.3050, val_loss = 0.1071, val_accuracy=0.97000
# step 14400, loss = 0.2021, val_loss = 0.0965, val_accuracy=0.96000
# step 14500, loss = 0.2058, val_loss = 0.1885, val_accuracy=0.95000
# step 14600, loss = 0.1426, val_loss = 0.0859, val_accuracy=0.96000
# step 14700, loss = 0.1767, val_loss = 0.0707, val_accuracy=0.98000
# step 14800, loss = 0.1777, val_loss = 0.1452, val_accuracy=0.98000
# step 14900, loss = 0.1734, val_loss = 0.0731, val_accuracy=0.97000
# step 15000, loss = 0.1787, val_loss = 0.1753, val_accuracy=0.98000
# step 15100, loss = 0.1329, val_loss = 0.1718, val_accuracy=0.98000
# step 15200, loss = 0.2013, val_loss = 0.2308, val_accuracy=0.99000
# step 15300, loss = 0.1428, val_loss = 0.2577, val_accuracy=0.95000
# step 15400, loss = 0.1557, val_loss = 0.1023, val_accuracy=0.97000
# step 15500, loss = 0.1458, val_loss = 0.2518, val_accuracy=0.97000
# step 15600, loss = 0.1167, val_loss = 0.0496, val_accuracy=0.96000
# step 15700, loss = 0.0774, val_loss = 0.0402, val_accuracy=0.95000
# step 15800, loss = 0.0913, val_loss = 0.0699, val_accuracy=0.97000
# step 15900, loss = 0.0971, val_loss = 0.2496, val_accuracy=0.97000
# step 16000, loss = 0.3319, val_loss = 0.3783, val_accuracy=0.95000
# step 16100, loss = 0.0294, val_loss = 0.2879, val_accuracy=0.97000
# step 16200, loss = 0.1055, val_loss = 0.0832, val_accuracy=0.95000
# step 16300, loss = 0.1392, val_loss = 0.1298, val_accuracy=0.97000
# step 16400, loss = 0.2865, val_loss = 0.2677, val_accuracy=0.91000
# step 16500, loss = 0.1329, val_loss = 0.1211, val_accuracy=0.94000
# step 16600, loss = 0.0799, val_loss = 0.0424, val_accuracy=0.95000
# step 16700, loss = 0.1297, val_loss = 0.1123, val_accuracy=0.96000
# step 16800, loss = 0.0442, val_loss = 0.1899, val_accuracy=0.94000
# step 16900, loss = 0.1659, val_loss = 0.1907, val_accuracy=0.95000
# step 17000, loss = 0.2071, val_loss = 0.0346, val_accuracy=0.92000
# step 17100, loss = 0.1061, val_loss = 0.1907, val_accuracy=0.93000
# step 17200, loss = 0.1820, val_loss = 0.2145, val_accuracy=0.97000
# step 17300, loss = 0.0696, val_loss = 0.2407, val_accuracy=0.97000
# step 17400, loss = 0.0988, val_loss = 0.1780, val_accuracy=0.98000
# step 17500, loss = 0.0996, val_loss = 0.1977, val_accuracy=0.97000
# step 17600, loss = 0.1308, val_loss = 0.0997, val_accuracy=0.97000
# step 17700, loss = 0.2178, val_loss = 0.1059, val_accuracy=0.94000
# step 17800, loss = 0.0934, val_loss = 0.0255, val_accuracy=0.96000
# step 17900, loss = 0.0877, val_loss = 0.2600, val_accuracy=0.97000
# step 18000, loss = 0.1571, val_loss = 0.1811, val_accuracy=0.97000
# step 18100, loss = 0.1118, val_loss = 0.1340, val_accuracy=0.96000
# step 18200, loss = 0.1126, val_loss = 0.2574, val_accuracy=0.96000
# step 18300, loss = 0.0696, val_loss = 0.1280, val_accuracy=0.97000
# step 18400, loss = 0.1667, val_loss = 0.1747, val_accuracy=0.98000
# step 18500, loss = 0.1289, val_loss = 0.2023, val_accuracy=0.96000
# step 18600, loss = 0.2414, val_loss = 0.1317, val_accuracy=0.98000
# step 18700, loss = 0.3047, val_loss = 0.2029, val_accuracy=0.95000
# step 18800, loss = 0.2859, val_loss = 0.1387, val_accuracy=0.98000
# step 18900, loss = 0.0836, val_loss = 0.1208, val_accuracy=0.97000
# step 19000, loss = 0.2385, val_loss = 0.1458, val_accuracy=0.97000
# step 19100, loss = 0.1545, val_loss = 0.1360, val_accuracy=0.99000
# step 19200, loss = 0.1615, val_loss = 0.1636, val_accuracy=0.98000
# step 19300, loss = 0.2021, val_loss = 0.0784, val_accuracy=0.98000
# step 19400, loss = 0.0930, val_loss = 0.1717, val_accuracy=0.97000
# step 19500, loss = 0.2449, val_loss = 0.0695, val_accuracy=0.99000
# step 19600, loss = 0.1343, val_loss = 0.2666, val_accuracy=0.98000
# step 19700, loss = 0.2173, val_loss = 0.0443, val_accuracy=0.99000
# step 19800, loss = 0.1661, val_loss = 0.1316, val_accuracy=0.98000
# step 19900, loss = 0.1170, val_loss = 0.1258, val_accuracy=0.99000
# step 20000, loss = 0.1699, val_loss = 0.1033, val_accuracy=0.97000
# step 20100, loss = 0.1304, val_loss = 0.0374, val_accuracy=0.97000
# step 20200, loss = 0.1762, val_loss = 0.1827, val_accuracy=0.98000
# step 20300, loss = 0.0975, val_loss = 0.1087, val_accuracy=0.98000
# step 20400, loss = 0.1422, val_loss = 0.2730, val_accuracy=0.98000
# step 20500, loss = 0.1429, val_loss = 0.1706, val_accuracy=0.96000
# step 20600, loss = 0.0684, val_loss = 0.2506, val_accuracy=0.95000
# step 20700, loss = 0.1696, val_loss = 0.2023, val_accuracy=0.96000
# step 20800, loss = 0.1898, val_loss = 0.1114, val_accuracy=0.96000
# step 20900, loss = 0.0796, val_loss = 0.1467, val_accuracy=0.97000
# step 21000, loss = 0.1880, val_loss = 0.0924, val_accuracy=0.89000
# step 21100, loss = 0.1139, val_loss = 0.2338, val_accuracy=0.99000
# step 21200, loss = 0.1125, val_loss = 0.1837, val_accuracy=0.97000
# step 21300, loss = 0.2240, val_loss = 0.0904, val_accuracy=0.96000
# step 21400, loss = 0.1489, val_loss = 0.0547, val_accuracy=0.97000
# step 21500, loss = 0.1965, val_loss = 0.0775, val_accuracy=0.97000
# step 21600, loss = 0.1760, val_loss = 0.0929, val_accuracy=0.97000
# step 21700, loss = 0.2077, val_loss = 0.1360, val_accuracy=0.96000
# step 21800, loss = 0.0926, val_loss = 0.1015, val_accuracy=0.98000
# step 21900, loss = 0.1340, val_loss = 0.1266, val_accuracy=0.96000
# step 22000, loss = 0.1948, val_loss = 0.1820, val_accuracy=0.97000
# step 22100, loss = 0.0955, val_loss = 0.1024, val_accuracy=0.96000
# step 22200, loss = 0.2060, val_loss = 0.1697, val_accuracy=0.95000
# step 22300, loss = 0.1574, val_loss = 0.1272, val_accuracy=0.98000
# step 22400, loss = 0.1391, val_loss = 0.0385, val_accuracy=0.96000
# step 22500, loss = 0.1166, val_loss = 0.0940, val_accuracy=0.96000
# step 22600, loss = 0.2159, val_loss = 0.0454, val_accuracy=0.98000
# step 22700, loss = 0.1458, val_loss = 0.1033, val_accuracy=0.95000
# step 22800, loss = 0.3878, val_loss = 0.3205, val_accuracy=0.95000
# step 22900, loss = 0.2463, val_loss = 0.0833, val_accuracy=0.96000
# step 23000, loss = 0.2592, val_loss = 0.0919, val_accuracy=0.97000
# step 23100, loss = 0.0958, val_loss = 0.1407, val_accuracy=0.96000
# step 23200, loss = 0.1103, val_loss = 0.0659, val_accuracy=0.98000
# step 23300, loss = 0.1018, val_loss = 0.1392, val_accuracy=0.98000
# step 23400, loss = 0.1818, val_loss = 0.1424, val_accuracy=0.95000
# step 23500, loss = 0.2202, val_loss = 0.1303, val_accuracy=0.97000
# step 23600, loss = 0.0536, val_loss = 0.0200, val_accuracy=0.93000
# step 23700, loss = 0.2541, val_loss = 0.2139, val_accuracy=0.94000
# step 23800, loss = 0.0846, val_loss = 0.1090, val_accuracy=0.95000
# step 23900, loss = 0.1270, val_loss = 0.0462, val_accuracy=0.97000
# step 24000, loss = 0.1798, val_loss = 0.0842, val_accuracy=0.93000
# step 24100, loss = 0.0898, val_loss = 0.2065, val_accuracy=0.95000
# step 24200, loss = 0.0866, val_loss = 0.0882, val_accuracy=0.97000
# step 24300, loss = 0.1564, val_loss = 0.0213, val_accuracy=0.96000
# step 24400, loss = 0.1569, val_loss = 0.2626, val_accuracy=0.97000
# step 24500, loss = 0.2195, val_loss = 0.0307, val_accuracy=0.97000
# step 24600, loss = 0.1204, val_loss = 0.0652, val_accuracy=0.98000
# step 24700, loss = 0.0689, val_loss = 0.0326, val_accuracy=0.98000
# step 24800, loss = 0.1880, val_loss = 0.2403, val_accuracy=0.95000
# step 24900, loss = 0.1458, val_loss = 0.2017, val_accuracy=0.99000
# step 25000, loss = 0.0775, val_loss = 0.1535, val_accuracy=0.99000
# step 25100, loss = 0.0465, val_loss = 0.1801, val_accuracy=0.99000
# step 25200, loss = 0.0987, val_loss = 0.1463, val_accuracy=0.99000
# step 25300, loss = 0.1088, val_loss = 0.1387, val_accuracy=0.95000
# step 25400, loss = 0.2978, val_loss = 0.1106, val_accuracy=0.98000
# step 25500, loss = 0.2058, val_loss = 0.2026, val_accuracy=0.99000
# step 25600, loss = 0.1862, val_loss = 0.0638, val_accuracy=0.98000
# step 25700, loss = 0.3795, val_loss = 0.1408, val_accuracy=0.99000
# step 25800, loss = 0.0727, val_loss = 0.0326, val_accuracy=0.99000
# step 25900, loss = 0.0549, val_loss = 0.0373, val_accuracy=0.98000
# step 26000, loss = 0.1667, val_loss = 0.0297, val_accuracy=0.97000
# step 26100, loss = 0.2776, val_loss = 0.1907, val_accuracy=0.97000
# step 26200, loss = 0.1013, val_loss = 0.1735, val_accuracy=0.97000
# step 26300, loss = 0.1952, val_loss = 0.1152, val_accuracy=0.96000
# step 26400, loss = 0.1924, val_loss = 0.1128, val_accuracy=0.99000
# step 26500, loss = 0.1633, val_loss = 0.1109, val_accuracy=0.98000
# step 26600, loss = 0.0969, val_loss = 0.0831, val_accuracy=0.95000
# step 26700, loss = 0.0357, val_loss = 0.0620, val_accuracy=1.00000
# step 26800, loss = 0.2455, val_loss = 0.1138, val_accuracy=1.00000
# step 26900, loss = 0.0917, val_loss = 0.0824, val_accuracy=0.97000
# step 27000, loss = 0.0516, val_loss = 0.1430, val_accuracy=1.00000
# step 27100, loss = 0.0554, val_loss = 0.2490, val_accuracy=0.98000
# step 27200, loss = 0.1858, val_loss = 0.0563, val_accuracy=0.99000
# step 27300, loss = 0.1562, val_loss = 0.0957, val_accuracy=0.94000
# step 27400, loss = 0.1226, val_loss = 0.1178, val_accuracy=0.95000
# step 27500, loss = 0.1889, val_loss = 0.2612, val_accuracy=0.94000
# step 27600, loss = 0.2745, val_loss = 0.1370, val_accuracy=0.93000
# step 27700, loss = 0.1730, val_loss = 0.1569, val_accuracy=0.95000
# step 27800, loss = 0.1440, val_loss = 0.0321, val_accuracy=0.94000
# step 27900, loss = 0.1659, val_loss = 0.1185, val_accuracy=0.95000
# step 28000, loss = 0.0205, val_loss = 0.1465, val_accuracy=0.96000
# step 28100, loss = 0.0408, val_loss = 0.0455, val_accuracy=0.96000
# step 28200, loss = 0.1303, val_loss = 0.1514, val_accuracy=0.97000
# step 28300, loss = 0.1477, val_loss = 0.1196, val_accuracy=0.99000
# step 28400, loss = 0.0624, val_loss = 0.2464, val_accuracy=0.97000
# step 28500, loss = 0.1873, val_loss = 0.2368, val_accuracy=0.97000
# step 28600, loss = 0.0693, val_loss = 0.0094, val_accuracy=0.98000
# step 28700, loss = 0.0902, val_loss = 0.0681, val_accuracy=0.97000
# step 28800, loss = 0.0683, val_loss = 0.0616, val_accuracy=0.96000
# step 28900, loss = 0.2061, val_loss = 0.1036, val_accuracy=0.95000
# step 29000, loss = 0.2451, val_loss = 0.0936, val_accuracy=0.96000
# step 29100, loss = 0.1217, val_loss = 0.1613, val_accuracy=0.98000
# step 29200, loss = 0.1776, val_loss = 0.1020, val_accuracy=0.99000
# step 29300, loss = 0.0352, val_loss = 0.1059, val_accuracy=0.98000
# step 29400, loss = 0.1421, val_loss = 0.1590, val_accuracy=0.98000
# step 29500, loss = 0.1232, val_loss = 0.0518, val_accuracy=0.97000
# step 29600, loss = 0.1699, val_loss = 0.1536, val_accuracy=0.97000
# step 29700, loss = 0.1186, val_loss = 0.0992, val_accuracy=0.97000
# step 29800, loss = 0.2291, val_loss = 0.1272, val_accuracy=0.94000
# step 29900, loss = 0.0878, val_loss = 0.0882, val_accuracy=0.95000
# step 30000, loss = 0.0808, val_loss = 0.0445, val_accuracy=0.97000
# step 30100, loss = 0.1281, val_loss = 0.0849, val_accuracy=0.96000
# step 30200, loss = 0.2622, val_loss = 0.3584, val_accuracy=0.97000
# step 30300, loss = 0.2157, val_loss = 0.0792, val_accuracy=0.96000
# step 30400, loss = 0.1813, val_loss = 0.0828, val_accuracy=0.97000
# step 30500, loss = 0.2596, val_loss = 0.1149, val_accuracy=0.97000
# step 30600, loss = 0.0584, val_loss = 0.2193, val_accuracy=0.97000
# step 30700, loss = 0.1835, val_loss = 0.1709, val_accuracy=0.99000
# step 30800, loss = 0.0406, val_loss = 0.0269, val_accuracy=0.99000
# step 30900, loss = 0.1186, val_loss = 0.1020, val_accuracy=0.98000
# step 31000, loss = 0.0847, val_loss = 0.0484, val_accuracy=0.98000
# step 31100, loss = 0.1382, val_loss = 0.2481, val_accuracy=0.98000
# step 31200, loss = 0.1451, val_loss = 0.0436, val_accuracy=0.95000
# step 31300, loss = 0.0856, val_loss = 0.0931, val_accuracy=0.96000
# step 31400, loss = 0.2445, val_loss = 0.0843, val_accuracy=0.95000
# step 31500, loss = 0.1609, val_loss = 0.1910, val_accuracy=0.94000
# step 31600, loss = 0.0824, val_loss = 0.0827, val_accuracy=0.96000
# step 31700, loss = 0.1041, val_loss = 0.0827, val_accuracy=0.96000
# step 31800, loss = 0.2218, val_loss = 0.0321, val_accuracy=0.95000
# step 31900, loss = 0.0688, val_loss = 0.2954, val_accuracy=0.96000
# step 32000, loss = 0.0586, val_loss = 0.0943, val_accuracy=0.96000
# step 32100, loss = 0.3014, val_loss = 0.0375, val_accuracy=0.97000
# step 32200, loss = 0.0631, val_loss = 0.1131, val_accuracy=0.96000
# step 32300, loss = 0.0167, val_loss = 0.1800, val_accuracy=0.98000
# step 32400, loss = 0.0749, val_loss = 0.0305, val_accuracy=0.98000
# step 32500, loss = 0.1066, val_loss = 0.1936, val_accuracy=0.98000
# step 32600, loss = 0.0678, val_loss = 0.0522, val_accuracy=0.98000
# step 32700, loss = 0.0172, val_loss = 0.0668, val_accuracy=0.99000
# step 32800, loss = 0.0227, val_loss = 0.1603, val_accuracy=0.99000
# step 32900, loss = 0.1362, val_loss = 0.0674, val_accuracy=0.98000
# step 33000, loss = 0.0464, val_loss = 0.0192, val_accuracy=0.94000
# step 33100, loss = 0.4318, val_loss = 0.2855, val_accuracy=0.93000
# step 33200, loss = 0.0553, val_loss = 0.1007, val_accuracy=0.96000
# step 33300, loss = 0.1911, val_loss = 0.1738, val_accuracy=0.95000
# step 33400, loss = 0.1968, val_loss = 0.1027, val_accuracy=0.97000
# step 33500, loss = 0.0630, val_loss = 0.1731, val_accuracy=0.98000
# step 33600, loss = 0.0422, val_loss = 0.0587, val_accuracy=0.97000
# step 33700, loss = 0.2747, val_loss = 0.2367, val_accuracy=0.96000
# step 33800, loss = 0.0977, val_loss = 0.0772, val_accuracy=0.97000
# step 33900, loss = 0.1911, val_loss = 0.0775, val_accuracy=0.96000
# step 34000, loss = 0.1299, val_loss = 0.0836, val_accuracy=0.98000
# step 34100, loss = 0.0455, val_loss = 0.1196, val_accuracy=0.94000
# step 34200, loss = 0.1914, val_loss = 0.0883, val_accuracy=0.97000
# step 34300, loss = 0.2160, val_loss = 0.0325, val_accuracy=0.96000
# step 34400, loss = 0.0766, val_loss = 0.0505, val_accuracy=0.97000
# step 34500, loss = 0.2722, val_loss = 0.0529, val_accuracy=0.97000
# step 34600, loss = 0.1459, val_loss = 0.0965, val_accuracy=0.97000
# step 34700, loss = 0.1827, val_loss = 0.1126, val_accuracy=0.94000
# step 34800, loss = 0.0847, val_loss = 0.0661, val_accuracy=0.95000
# step 34900, loss = 0.0514, val_loss = 0.0376, val_accuracy=0.97000
# step 35000, loss = 0.0767, val_loss = 0.1115, val_accuracy=0.99000
# step 35100, loss = 0.1165, val_loss = 0.2147, val_accuracy=0.98000
# step 35200, loss = 0.0399, val_loss = 0.2517, val_accuracy=0.98000
# step 35300, loss = 0.2736, val_loss = 0.1285, val_accuracy=0.97000
# step 35400, loss = 0.0716, val_loss = 0.0628, val_accuracy=0.98000
# step 35500, loss = 0.1845, val_loss = 0.1798, val_accuracy=0.98000
# step 35600, loss = 0.2824, val_loss = 0.0506, val_accuracy=0.96000
# step 35700, loss = 0.1228, val_loss = 0.1841, val_accuracy=0.98000
# step 35800, loss = 0.1021, val_loss = 0.0423, val_accuracy=0.98000
# step 35900, loss = 0.0976, val_loss = 0.1571, val_accuracy=0.99000
# step 36000, loss = 0.1007, val_loss = 0.0079, val_accuracy=0.96000
# step 36100, loss = 0.1352, val_loss = 0.2468, val_accuracy=0.99000
# step 36200, loss = 0.3350, val_loss = 0.1352, val_accuracy=0.97000
# step 36300, loss = 0.0753, val_loss = 0.0992, val_accuracy=0.96000
# step 36400, loss = 0.0316, val_loss = 0.0648, val_accuracy=0.95000
# step 36500, loss = 0.2789, val_loss = 0.1328, val_accuracy=0.94000
# step 36600, loss = 0.1303, val_loss = 0.0953, val_accuracy=0.97000
# step 36700, loss = 0.0872, val_loss = 0.0349, val_accuracy=0.97000
# step 36800, loss = 0.0574, val_loss = 0.0847, val_accuracy=0.97000
# step 36900, loss = 0.1546, val_loss = 0.0779, val_accuracy=0.96000
# step 37000, loss = 0.0800, val_loss = 0.0329, val_accuracy=0.98000
# step 37100, loss = 0.2210, val_loss = 0.1124, val_accuracy=0.97000
# step 37200, loss = 0.0526, val_loss = 0.1725, val_accuracy=0.97000
# step 37300, loss = 0.0175, val_loss = 0.0973, val_accuracy=0.96000
# step 37400, loss = 0.1611, val_loss = 0.3050, val_accuracy=0.97000
# step 37500, loss = 0.1329, val_loss = 0.1698, val_accuracy=0.98000
# step 37600, loss = 0.1205, val_loss = 0.0644, val_accuracy=0.98000
# step 37700, loss = 0.1694, val_loss = 0.2164, val_accuracy=0.97000
# step 37800, loss = 0.1174, val_loss = 0.1289, val_accuracy=0.95000
# step 37900, loss = 0.1338, val_loss = 0.3449, val_accuracy=0.96000
# step 38000, loss = 0.0981, val_loss = 0.0802, val_accuracy=0.97000
# step 38100, loss = 0.0557, val_loss = 0.3032, val_accuracy=0.97000
# step 38200, loss = 0.1052, val_loss = 0.0996, val_accuracy=0.95000
# step 38300, loss = 0.1081, val_loss = 0.1181, val_accuracy=0.98000
# step 38400, loss = 0.0819, val_loss = 0.1188, val_accuracy=0.98000
# step 38500, loss = 0.0308, val_loss = 0.1235, val_accuracy=0.97000
# step 38600, loss = 0.0136, val_loss = 0.0212, val_accuracy=0.98000
# step 38700, loss = 0.0319, val_loss = 0.1243, val_accuracy=0.99000
# step 38800, loss = 0.1190, val_loss = 0.0983, val_accuracy=0.98000
# step 38900, loss = 0.4563, val_loss = 0.1011, val_accuracy=0.93000
# step 39000, loss = 0.0890, val_loss = 0.1490, val_accuracy=0.94000
# step 39100, loss = 0.0591, val_loss = 0.3624, val_accuracy=0.97000
# step 39200, loss = 0.1992, val_loss = 0.1434, val_accuracy=0.95000
# step 39300, loss = 0.0314, val_loss = 0.1019, val_accuracy=0.97000
# step 39400, loss = 0.3449, val_loss = 0.1582, val_accuracy=0.91000
# step 39500, loss = 0.1003, val_loss = 0.1514, val_accuracy=0.98000
# step 39600, loss = 0.0875, val_loss = 0.2559, val_accuracy=0.99000
# step 39700, loss = 0.0706, val_loss = 0.1042, val_accuracy=0.97000
# step 39800, loss = 0.2030, val_loss = 0.0990, val_accuracy=0.96000
# step 39900, loss = 0.1372, val_loss = 0.0996, val_accuracy=0.98000
# step 40000, loss = 0.1283, val_loss = 0.0301, val_accuracy=0.99000
# step 40100, loss = 0.1243, val_loss = 0.0418, val_accuracy=0.98000
# step 40200, loss = 0.0491, val_loss = 0.1486, val_accuracy=0.97000
# step 40300, loss = 0.0935, val_loss = 0.0821, val_accuracy=0.98000
# step 40400, loss = 0.0741, val_loss = 0.0973, val_accuracy=0.99000
# step 40500, loss = 0.0768, val_loss = 0.1177, val_accuracy=0.98000
# step 40600, loss = 0.3371, val_loss = 0.1438, val_accuracy=1.00000
# step 40700, loss = 0.1350, val_loss = 0.1144, val_accuracy=0.95000
# step 40800, loss = 0.1041, val_loss = 0.0871, val_accuracy=0.99000
# step 40900, loss = 0.1319, val_loss = 0.1227, val_accuracy=0.98000
# step 41000, loss = 0.2612, val_loss = 0.0754, val_accuracy=1.00000
# step 41100, loss = 0.0441, val_loss = 0.1473, val_accuracy=1.00000
# step 41200, loss = 0.1129, val_loss = 0.1221, val_accuracy=0.96000
# step 41300, loss = 0.2049, val_loss = 0.1073, val_accuracy=0.98000
# step 41400, loss = 0.0942, val_loss = 0.1409, val_accuracy=0.99000
# step 41500, loss = 0.2927, val_loss = 0.1702, val_accuracy=0.97000
# step 41600, loss = 0.0600, val_loss = 0.1556, val_accuracy=0.96000
# step 41700, loss = 0.1451, val_loss = 0.0649, val_accuracy=0.97000
# step 41800, loss = 0.1575, val_loss = 0.0686, val_accuracy=0.94000
# step 41900, loss = 0.0732, val_loss = 0.3025, val_accuracy=0.98000
# step 42000, loss = 0.0732, val_loss = 0.1726, val_accuracy=0.98000
# step 42100, loss = 0.0536, val_loss = 0.0681, val_accuracy=0.98000
# step 42200, loss = 0.0675, val_loss = 0.0971, val_accuracy=0.96000
# step 42300, loss = 0.0642, val_loss = 0.1175, val_accuracy=0.97000
# step 42400, loss = 0.1402, val_loss = 0.0316, val_accuracy=0.95000
# step 42500, loss = 0.0649, val_loss = 0.1481, val_accuracy=0.97000
# step 42600, loss = 0.0122, val_loss = 0.0312, val_accuracy=0.97000
# step 42700, loss = 0.0557, val_loss = 0.0440, val_accuracy=0.96000
# step 42800, loss = 0.0280, val_loss = 0.2510, val_accuracy=0.96000
# step 42900, loss = 0.3201, val_loss = 0.0711, val_accuracy=0.98000
# step 43000, loss = 0.1267, val_loss = 0.0842, val_accuracy=0.96000
# step 43100, loss = 0.1935, val_loss = 0.2164, val_accuracy=0.95000
# step 43200, loss = 0.0810, val_loss = 0.0258, val_accuracy=0.98000
# step 43300, loss = 0.1355, val_loss = 0.0575, val_accuracy=0.97000
# step 43400, loss = 0.0672, val_loss = 0.0734, val_accuracy=0.97000
# step 43500, loss = 0.0279, val_loss = 0.1225, val_accuracy=0.97000
# step 43600, loss = 0.0358, val_loss = 0.0555, val_accuracy=0.98000
# step 43700, loss = 0.1617, val_loss = 0.1658, val_accuracy=1.00000
# step 43800, loss = 0.1334, val_loss = 0.1881, val_accuracy=0.98000
# step 43900, loss = 0.2093, val_loss = 0.0718, val_accuracy=0.97000
# step 44000, loss = 0.3230, val_loss = 0.1791, val_accuracy=1.00000
# step 44100, loss = 0.0687, val_loss = 0.1855, val_accuracy=0.99000
# step 44200, loss = 0.0724, val_loss = 0.0573, val_accuracy=0.96000
# step 44300, loss = 0.1073, val_loss = 0.0105, val_accuracy=0.98000
# step 44400, loss = 0.0378, val_loss = 0.0714, val_accuracy=0.97000
# step 44500, loss = 0.0176, val_loss = 0.0665, val_accuracy=0.97000
# step 44600, loss = 0.1000, val_loss = 0.0451, val_accuracy=0.97000
# step 44700, loss = 0.0313, val_loss = 0.0085, val_accuracy=0.98000
# step 44800, loss = 0.0933, val_loss = 0.0313, val_accuracy=0.97000
# step 44900, loss = 0.0314, val_loss = 0.0572, val_accuracy=0.97000
# step 45000, loss = 0.0788, val_loss = 0.2638, val_accuracy=0.97000
# step 45100, loss = 0.0378, val_loss = 0.3665, val_accuracy=0.97000
# step 45200, loss = 0.1750, val_loss = 0.3410, val_accuracy=0.97000
# step 45300, loss = 0.4631, val_loss = 0.3197, val_accuracy=0.97000
# step 45400, loss = 0.1117, val_loss = 0.0881, val_accuracy=0.96000
# step 45500, loss = 0.2262, val_loss = 0.1401, val_accuracy=0.95000
# step 45600, loss = 0.1916, val_loss = 0.1559, val_accuracy=0.97000
# step 45700, loss = 0.0526, val_loss = 0.1310, val_accuracy=0.98000
# step 45800, loss = 0.2488, val_loss = 0.0585, val_accuracy=0.97000
# step 45900, loss = 0.0959, val_loss = 0.0504, val_accuracy=0.99000
# step 46000, loss = 0.0465, val_loss = 0.0455, val_accuracy=0.96000
# step 46100, loss = 0.2333, val_loss = 0.2421, val_accuracy=0.98000
# step 46200, loss = 0.0773, val_loss = 0.0577, val_accuracy=0.99000
# step 46300, loss = 0.0843, val_loss = 0.2231, val_accuracy=0.99000
# step 46400, loss = 0.0290, val_loss = 0.0630, val_accuracy=0.97000
# step 46500, loss = 0.2847, val_loss = 0.1686, val_accuracy=0.98000
# step 46600, loss = 0.0241, val_loss = 0.1546, val_accuracy=0.98000
# step 46700, loss = 0.0992, val_loss = 0.0479, val_accuracy=0.98000
# step 46800, loss = 0.0141, val_loss = 0.0625, val_accuracy=0.98000
# step 46900, loss = 0.0315, val_loss = 0.1121, val_accuracy=0.99000
# step 47000, loss = 0.0595, val_loss = 0.0643, val_accuracy=0.99000
# step 47100, loss = 0.0547, val_loss = 0.1526, val_accuracy=0.99000
# step 47200, loss = 0.0849, val_loss = 0.0788, val_accuracy=1.00000
# step 47300, loss = 0.1473, val_loss = 0.0529, val_accuracy=0.99000
# step 47400, loss = 0.1478, val_loss = 0.0847, val_accuracy=1.00000
# step 47500, loss = 0.0243, val_loss = 0.2191, val_accuracy=1.00000
# step 47600, loss = 0.1016, val_loss = 0.0243, val_accuracy=0.99000
# step 47700, loss = 0.1897, val_loss = 0.0857, val_accuracy=0.99000
# step 47800, loss = 0.1605, val_loss = 0.0464, val_accuracy=0.95000
# step 47900, loss = 0.0498, val_loss = 0.5019, val_accuracy=0.97000
# step 48000, loss = 0.2756, val_loss = 0.0973, val_accuracy=1.00000
# step 48100, loss = 0.0969, val_loss = 0.1933, val_accuracy=0.99000
# step 48200, loss = 0.1728, val_loss = 0.2253, val_accuracy=0.95000
# step 48300, loss = 0.1339, val_loss = 0.1046, val_accuracy=0.99000
# step 48400, loss = 0.2822, val_loss = 0.1023, val_accuracy=0.97000
# step 48500, loss = 0.1153, val_loss = 0.1528, val_accuracy=0.98000
# step 48600, loss = 0.0739, val_loss = 0.0580, val_accuracy=0.97000
# step 48700, loss = 0.1006, val_loss = 0.0924, val_accuracy=0.97000
# step 48800, loss = 0.1237, val_loss = 0.0873, val_accuracy=0.97000
# step 48900, loss = 0.1437, val_loss = 0.0431, val_accuracy=0.98000
# step 49000, loss = 0.1972, val_loss = 0.0728, val_accuracy=0.98000
# step 49100, loss = 0.0969, val_loss = 0.1532, val_accuracy=0.96000
# step 49200, loss = 0.1366, val_loss = 0.2020, val_accuracy=0.98000
# step 49300, loss = 0.1272, val_loss = 0.1063, val_accuracy=0.99000
# step 49400, loss = 0.0887, val_loss = 0.1090, val_accuracy=0.98000
# step 49500, loss = 0.0296, val_loss = 0.0260, val_accuracy=0.99000
# step 49600, loss = 0.0034, val_loss = 0.1158, val_accuracy=0.99000
# step 49700, loss = 0.1234, val_loss = 0.0828, val_accuracy=0.98000
# step 49800, loss = 0.1840, val_loss = 0.2037, val_accuracy=0.98000
# step 49900, loss = 0.2011, val_loss = 0.1173, val_accuracy=0.98000
# step 50000, loss = 0.0140, val_loss = 0.0534, val_accuracy=0.98000
# step 50100, loss = 0.1191, val_loss = 0.0622, val_accuracy=0.98000
# step 50200, loss = 0.1954, val_loss = 0.1759, val_accuracy=0.98000
# step 50300, loss = 0.0679, val_loss = 0.0319, val_accuracy=0.98000
# step 50400, loss = 0.0868, val_loss = 0.0536, val_accuracy=0.99000
# step 50500, loss = 0.1416, val_loss = 0.2495, val_accuracy=0.96000
# step 50600, loss = 0.0823, val_loss = 0.1714, val_accuracy=0.96000
# step 50700, loss = 0.3397, val_loss = 0.1848, val_accuracy=0.96000
# step 50800, loss = 0.1172, val_loss = 0.0365, val_accuracy=0.97000
# step 50900, loss = 0.0468, val_loss = 0.1242, val_accuracy=0.96000
# step 51000, loss = 0.2212, val_loss = 0.0076, val_accuracy=0.95000
# step 51100, loss = 0.1347, val_loss = 0.1477, val_accuracy=0.98000
# step 51200, loss = 0.0892, val_loss = 0.0479, val_accuracy=0.97000
# step 51300, loss = 0.1117, val_loss = 0.0606, val_accuracy=0.94000
# step 51400, loss = 0.0760, val_loss = 0.1541, val_accuracy=0.97000
# step 51500, loss = 0.1832, val_loss = 0.1357, val_accuracy=0.94000
# step 51600, loss = 0.0833, val_loss = 0.1169, val_accuracy=0.96000
# step 51700, loss = 0.0774, val_loss = 0.1526, val_accuracy=0.95000
# step 51800, loss = 0.2075, val_loss = 0.0322, val_accuracy=0.95000
# step 51900, loss = 0.1310, val_loss = 0.0907, val_accuracy=0.96000
# step 52000, loss = 0.2511, val_loss = 0.0791, val_accuracy=0.97000
# step 52100, loss = 0.2126, val_loss = 0.0945, val_accuracy=0.97000
# step 52200, loss = 0.0974, val_loss = 0.2112, val_accuracy=0.98000
# step 52300, loss = 0.2121, val_loss = 0.1946, val_accuracy=0.98000
# step 52400, loss = 0.0779, val_loss = 0.1046, val_accuracy=0.96000
# step 52500, loss = 0.1343, val_loss = 0.2251, val_accuracy=0.96000
# step 52600, loss = 0.1637, val_loss = 0.0416, val_accuracy=0.97000
# step 52700, loss = 0.1833, val_loss = 0.1067, val_accuracy=0.94000
# step 52800, loss = 0.0706, val_loss = 0.1578, val_accuracy=0.96000
# step 52900, loss = 0.0390, val_loss = 0.0487, val_accuracy=0.99000
# step 53000, loss = 0.1930, val_loss = 0.0598, val_accuracy=0.99000
# step 53100, loss = 0.0422, val_loss = 0.1429, val_accuracy=0.97000
# step 53200, loss = 0.3146, val_loss = 0.0550, val_accuracy=0.96000
# step 53300, loss = 0.1628, val_loss = 0.0920, val_accuracy=0.97000
# step 53400, loss = 0.0771, val_loss = 0.0954, val_accuracy=0.96000
# step 53500, loss = 0.1423, val_loss = 0.1533, val_accuracy=0.98000
# step 53600, loss = 0.0930, val_loss = 0.0236, val_accuracy=0.97000
# step 53700, loss = 0.1677, val_loss = 0.1377, val_accuracy=1.00000
# step 53800, loss = 0.0353, val_loss = 0.0672, val_accuracy=1.00000
# step 53900, loss = 0.0800, val_loss = 0.0507, val_accuracy=1.00000
# step 54000, loss = 0.0679, val_loss = 0.0337, val_accuracy=0.99000
# step 54100, loss = 0.1401, val_loss = 0.0355, val_accuracy=0.97000
# step 54200, loss = 0.0761, val_loss = 0.0786, val_accuracy=0.97000
# step 54300, loss = 0.0525, val_loss = 0.0210, val_accuracy=0.98000
# step 54400, loss = 0.0813, val_loss = 0.1224, val_accuracy=0.96000
# step 54500, loss = 0.1938, val_loss = 0.2299, val_accuracy=0.94000
# step 54600, loss = 0.1141, val_loss = 0.0518, val_accuracy=0.96000
# step 54700, loss = 0.1235, val_loss = 0.0383, val_accuracy=0.96000
# step 54800, loss = 0.0555, val_loss = 0.0634, val_accuracy=0.98000
# step 54900, loss = 0.0818, val_loss = 0.1616, val_accuracy=0.96000
# step 55000, loss = 0.0774, val_loss = 0.1817, val_accuracy=0.97000
# step 55100, loss = 0.1090, val_loss = 0.1407, val_accuracy=0.92000
# step 55200, loss = 0.0777, val_loss = 0.2358, val_accuracy=0.97000
# step 55300, loss = 0.0932, val_loss = 0.1158, val_accuracy=0.96000
# step 55400, loss = 0.1775, val_loss = 0.0880, val_accuracy=0.97000
# step 55500, loss = 0.1638, val_loss = 0.1804, val_accuracy=0.99000
# step 55600, loss = 0.0857, val_loss = 0.0804, val_accuracy=0.99000
# step 55700, loss = 0.1563, val_loss = 0.0725, val_accuracy=0.97000
# step 55800, loss = 0.0496, val_loss = 0.0310, val_accuracy=0.97000
# step 55900, loss = 0.1960, val_loss = 0.0304, val_accuracy=0.97000
# step 56000, loss = 0.0375, val_loss = 0.0200, val_accuracy=0.98000
# step 56100, loss = 0.0378, val_loss = 0.1296, val_accuracy=0.95000
# step 56200, loss = 0.1598, val_loss = 0.0403, val_accuracy=0.98000
# step 56300, loss = 0.0251, val_loss = 0.0711, val_accuracy=0.98000
# step 56400, loss = 0.0207, val_loss = 0.0382, val_accuracy=0.99000
# step 56500, loss = 0.0266, val_loss = 0.0570, val_accuracy=0.98000
# step 56600, loss = 0.0795, val_loss = 0.0821, val_accuracy=0.94000
# step 56700, loss = 0.1650, val_loss = 0.0373, val_accuracy=0.97000
# step 56800, loss = 0.1092, val_loss = 0.1251, val_accuracy=0.98000
# step 56900, loss = 0.1098, val_loss = 0.0431, val_accuracy=0.97000
# step 57000, loss = 0.2023, val_loss = 0.0879, val_accuracy=0.98000
# step 57100, loss = 0.0618, val_loss = 0.0972, val_accuracy=0.99000
# step 57200, loss = 0.1496, val_loss = 0.0626, val_accuracy=0.99000
# step 57300, loss = 0.1209, val_loss = 0.0607, val_accuracy=0.98000
# step 57400, loss = 0.0464, val_loss = 0.0735, val_accuracy=0.99000
# step 57500, loss = 0.0052, val_loss = 0.1934, val_accuracy=0.98000
# step 57600, loss = 0.0822, val_loss = 0.1037, val_accuracy=0.98000
# step 57700, loss = 0.0794, val_loss = 0.0731, val_accuracy=0.97000
# step 57800, loss = 0.0845, val_loss = 0.0595, val_accuracy=0.98000
# step 57900, loss = 0.3403, val_loss = 0.2212, val_accuracy=0.98000
# step 58000, loss = 0.1677, val_loss = 0.0866, val_accuracy=0.96000
# step 58100, loss = 0.0882, val_loss = 0.1406, val_accuracy=0.99000
# step 58200, loss = 0.2035, val_loss = 0.1388, val_accuracy=0.98000
# step 58300, loss = 0.0595, val_loss = 0.1574, val_accuracy=0.97000
# step 58400, loss = 0.1262, val_loss = 0.1371, val_accuracy=0.99000
# step 58500, loss = 0.1594, val_loss = 0.1120, val_accuracy=0.96000
# step 58600, loss = 0.2241, val_loss = 0.0404, val_accuracy=0.98000
# step 58700, loss = 0.0844, val_loss = 0.1750, val_accuracy=0.99000
# step 58800, loss = 0.1741, val_loss = 0.0911, val_accuracy=0.98000
# step 58900, loss = 0.1296, val_loss = 0.0250, val_accuracy=0.98000
# step 59000, loss = 0.1736, val_loss = 0.1323, val_accuracy=0.98000
# step 59100, loss = 0.0476, val_loss = 0.1717, val_accuracy=0.98000
# step 59200, loss = 0.2350, val_loss = 0.1524, val_accuracy=1.00000
# step 59300, loss = 0.1353, val_loss = 0.0118, val_accuracy=0.99000
# step 59400, loss = 0.1067, val_loss = 0.0533, val_accuracy=0.96000
# step 59500, loss = 0.0789, val_loss = 0.0210, val_accuracy=0.96000
# step 59600, loss = 0.0693, val_loss = 0.2094, val_accuracy=0.98000
# step 59700, loss = 0.0551, val_loss = 0.0283, val_accuracy=0.98000
# step 59800, loss = 0.0183, val_loss = 0.1806, val_accuracy=0.98000
# step 59900, loss = 0.0602, val_loss = 0.0521, val_accuracy=0.98000
# step 60000, loss = 0.0310, val_loss = 0.0264, val_accuracy=0.96000
# step 60100, loss = 0.0531, val_loss = 0.0089, val_accuracy=0.95000
# step 60200, loss = 0.0696, val_loss = 0.2436, val_accuracy=0.98000
# step 60300, loss = 0.0852, val_loss = 0.1159, val_accuracy=0.97000
# step 60400, loss = 0.2235, val_loss = 0.1971, val_accuracy=0.98000
# step 60500, loss = 0.2112, val_loss = 0.1159, val_accuracy=0.97000
# step 60600, loss = 0.0804, val_loss = 0.1031, val_accuracy=0.98000
# step 60700, loss = 0.0338, val_loss = 0.0804, val_accuracy=0.99000
# step 60800, loss = 0.1539, val_loss = 0.0223, val_accuracy=0.95000
# step 60900, loss = 0.1428, val_loss = 0.0879, val_accuracy=0.94000
# step 61000, loss = 0.1731, val_loss = 0.0532, val_accuracy=0.95000
# step 61100, loss = 0.3682, val_loss = 0.1471, val_accuracy=0.95000
# step 61200, loss = 0.2107, val_loss = 0.1091, val_accuracy=0.98000
# step 61300, loss = 0.1123, val_loss = 0.0831, val_accuracy=0.99000
# step 61400, loss = 0.0958, val_loss = 0.1303, val_accuracy=0.98000
# step 61500, loss = 0.0676, val_loss = 0.0582, val_accuracy=0.99000
# step 61600, loss = 0.0877, val_loss = 0.2480, val_accuracy=0.96000
# step 61700, loss = 0.0643, val_loss = 0.0697, val_accuracy=0.96000
# step 61800, loss = 0.1605, val_loss = 0.0148, val_accuracy=0.97000
# step 61900, loss = 0.0768, val_loss = 0.1389, val_accuracy=0.98000
# step 62000, loss = 0.0289, val_loss = 0.0371, val_accuracy=0.99000
# step 62100, loss = 0.1010, val_loss = 0.0567, val_accuracy=0.96000
# step 62200, loss = 0.0712, val_loss = 0.1547, val_accuracy=0.97000
# step 62300, loss = 0.0935, val_loss = 0.1389, val_accuracy=0.98000
# step 62400, loss = 0.0960, val_loss = 0.1766, val_accuracy=0.98000
# step 62500, loss = 0.0153, val_loss = 0.2524, val_accuracy=0.97000
# step 62600, loss = 0.2247, val_loss = 0.0760, val_accuracy=0.97000
# step 62700, loss = 0.1126, val_loss = 0.0350, val_accuracy=0.97000
# step 62800, loss = 0.0784, val_loss = 0.0923, val_accuracy=0.97000
# step 62900, loss = 0.0842, val_loss = 0.0486, val_accuracy=0.96000
# step 63000, loss = 0.1966, val_loss = 0.1246, val_accuracy=0.94000
# step 63100, loss = 0.1688, val_loss = 0.2532, val_accuracy=0.96000
# step 63200, loss = 0.1164, val_loss = 0.1030, val_accuracy=0.96000
# step 63300, loss = 0.0546, val_loss = 0.1741, val_accuracy=0.96000
# step 63400, loss = 0.0364, val_loss = 0.0643, val_accuracy=0.95000
# step 63500, loss = 0.1570, val_loss = 0.2010, val_accuracy=0.95000
# step 63600, loss = 0.1564, val_loss = 0.0593, val_accuracy=0.95000
# step 63700, loss = 0.0658, val_loss = 0.1017, val_accuracy=0.96000
# step 63800, loss = 0.0343, val_loss = 0.0887, val_accuracy=0.96000
# step 63900, loss = 0.1152, val_loss = 0.0318, val_accuracy=0.95000
# step 64000, loss = 0.0439, val_loss = 0.0385, val_accuracy=0.96000
# step 64100, loss = 0.0408, val_loss = 0.0296, val_accuracy=0.96000
# step 64200, loss = 0.1554, val_loss = 0.0949, val_accuracy=0.96000
# step 64300, loss = 0.0833, val_loss = 0.0398, val_accuracy=0.96000
# step 64400, loss = 0.0211, val_loss = 0.0441, val_accuracy=0.96000
# step 64500, loss = 0.0588, val_loss = 0.0828, val_accuracy=0.97000
# step 64600, loss = 0.0612, val_loss = 0.0764, val_accuracy=0.95000
# step 64700, loss = 0.1337, val_loss = 0.1122, val_accuracy=0.93000
# step 64800, loss = 0.1612, val_loss = 0.0673, val_accuracy=0.92000
# step 64900, loss = 0.2843, val_loss = 0.4791, val_accuracy=0.95000
# step 65000, loss = 0.0268, val_loss = 0.2028, val_accuracy=0.97000
# step 65100, loss = 0.0896, val_loss = 0.1256, val_accuracy=0.97000
# step 65200, loss = 0.1251, val_loss = 0.1334, val_accuracy=0.97000
# step 65300, loss = 0.0138, val_loss = 0.1987, val_accuracy=0.96000
# step 65400, loss = 0.0496, val_loss = 0.0332, val_accuracy=0.98000
# step 65500, loss = 0.0310, val_loss = 0.2087, val_accuracy=0.96000
# step 65600, loss = 0.0534, val_loss = 0.0626, val_accuracy=0.99000
# step 65700, loss = 0.2625, val_loss = 0.1895, val_accuracy=0.96000
# step 65800, loss = 0.1299, val_loss = 0.1598, val_accuracy=0.97000
# step 65900, loss = 0.0725, val_loss = 0.0509, val_accuracy=0.97000
# step 66000, loss = 0.1358, val_loss = 0.0306, val_accuracy=0.97000
# step 66100, loss = 0.0409, val_loss = 0.1997, val_accuracy=0.97000
# step 66200, loss = 0.1341, val_loss = 0.0236, val_accuracy=0.97000
# step 66300, loss = 0.1184, val_loss = 0.2175, val_accuracy=0.97000
# step 66400, loss = 0.1107, val_loss = 0.1184, val_accuracy=0.96000
# step 66500, loss = 0.1065, val_loss = 0.1909, val_accuracy=0.95000
# step 66600, loss = 0.2611, val_loss = 0.0542, val_accuracy=0.96000
# step 66700, loss = 0.1064, val_loss = 0.0475, val_accuracy=0.97000
# step 66800, loss = 0.0573, val_loss = 0.1200, val_accuracy=0.97000
# step 66900, loss = 0.0547, val_loss = 0.0666, val_accuracy=0.98000
# step 67000, loss = 0.1171, val_loss = 0.0125, val_accuracy=0.98000
# step 67100, loss = 0.0093, val_loss = 0.0913, val_accuracy=0.98000
# step 67200, loss = 0.0614, val_loss = 0.0754, val_accuracy=0.95000
# step 67300, loss = 0.1522, val_loss = 0.1348, val_accuracy=0.94000
# step 67400, loss = 0.1879, val_loss = 0.1596, val_accuracy=0.99000
# step 67500, loss = 0.0424, val_loss = 0.2327, val_accuracy=0.96000
# step 67600, loss = 0.1271, val_loss = 0.1490, val_accuracy=0.96000
# step 67700, loss = 0.0571, val_loss = 0.1635, val_accuracy=0.96000
# step 67800, loss = 0.1372, val_loss = 0.0224, val_accuracy=0.99000
# step 67900, loss = 0.1134, val_loss = 0.1572, val_accuracy=0.96000
# step 68000, loss = 0.2661, val_loss = 0.1258, val_accuracy=0.97000
# step 68100, loss = 0.1765, val_loss = 0.0828, val_accuracy=0.94000
# step 68200, loss = 0.1795, val_loss = 0.1205, val_accuracy=0.96000
# step 68300, loss = 0.0198, val_loss = 0.0389, val_accuracy=0.97000
# step 68400, loss = 0.1498, val_loss = 0.1172, val_accuracy=0.98000
# step 68500, loss = 0.0925, val_loss = 0.1600, val_accuracy=0.98000
# step 68600, loss = 0.2502, val_loss = 0.0466, val_accuracy=0.96000
# step 68700, loss = 0.0815, val_loss = 0.0721, val_accuracy=0.98000
# step 68800, loss = 0.1042, val_loss = 0.0464, val_accuracy=0.98000
# step 68900, loss = 0.0558, val_loss = 0.0353, val_accuracy=0.97000
# step 69000, loss = 0.0470, val_loss = 0.1110, val_accuracy=0.96000
# step 69100, loss = 0.0542, val_loss = 0.2233, val_accuracy=0.94000
# step 69200, loss = 0.0773, val_loss = 0.1720, val_accuracy=0.98000
# step 69300, loss = 0.0570, val_loss = 0.0801, val_accuracy=0.98000
# step 69400, loss = 0.0817, val_loss = 0.0186, val_accuracy=0.98000
# step 69500, loss = 0.0287, val_loss = 0.0110, val_accuracy=0.98000
# step 69600, loss = 0.2642, val_loss = 0.1857, val_accuracy=0.95000
# step 69700, loss = 0.0701, val_loss = 0.1496, val_accuracy=0.97000
# step 69800, loss = 0.1028, val_loss = 0.1173, val_accuracy=0.96000
# step 69900, loss = 0.1332, val_loss = 0.0723, val_accuracy=0.96000
# step 70000, loss = 0.1073, val_loss = 0.1654, val_accuracy=0.97000
# step 70100, loss = 0.1458, val_loss = 0.0634, val_accuracy=0.98000
# step 70200, loss = 0.1792, val_loss = 0.1688, val_accuracy=0.96000
# step 70300, loss = 0.1112, val_loss = 0.0412, val_accuracy=0.97000
# step 70400, loss = 0.0517, val_loss = 0.0555, val_accuracy=0.97000
# step 70500, loss = 0.0980, val_loss = 0.1673, val_accuracy=0.97000
# step 70600, loss = 0.2492, val_loss = 0.1058, val_accuracy=0.97000
# step 70700, loss = 0.0430, val_loss = 0.0409, val_accuracy=0.97000
# step 70800, loss = 0.0167, val_loss = 0.0198, val_accuracy=0.98000
# step 70900, loss = 0.0472, val_loss = 0.1569, val_accuracy=0.97000
# step 71000, loss = 0.2510, val_loss = 0.0246, val_accuracy=0.99000
# step 71100, loss = 0.2090, val_loss = 0.1243, val_accuracy=0.97000
# step 71200, loss = 0.1261, val_loss = 0.0962, val_accuracy=0.99000
# step 71300, loss = 0.0281, val_loss = 0.0697, val_accuracy=0.99000
# step 71400, loss = 0.3073, val_loss = 0.0842, val_accuracy=0.97000
# step 71500, loss = 0.0702, val_loss = 0.0530, val_accuracy=0.97000
# step 71600, loss = 0.1070, val_loss = 0.2337, val_accuracy=0.99000
# step 71700, loss = 0.0717, val_loss = 0.2482, val_accuracy=0.98000
# ...
# step 353000, loss = 0.1070, val_loss = 0.1484, val_accuracy=0.98000
# step 353100, loss = 0.0072, val_loss = 0.1359, val_accuracy=0.98000
# step 353200, loss = 0.1211, val_loss = 0.0354, val_accuracy=0.99000
# step 353300, loss = 0.0512, val_loss = 0.3340, val_accuracy=0.98000
# step 353400, loss = 0.0165, val_loss = 0.1143, val_accuracy=0.98000
# step 353500, loss = 0.0770, val_loss = 0.3160, val_accuracy=0.98000
# step 353600, loss = 0.0062, val_loss = 0.0146, val_accuracy=0.98000
# step 353700, loss = 0.1433, val_loss = 0.2755, val_accuracy=0.99000
# step 353800, loss = 0.0080, val_loss = 0.1038, val_accuracy=0.99000
# step 353900, loss = 0.0232, val_loss = 0.0897, val_accuracy=0.98000
# step 354000, loss = 0.0624, val_loss = 0.0016, val_accuracy=0.99000
# step 354100, loss = 0.0155, val_loss = 0.0432, val_accuracy=0.98000
# step 354200, loss = 0.0913, val_loss = 0.0918, val_accuracy=0.97000
# step 354300, loss = 0.0070, val_loss = 0.0015, val_accuracy=0.97000
# step 354400, loss = 0.0363, val_loss = 0.2235, val_accuracy=0.98000
# step 354500, loss = 0.1495, val_loss = 0.1646, val_accuracy=0.97000
# step 354600, loss = 0.1556, val_loss = 0.3014, val_accuracy=0.98000
# step 354700, loss = 0.0911, val_loss = 0.2358, val_accuracy=0.96000
# step 354800, loss = 0.0915, val_loss = 0.0146, val_accuracy=0.98000
# step 354900, loss = 0.0960, val_loss = 0.1744, val_accuracy=1.00000
# step 355000, loss = 0.0072, val_loss = 0.1715, val_accuracy=1.00000
# step 355100, loss = 0.0348, val_loss = 0.1584, val_accuracy=1.00000
# step 355200, loss = 0.1157, val_loss = 0.3389, val_accuracy=0.99000
# step 355300, loss = 0.0022, val_loss = 0.2341, val_accuracy=0.96000
# step 355400, loss = 0.0676, val_loss = 0.2734, val_accuracy=0.97000
# step 355500, loss = 0.3877, val_loss = 0.1043, val_accuracy=0.98000
# step 355600, loss = 0.0221, val_loss = 0.0426, val_accuracy=0.98000
# step 355700, loss = 0.0601, val_loss = 0.0751, val_accuracy=0.98000
# step 355800, loss = 0.0249, val_loss = 0.0106, val_accuracy=0.98000
# step 355900, loss = 0.0509, val_loss = 0.1161, val_accuracy=0.99000
# step 356000, loss = 0.0027, val_loss = 0.0136, val_accuracy=0.99000
# step 356100, loss = 0.0958, val_loss = 0.5837, val_accuracy=0.96000
# step 356200, loss = 0.1854, val_loss = 0.3695, val_accuracy=0.98000
# step 356300, loss = 0.0111, val_loss = 0.1107, val_accuracy=0.99000
# step 356400, loss = 0.0077, val_loss = 0.0425, val_accuracy=0.98000
# step 356500, loss = 0.1070, val_loss = 0.0875, val_accuracy=0.96000
# step 356600, loss = 0.0112, val_loss = 0.2106, val_accuracy=0.97000
# step 356700, loss = 0.0942, val_loss = 0.1413, val_accuracy=0.97000
# step 356800, loss = 0.0076, val_loss = 0.0298, val_accuracy=0.99000
# step 356900, loss = 0.2378, val_loss = 0.0162, val_accuracy=0.99000
# step 357000, loss = 0.0257, val_loss = 0.0532, val_accuracy=0.98000
# step 357100, loss = 0.0054, val_loss = 0.1307, val_accuracy=0.98000
# step 357200, loss = 0.0426, val_loss = 0.0340, val_accuracy=1.00000
# step 357300, loss = 0.1379, val_loss = 0.1879, val_accuracy=0.99000
# step 357400, loss = 0.1251, val_loss = 0.0598, val_accuracy=0.98000
# step 357500, loss = 0.0304, val_loss = 0.1003, val_accuracy=0.98000
# step 357600, loss = 0.0103, val_loss = 0.1083, val_accuracy=0.98000
# step 357700, loss = 0.0141, val_loss = 0.2407, val_accuracy=0.97000
# step 357800, loss = 0.1292, val_loss = 0.0006, val_accuracy=0.95000
# step 357900, loss = 0.3674, val_loss = 0.2120, val_accuracy=0.97000
# step 358000, loss = 0.1121, val_loss = 0.1481, val_accuracy=0.97000
# step 358100, loss = 0.0981, val_loss = 0.0600, val_accuracy=0.99000
# step 358200, loss = 0.0481, val_loss = 0.1901, val_accuracy=1.00000
# step 358300, loss = 0.0247, val_loss = 0.0402, val_accuracy=1.00000
# step 358400, loss = 0.0843, val_loss = 0.1876, val_accuracy=1.00000
# step 358500, loss = 0.0678, val_loss = 0.2734, val_accuracy=1.00000
# step 358600, loss = 0.2037, val_loss = 0.1388, val_accuracy=0.99000
# step 358700, loss = 0.0350, val_loss = 0.1174, val_accuracy=1.00000
# step 358800, loss = 0.0371, val_loss = 0.1735, val_accuracy=1.00000
# step 358900, loss = 0.0608, val_loss = 0.0037, val_accuracy=1.00000
# step 359000, loss = 0.2200, val_loss = 0.0294, val_accuracy=0.99000
# step 359100, loss = 0.0456, val_loss = 0.0516, val_accuracy=0.98000
# step 359200, loss = 0.0263, val_loss = 0.2433, val_accuracy=0.99000
# step 359300, loss = 0.0707, val_loss = 0.0443, val_accuracy=1.00000
# step 359400, loss = 0.1100, val_loss = 0.2023, val_accuracy=1.00000
# step 359500, loss = 0.0478, val_loss = 0.0596, val_accuracy=0.99000
# step 359600, loss = 0.0125, val_loss = 0.0388, val_accuracy=0.99000
# step 359700, loss = 0.0399, val_loss = 0.0653, val_accuracy=0.99000
# step 359800, loss = 0.0044, val_loss = 0.1353, val_accuracy=0.99000
# step 359900, loss = 0.0101, val_loss = 0.0854, val_accuracy=1.00000
# step 360000, loss = 0.0828, val_loss = 0.0062, val_accuracy=0.99000
# step 360100, loss = 0.0202, val_loss = 0.0888, val_accuracy=0.99000
# step 360200, loss = 0.0257, val_loss = 0.3845, val_accuracy=1.00000
# step 360300, loss = 0.0012, val_loss = 0.0116, val_accuracy=1.00000
# step 360400, loss = 0.1389, val_loss = 0.2160, val_accuracy=0.99000
# step 360500, loss = 0.0699, val_loss = 0.1192, val_accuracy=0.99000
# step 360600, loss = 0.0828, val_loss = 0.2386, val_accuracy=0.99000
# step 360700, loss = 0.0397, val_loss = 0.2778, val_accuracy=0.97000
# step 360800, loss = 0.0249, val_loss = 0.0174, val_accuracy=0.99000
# step 360900, loss = 0.1088, val_loss = 0.1553, val_accuracy=0.99000
# step 361000, loss = 0.1113, val_loss = 0.1156, val_accuracy=0.95000
# step 361100, loss = 0.3062, val_loss = 0.0821, val_accuracy=0.99000
# step 361200, loss = 0.0779, val_loss = 0.1036, val_accuracy=0.99000
# step 361300, loss = 0.0678, val_loss = 0.1045, val_accuracy=1.00000
# step 361400, loss = 0.0076, val_loss = 0.0680, val_accuracy=0.99000
# step 361500, loss = 0.0320, val_loss = 0.1464, val_accuracy=0.99000
# step 361600, loss = 0.0516, val_loss = 0.0160, val_accuracy=1.00000
# step 361700, loss = 0.0220, val_loss = 0.4428, val_accuracy=1.00000
# step 361800, loss = 0.0139, val_loss = 0.0573, val_accuracy=0.99000
# step 361900, loss = 0.1594, val_loss = 0.6314, val_accuracy=0.98000
# step 362000, loss = 0.0937, val_loss = 0.4432, val_accuracy=0.97000
# step 362100, loss = 0.3403, val_loss = 0.3022, val_accuracy=0.97000
# step 362200, loss = 0.0157, val_loss = 0.1731, val_accuracy=0.99000
# step 362300, loss = 0.0902, val_loss = 0.3804, val_accuracy=0.97000
# step 362400, loss = 0.1178, val_loss = 0.0769, val_accuracy=0.98000
# step 362500, loss = 0.0258, val_loss = 0.5021, val_accuracy=0.97000
# step 362600, loss = 0.1794, val_loss = 0.1086, val_accuracy=0.98000
# step 362700, loss = 0.0278, val_loss = 0.1018, val_accuracy=0.98000
# step 362800, loss = 0.0405, val_loss = 0.0954, val_accuracy=0.99000
# step 362900, loss = 0.0285, val_loss = 0.0078, val_accuracy=0.98000
# step 363000, loss = 0.2393, val_loss = 0.1650, val_accuracy=0.96000
# step 363100, loss = 0.1920, val_loss = 0.2680, val_accuracy=0.98000
# step 363200, loss = 0.1024, val_loss = 0.0477, val_accuracy=0.99000
# step 363300, loss = 0.0053, val_loss = 0.4167, val_accuracy=0.99000
# step 363400, loss = 0.0193, val_loss = 0.0828, val_accuracy=0.98000
# step 363500, loss = 0.0918, val_loss = 0.2857, val_accuracy=0.98000
# step 363600, loss = 0.0680, val_loss = 0.0465, val_accuracy=0.99000
# step 363700, loss = 0.0974, val_loss = 0.2682, val_accuracy=0.98000
# step 363800, loss = 0.1001, val_loss = 0.1026, val_accuracy=0.98000
# step 363900, loss = 0.2028, val_loss = 0.1003, val_accuracy=0.96000
# step 364000, loss = 0.0173, val_loss = 0.0543, val_accuracy=0.97000
# step 364100, loss = 0.0116, val_loss = 0.0961, val_accuracy=0.98000
# step 364200, loss = 0.0393, val_loss = 0.0226, val_accuracy=0.98000
# step 364300, loss = 0.0128, val_loss = 0.0314, val_accuracy=0.99000
# step 364400, loss = 0.0681, val_loss = 0.1972, val_accuracy=0.98000
# step 364500, loss = 0.1307, val_loss = 0.0499, val_accuracy=0.97000
# step 364600, loss = 0.0621, val_loss = 0.1765, val_accuracy=0.97000
# step 364700, loss = 0.3534, val_loss = 0.1555, val_accuracy=0.95000
# step 364800, loss = 0.1594, val_loss = 0.0678, val_accuracy=0.98000
# step 364900, loss = 0.0033, val_loss = 0.0529, val_accuracy=0.98000
# step 365000, loss = 0.0131, val_loss = 0.2026, val_accuracy=0.97000
# step 365100, loss = 0.0158, val_loss = 0.0291, val_accuracy=0.97000
# step 365200, loss = 0.0045, val_loss = 0.3525, val_accuracy=0.97000
# step 365300, loss = 0.0222, val_loss = 0.3194, val_accuracy=0.97000
# step 365400, loss = 0.0023, val_loss = 0.1391, val_accuracy=0.97000
# step 365500, loss = 0.0001, val_loss = 0.3312, val_accuracy=0.97000
# step 365600, loss = 0.1454, val_loss = 0.1565, val_accuracy=0.98000
# step 365700, loss = 0.1772, val_loss = 0.0720, val_accuracy=0.99000
# step 365800, loss = 0.0952, val_loss = 0.1896, val_accuracy=0.97000
# step 365900, loss = 0.2056, val_loss = 0.2254, val_accuracy=0.97000
# step 366000, loss = 0.0187, val_loss = 0.0520, val_accuracy=0.97000
# step 366100, loss = 0.0681, val_loss = 0.7056, val_accuracy=0.96000
# step 366200, loss = 0.0106, val_loss = 0.0981, val_accuracy=0.97000
# step 366300, loss = 0.0114, val_loss = 0.1289, val_accuracy=0.98000
# step 366400, loss = 0.0474, val_loss = 0.1140, val_accuracy=0.99000
# step 366500, loss = 0.0367, val_loss = 0.1914, val_accuracy=0.99000
# step 366600, loss = 0.2011, val_loss = 0.0377, val_accuracy=0.97000
# step 366700, loss = 0.1153, val_loss = 0.0360, val_accuracy=0.98000
# step 366800, loss = 0.0615, val_loss = 0.1064, val_accuracy=0.96000
# step 366900, loss = 0.0707, val_loss = 0.1590, val_accuracy=0.97000
# step 367000, loss = 0.2076, val_loss = 0.3152, val_accuracy=0.98000
# step 367100, loss = 0.0712, val_loss = 0.0231, val_accuracy=0.96000
# step 367200, loss = 0.0591, val_loss = 0.0677, val_accuracy=0.98000
# step 367300, loss = 0.0808, val_loss = 0.2405, val_accuracy=0.99000
# step 367400, loss = 0.0681, val_loss = 0.0496, val_accuracy=0.99000
# step 367500, loss = 0.0529, val_loss = 0.1466, val_accuracy=0.98000
# step 367600, loss = 0.0552, val_loss = 0.1218, val_accuracy=0.99000
# step 367700, loss = 0.1189, val_loss = 0.1231, val_accuracy=0.98000
# step 367800, loss = 0.0678, val_loss = 0.0003, val_accuracy=0.98000
# step 367900, loss = 0.0232, val_loss = 0.2632, val_accuracy=0.99000
# step 368000, loss = 0.2276, val_loss = 0.3034, val_accuracy=0.98000
# step 368100, loss = 0.0527, val_loss = 0.1646, val_accuracy=0.96000
# step 368200, loss = 0.1620, val_loss = 0.1555, val_accuracy=0.96000
# step 368300, loss = 0.0506, val_loss = 0.0544, val_accuracy=0.97000
# step 368400, loss = 0.1647, val_loss = 0.2481, val_accuracy=0.96000
# step 368500, loss = 0.0561, val_loss = 0.1950, val_accuracy=0.98000
# step 368600, loss = 0.1863, val_loss = 0.1550, val_accuracy=0.96000
# step 368700, loss = 0.0641, val_loss = 0.1872, val_accuracy=0.98000
# step 368800, loss = 0.1380, val_loss = 0.2365, val_accuracy=0.98000
# step 368900, loss = 0.0394, val_loss = 0.0662, val_accuracy=0.98000
# step 369000, loss = 0.0293, val_loss = 0.1508, val_accuracy=0.98000
# step 369100, loss = 0.0639, val_loss = 0.0684, val_accuracy=0.98000
# step 369200, loss = 0.2695, val_loss = 0.2921, val_accuracy=0.95000
# step 369300, loss = 0.1428, val_loss = 0.0999, val_accuracy=0.99000
# step 369400, loss = 0.0848, val_loss = 0.0182, val_accuracy=0.98000
# step 369500, loss = 0.0672, val_loss = 0.0048, val_accuracy=0.97000
# step 369600, loss = 0.0261, val_loss = 0.0647, val_accuracy=0.97000
# step 369700, loss = 0.0521, val_loss = 0.0734, val_accuracy=0.98000
# step 369800, loss = 0.0157, val_loss = 0.1244, val_accuracy=0.99000
# step 369900, loss = 0.1799, val_loss = 0.0425, val_accuracy=0.98000
# step 370000, loss = 0.0115, val_loss = 0.0348, val_accuracy=0.98000
# step 370100, loss = 0.0506, val_loss = 0.0304, val_accuracy=0.99000
# step 370200, loss = 0.4462, val_loss = 0.1338, val_accuracy=0.98000
# step 370300, loss = 0.0432, val_loss = 0.0344, val_accuracy=0.98000
# step 370400, loss = 0.0151, val_loss = 0.2029, val_accuracy=0.99000
# step 370500, loss = 0.0264, val_loss = 0.1232, val_accuracy=0.98000
# step 370600, loss = 0.0678, val_loss = 0.1931, val_accuracy=0.99000
# step 370700, loss = 0.0618, val_loss = 0.1278, val_accuracy=0.99000
# step 370800, loss = 0.0372, val_loss = 0.0640, val_accuracy=0.99000
# step 370900, loss = 0.0077, val_loss = 0.3531, val_accuracy=0.98000
# step 371000, loss = 0.0759, val_loss = 0.0823, val_accuracy=0.99000
# step 371100, loss = 0.1405, val_loss = 0.2194, val_accuracy=1.00000
# step 371200, loss = 0.0159, val_loss = 0.0481, val_accuracy=0.99000
# step 371300, loss = 0.0363, val_loss = 0.2464, val_accuracy=0.97000
# step 371400, loss = 0.1505, val_loss = 0.0692, val_accuracy=0.99000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 33
#      31 for step in range(steps):
#      32   idx = train_indices[step % len(x_train)]
# ---> 33   cnn_params, opt_state, loss = train_step(cnn_params, x_train[idx], y_train[idx], opt_state)
#      34   test_idx = test_indices[step % len(x_test)]
#      35   val_loss = get_loss(cnn_params, x_test[test_idx], y_test[test_idx])
#
# File ~/Desktop/ai_gym/.venv/lib/python3.10/site-packages/jax/_src/array.py:370, in ArrayImpl.__getitem__(self, idx)
#     365       out = lax.squeeze(out, dimensions=dims)
#     367     return ArrayImpl(
#     368         out.aval, sharding, [out], committed=False, _skip_checks=True)
# --> 370 return lax_numpy._rewriting_take(self, idx)
#
# File ~/Desktop/ai_gym/.venv/lib/python3.10/site-packages/jax/_src/numpy/lax_numpy.py:11396, in _rewriting_take(arr, idx, indices_are_sorted, unique_indices, mode, fill_value)
#   11387 def _rewriting_take(arr, idx, indices_are_sorted=False, unique_indices=False,
#   11388                     mode=None, fill_value=None):
#   11389   # Computes arr[idx].
#    (...)
#   11393   # For simplicity of generated primitives, we call lax.dynamic_slice in the
#   11394   # simplest cases: i.e. non-dynamic arrays indexed with integers and slices.
# > 11396   if (result := _attempt_rewriting_take_via_slice(arr, idx, mode)) is not None:
#   11397     return result
#   11399   # TODO(mattjj,dougalm): expand dynamic shape indexing support
#
# File ~/Desktop/ai_gym/.venv/lib/python3.10/site-packages/jax/_src/numpy/lax_numpy.py:11380, in _attempt_rewriting_take_via_slice(arr, idx, mode)
#   11378   if len(start_indices) > 1:
#   11379     start_indices = util.promote_dtypes(*start_indices)
# > 11380   arr = lax.dynamic_slice(
#   11381       arr, start_indices=start_indices, slice_sizes=slice_sizes)
#   11382 if int_indices:
#   11383   arr = lax.squeeze(arr, tuple(int_indices))
#
# File ~/Desktop/ai_gym/.venv/lib/python3.10/site-packages/jax/_src/lax/slicing.py:160, in dynamic_slice(operand, start_indices, slice_sizes)
#     112 def dynamic_slice(
#     113     operand: Array | np.ndarray,
#     114     start_indices: Array | np.ndarray | Sequence[ArrayLike],
#     115     slice_sizes: Shape,
#     116 ) -> Array:
#     117   """Wraps XLA's `DynamicSlice
#     118   <https://www.tensorflow.org/xla/operation_semantics#dynamicslice>`_
#     119   operator.
#    (...)
#     158     - :func:`jax.lax.dynamic_index_in_dim`
#     159   """
# --> 160   start_indices = _dynamic_slice_indices(operand, start_indices)
#     161   if config.dynamic_shapes.value:
#     162     dynamic_sizes, static_sizes = lax._extract_tracers_dyn_shape(slice_sizes)
#
# File ~/Desktop/ai_gym/.venv/lib/python3.10/site-packages/jax/_src/lax/slicing.py:3000, in _dynamic_slice_indices(operand, start_indices)
#    2998     continue
#    2999   d_arr = lax.convert_element_type(d, _dtype(i))
# -> 3000   result.append(lax.select(i < 0, i + d_arr, i))
#    3001 return result
#
# File ~/Desktop/ai_gym/.venv/lib/python3.10/site-packages/jax/_src/numpy/array_methods.py:569, in _defer_to_unrecognized_arg.<locals>.deferring_binary_op(self, other)
#     568 def deferring_binary_op(self, other):
# --> 569   if hasattr(other, '__jax_array__'):
#     570     other = other.__jax_array__()
#     571   args = (other, self) if swap else (self, other)
#
# KeyboardInterrupt:

# %%
import pygame
import numpy as np
import jax.numpy as jnp
import scipy.ndimage


def apply_brush(grid, x, y, intensity=40, radius=2):
    """
    Applies a Gaussian-like brush stroke to the grid.
    Args:
        grid: The drawing grid (28x28 numpy array).
        x, y: The coordinates of the center of the brush.
        intensity: The max intensity to add.
        radius: The size of the brush.
    """
    for dx in range(-radius, radius + 1):
        for dy in range(-radius, radius + 1):
            nx, ny = x + dx, y + dy
            if 0 <= nx < grid.shape[1] and 0 <= ny < grid.shape[0]:
                distance = (dx ** 2 + dy ** 2) ** 0.5
                weight = max(0, 1 - distance / radius)  # Linear fall-off
                grid[ny, nx] = min(255, int(grid[ny, nx]) + int(intensity * weight))

# Initialize Pygame
pygame.init()

# Grid settings
grid_size = 28
square_size = 20  # Each square is 20x20 pixels, making a 560x560 window
screen_size = grid_size * square_size

# Create the drawing grid (28x28)
drawing_grid = np.zeros((grid_size, grid_size), dtype=np.uint8)

# Initialize Pygame screen
screen = pygame.display.set_mode((screen_size, screen_size))
pygame.display.set_caption("Drawing")  # Default status

# Colors
black = (0, 0, 0)

# Function to draw the grid on the screen
def draw_grid():
    for x in range(grid_size):
        for y in range(grid_size):
            intensity = drawing_grid[y][x]
            color = (intensity, intensity, intensity)  # Grayscale color based on intensity
            pygame.draw.rect(
                screen,
                color,
                (x * square_size, y * square_size, square_size, square_size)
            )

# Main loop
running = True
drawing = False

while running:
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False

        elif event.type == pygame.MOUSEBUTTONDOWN:
            drawing = True
            pygame.display.set_caption("Drawing")  # Set title to indicate drawing

        elif event.type == pygame.MOUSEBUTTONUP:
            drawing = False

        elif event.type == pygame.KEYDOWN:
            if event.key == pygame.K_c:  # Clear the grid
                drawing_grid = np.zeros((grid_size, grid_size), dtype=np.uint8)
                screen.fill(black)
                pygame.display.set_caption("Cleared")  # Update title
                pygame.display.flip()

            elif event.key == pygame.K_p:  # Predict
                # Pass the 28x28 numpy array to the CNN
                img = drawing_grid
                img_jax = jnp.expand_dims(jnp.expand_dims(jnp.array(img, dtype=jnp.float32), axis=0), axis=0)  # Shape: (1, 1, 28, 28)
                prediction = cnn_forward(cnn_params, img_jax[0])  # Forward pass with your JAX CNN
                predicted_digit = int(jnp.argmax(prediction))
                pygame.display.set_caption(f"Predicted Digit: {predicted_digit}")  # Update title with prediction

            elif event.key == pygame.K_l:  # Load a random image from x_train
                random_index = np.random.randint(0, len(x_test))
                drawing_grid = (np.array(x_test[random_index][0]) * 255).astype(np.uint8)  # Ensure NumPy and scale to [0, 255]
                screen.fill(black)
                pygame.display.set_caption("Loaded Example")  # Update title
                pygame.display.flip()

    # Handle drawing
    if drawing:
        mouse_x, mouse_y = pygame.mouse.get_pos()
        grid_x = mouse_x // square_size
        grid_y = mouse_y // square_size
        if 0 <= grid_x < grid_size and 0 <= grid_y < grid_size:
            apply_brush(drawing_grid, grid_x, grid_y, intensity=80, radius=2)

    # Update the screen
    draw_grid()
    pygame.display.flip()

pygame.quit()
