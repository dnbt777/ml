# %%
# an experiment in high and low pass filters for grads
# result: meh :/

import jax
import jax.numpy as jnp
import jax.random as jrand
import numpy as np
import optax
import functools # for partial
from functools import reduce
import time
from typing import List, NamedTuple

ipynb = True
dataset_name = "dictionary"
debug = False


if debug:
  jax.config.update("jax_disable_jit", True)


## LOAD DATA ##
from transformer_utils import load_dataset



prefix = ""
if ipynb == True:
  prefix = "../../"

token_type = 'bpe' # wordlevel bpe charlevel
tokenizer_vocab_size = 120
if dataset_name == "shakespeare":
  dataset_path = prefix + "data/shakespeare.txt"
  vocab, train_data, test_data, encode, decode = load_dataset(dataset_path, split=0.9, vocab_size=tokenizer_vocab_size, prefix=prefix)
if dataset_name == "dnbt":
  dataset_path = prefix + "data/dnbt_posts.txt"
  vocab, train_data, test_data, encode, decode = load_dataset(dataset_path, split=0.9, vocab_size=tokenizer_vocab_size, prefix=prefix)
if dataset_name == "dictionary":
  dataset_path = prefix + "data/dictionary.txt"
  vocab, train_data, test_data, encode, decode = load_dataset(dataset_path, split=0.9, vocab_size=tokenizer_vocab_size, prefix=prefix)
if dataset_name == "wikipedia":
  dataset_path = prefix + "data/dnbt_posts.txt"
  vocab, train_data, test_data, encode, decode = load_dataset(dataset_path, split=0.9, vocab_size=tokenizer_vocab_size, prefix=prefix)
if dataset_name == "tinystories":
  print("preparing dataset...")
  dataset_path = prefix + "data/tinystories_combined.txt" # concatenate test and val, and split ourselves. should be roughly the same at 0.9
  vocab, train_data, test_data, encode, decode = load_dataset(dataset_path, split=0.9, vocab_size=tokenizer_vocab_size, prefix=prefix)
  print("Done")

vocab_size = len(vocab)



## SET UP PARAM STRUCTS ##
# https://github.com/xjdr-alt/simple_transformer/blob/main/simple_transformer.py
class BlockParams(NamedTuple):
  w_q : jax.Array
  w_k : jax.Array
  w_v : jax.Array
  w_o : jax.Array
  w1 : jax.Array
  w2 : jax.Array
  w3 : jax.Array
  attn_norm_w : jax.Array
  attn_norm_b : jax.Array
  ffnorm_w : jax.Array
  ffnorm_b : jax.Array


class ModelParams(NamedTuple):
  blocks : List[BlockParams]
  embedding_projection : jax.Array
  to_logits_w : jax.Array # after entire network
  positional_embeddings : jax.Array
  output_norm_w : jax.Array
  output_norm_b : jax.Array


def init_model_params(blocks, model_dim, d_k, qkv_dim, ff_hidden_size, vocab_size, block_size):
  D = d_k
  K = qkv_dim
  attention_heads = model_dim // d_k
  H = attention_heads
  DH = attention_heads * d_k
  scale = lambda s1, s2: 1 / jnp.sqrt(s1 + s2)
  xavier_blocks = lambda n, m: np.random.uniform(size=(blocks, n, m)) * scale(n, m)
  xavier_multihead_blocks = lambda n, m: np.random.uniform(size=(blocks, H, n, m))
  xavier = lambda n, m: np.random.uniform(size=(n, m)) * scale(n, m)
  
  block_params = BlockParams(
    # multi head attention
    # C => D, H
    w_q=xavier_multihead_blocks(D, K),
    w_k=xavier_multihead_blocks(D, K),
    w_v=xavier_multihead_blocks(D, K),
    w_o=xavier_multihead_blocks(K, D),

    w1=xavier_blocks(model_dim, ff_hidden_size),
    w2=xavier_blocks(model_dim, ff_hidden_size),
    w3=xavier_blocks(ff_hidden_size, model_dim),
    # norm stuff
    attn_norm_w=xavier_blocks(1, model_dim), # B, T, C (x) B, 1, C
    attn_norm_b=jnp.zeros(shape=(blocks, model_dim,)),
    ffnorm_w=xavier_blocks(1, model_dim),
    ffnorm_b=jnp.zeros(shape=(blocks, model_dim,)),
  )

  model_params = ModelParams(
    blocks=block_params,
    embedding_projection=xavier(vocab_size, model_dim),
    to_logits_w=xavier(model_dim, vocab_size),
    positional_embeddings=xavier(block_size, model_dim), # bias: T, C
    output_norm_w=xavier(1, model_dim),
    output_norm_b=jnp.zeros(shape=(model_dim,)),
  )

  return model_params


@functools.partial(jax.jit, static_argnames=["dropout_rate"])
def attention(block_params : BlockParams, xBTC, dropout_key, dropout_rate=0.0):
  # xBTC -> xBTHD via reshape | H = head, D = dim (like channel, but split into H segments)
  B, T, C = xBTC.shape
  H = block_params.w_q.shape[0] # attention head
  D = block_params.w_q.shape[1] # model dim after split into heads
  K = block_params.w_q.shape[2] # query dim
  BTHD = (B, T, H, D)
  xBTHD = jnp.reshape(xBTC, shape=BTHD)
  # xBTHD -> xBHTD via transpose or axes swap
  xBHTD = jnp.swapaxes(xBTHD, 1, 2)
  # xBHTD @ (Wq, Wk, Wv) => (Q, K, V)   | (B, H, T, D) @ (D, K) => (B, H, T, K) | K = query/key size. also V size here, but does not have to be.
  Q = jnp.einsum("BHTD,HDK->BHTK", xBHTD, block_params.w_q) # (B, H, T, D) @ (H, D, K) => (B, H, T, K)
  K = jnp.einsum("BHTD,HDK->BHTK", xBHTD, block_params.w_k)
  V = jnp.einsum("BHTD,HDK->BHTK", xBHTD, block_params.w_v)
  # Q @ K_transpose => QK               | (B, H, T, K) @ (B, H, K, T) => (B, H, T, T) | this may be the wrong transpose
  QK = Q @ jnp.swapaxes(K, 2, 3)
  # scale, mask, and softmax
  mask = jnp.triu(jnp.ones_like(QK), k=1) #  mask=1 where jnp.-inf will be. k=1 preseves the middle diagonal for self attention
  attention_scores = jnp.where(mask, -jnp.inf, QK/jnp.sqrt(d_k))
  # QK @ V => Z                         | (B, H, T, T) @ (B, H, T, K) => (B, H, T, K)
  Z = jax.nn.softmax(attention_scores, axis=-1) @ V # softmax in the T and K dims, for each B and H
  # Z swap axes                         | (B, H, T, K) => (B, T, H, K)
  Z = dropout(dropout_key, Z, dropout_rate)
  Z = jnp.swapaxes(Z, 1, 2)
  # Z @ w_out       | project to BTHD   | (B, T, H, K) @ (H, K, D) => (B, T, H, D)
  xBTHD = jnp.einsum("BTHK,HKD->BTHD", Z, block_params.w_o)
  # reshape to BTC                      | (B, T, H, D) => (B, T, C)
  xBTC = jnp.reshape(xBTHD, (B, T, C))
  # return xBTC_out
  xBTC = dropout(dropout_key, xBTC, dropout_rate)
  return xBTC



@functools.partial(jax.jit, static_argnames=["dropout_rate"])
def forward(dropout_key, model_params : ModelParams, xBT, vocab_size=vocab_size, dropout_rate=0.0):
  dropout_keys = jrand.split(dropout_key, 4)
  # get embeddings via projection from token onehot to channel space
  # xBT -> xBTC
  xBTOH = jax.nn.one_hot(xBT, num_classes=vocab_size, axis=-1)
  xBTC = xBTOH @ model_params.embedding_projection
  # add learned positional embeddings. broadcast over B
  B, T, C = xBTC.shape
  xBTC = xBTC + model_params.positional_embeddings[None, :T, :] # B, T, C + 1, T, C
  # scan through transformer blocks, updating xBTC
  # block
  #   attention
  #   forward projection from Z space to channel space
  # scan_fn :: (c, a) -> (c, b)
  def ffw(block_params, xBTC):
    #return jax.nn.silu(xBTC @ block_params.w1) * ((xBTC @ block_params.w2 + block_params.b2) @ block_params.w3 + block_params.b3)
    return (jax.nn.silu(xBTC @ block_params.w1) * (xBTC @ block_params.w2)) @ block_params.w3
  
  def scan_fn(xBTC, block_params):
    xBTC = xBTC + attention(block_params, layer_norm(xBTC, block_params.attn_norm_w, block_params.attn_norm_b), dropout_keys[0], dropout_rate)
    xBTC = xBTC + dropout(dropout_keys[1], ffw(block_params, layer_norm(xBTC, block_params.ffnorm_w, block_params.ffnorm_b)), dropout_rate)
    return xBTC, None # c, b
  # ((c, a) -> (c, b)) -> c -> [a] -> (c, [b]) where b is None
  xBTC = jax.lax.scan(scan_fn, xBTC, model_params.blocks)[0] # (xBTC, None) from the scan
  # then project the embeddings to logit space
  #xBTC = layer_norm(xBTC, model_params.output_norm_w, model_params.output_norm_b)
  # logits = xBTC @ model_params.to_logits_w + model_params.to_logits_b
  logits = xBTC @ model_params.to_logits_w
  return dropout(key, logits, dropout_rate)


@functools.partial(jax.jit, static_argnames=["dropout_rate"])
def model_loss(dropout_key, model_params : ModelParams, xBT, yBT, dropout_rate):
  # -sum(q*log(p))
  # dont use one hot?
  logits = forward(dropout_key, model_params, xBT, dropout_rate=dropout_rate)
  vocab_size = logits.shape[-1]
  labels = jax.nn.one_hot(yBT, num_classes=vocab_size, axis=-1)
  losses = -jnp.sum(labels * jax.nn.log_softmax(logits, axis=-1), axis=-1)
  mean_loss = jnp.mean(losses)
  return mean_loss


@functools.partial(jax.jit, static_argnames=["dropout_rate", "label_smoothing_epsilon"])
def smoothed_model_loss(dropout_key, model_params : ModelParams, xBT, yBT, dropout_rate, label_smoothing_epsilon):
  # -sum(q*log(p))
  # dont use one hot?
  logits = forward(dropout_key, model_params, xBT, dropout_rate=dropout_rate)
  vocab_size = logits.shape[-1]
  labels = jax.nn.one_hot(yBT, num_classes=vocab_size, axis=-1) * (1 - label_smoothing_epsilon) + label_smoothing_epsilon/vocab_size
  losses = -jnp.sum(labels * jax.nn.log_softmax(logits, axis=-1), axis=-1)
  mean_loss = jnp.mean(losses)
  return mean_loss


# for validation only
@jax.jit
def model_loss_and_accuracy(model_params : ModelParams, xBT, yBT):
  # -sum(q*log(p))
  # dont use one hot?
  dropout_key = jrand.PRNGKey(0) # not used, but needed
  logits = forward(dropout_key, model_params, xBT) # no key, no dropout
  vocab_size = logits.shape[-1]
  labels = jax.nn.one_hot(yBT, num_classes=vocab_size, axis=-1)
  losses = -jnp.sum(labels * jax.nn.log_softmax(logits, axis=-1), axis=-1) # no label smoothing
  mean_loss = jnp.mean(losses)
  mean_accuracy = jnp.mean(yBT == jnp.argmax(logits, axis=-1))
  return mean_loss, mean_accuracy


@functools.partial(jax.jit, static_argnames=['optimizer', "dropout_rate", "label_smoothing_epsilon"])
def train_step(dropout_key,
               model_params:ModelParams,
               xBT, yBT,
               opt_state, optimizer,
               dropout_rate, label_smoothing_epsilon):
  # jax value and grad
  loss, grads = jax.value_and_grad(smoothed_model_loss, argnums=1)(
    dropout_key, model_params, xBT, yBT, dropout_rate, label_smoothing_epsilon)
  # update optimizer
  updates, opt_state = optimizer.update(grads, opt_state, model_params)
  # update params
  model_params = optax.apply_updates(updates, model_params)
  # return opt state, loss, and new params
  return model_params, opt_state, loss, grads


@functools.partial(jax.jit, static_argnames=['optimizer', "dropout_rate", "label_smoothing_epsilon", "grad_filter"])
def train_step_grad_filter(dropout_key,
               model_params:ModelParams,
               xBT, yBT,
               opt_state, optimizer,
               dropout_rate, label_smoothing_epsilon,
               grad_filter):
  # jax value and grad
  loss, grads = jax.value_and_grad(smoothed_model_loss, argnums=1)(
    dropout_key, model_params, xBT, yBT, dropout_rate, label_smoothing_epsilon)
  
  # high or low pass filtering
  if grad_filter == "high":
    leaves, _ = jax.tree_util.tree_flatten(grads)
    flat_tree = jnp.concatenate([jnp.ravel(leaf) for leaf in leaves])
    threshold = jnp.abs(jnp.percentile(flat_tree, 90)) # 90th percentile
    grads = jax.tree_util.tree_map(lambda x: jnp.where(jnp.abs(x) > threshold, 0, x), grads) # mask-out updates to neurons that underfired
  if grad_filter == "low":
    leaves, _ = jax.tree_util.tree_flatten(grads)
    flat_tree = jnp.concatenate([jnp.ravel(leaf) for leaf in leaves])
    threshold = jnp.abs(jnp.percentile(flat_tree, 10)) # 10th percentile
    grads = jax.tree_util.tree_map(lambda x: jnp.where(jnp.abs(x) < threshold, 0, x), grads) # mask-out updates to neurons that overfired
  if grad_filter == "none":
    # do nothing
    leaves, _ = jax.tree_util.tree_flatten(grads)
    flat_tree = jnp.concatenate([jnp.ravel(leaf) for leaf in leaves])
    threshold = jnp.abs(jnp.percentile(flat_tree, 0)) # 0th percentile
    grads = jax.tree_util.tree_map(lambda x: jnp.where(jnp.abs(x) > threshold, 0, x), grads) # mask-out updates to neurons that overfired
  # update optimizer
  updates, opt_state = optimizer.update(grads, opt_state, model_params)
  # update params
  model_params = optax.apply_updates(updates, model_params)
  # return opt state, loss, and new params
  return model_params, opt_state, loss, grads


@jax.jit
def inference(model_params : ModelParams, xBT, temp=0.5):
  dropout_key = jrand.PRNGKey(0) # not used
  logits = forward(dropout_key, model_params, xBT, dropout_rate=0.0)[0, :, :] # the first Batch
  probs = jax.nn.softmax(logits / temp, axis=-1)
  get_token = lambda channel: jrand.choice(jrand.PRNGKey(int(1000*time.time())), channel.shape[-1], p=channel)
  ts = jax.vmap(get_token, in_axes=0, out_axes=0)(probs) # just take the first T in the first batch ig
  return ts


@functools.partial(jax.jit, static_argnames=["dropout_rate"])
def dropout(dropout_key, tensor, dropout_rate):
  if dropout_rate == 0:
    return tensor
  # generate dropout_mask = rand(x) < dropout_rate of size tensor.shape
  dropout_mask = jrand.uniform(dropout_key, tensor.shape, tensor.dtype) <= dropout_rate
  return jnp.where(dropout_mask, 0, tensor) * (1 / (1 - dropout_rate))


@jax.jit
def layer_norm(BTC, w, b):
  # norm over TxC
  epsilon = 1e-7
  mean = jnp.mean(BTC, axis=(1, 2), keepdims=True)
  variance = jnp.var(BTC, axis=(1, 2), keepdims=True)
  normalized = (BTC - mean) / jnp.sqrt(variance + epsilon)
  return normalized * w + b


@jax.jit
def channel_norm(BTC, w, b):
  # norm over C
  epsilon = 1e-7
  mean = jnp.mean(BTC, axis=-1, keepdims=True)
  variance = jnp.var(BTC, axis=-1, keepdims=True)
  normalized = (BTC - mean) / jnp.sqrt(variance + epsilon)
  return normalized * w + b


## TRAIN
# model params
# model params
transformer_blocks = 6
attention_heads = 8

model_dim = 512
qkv_dim = 64
ff_hidden_size = 2048 # 2048
block_size = 64 # xlen


# paper lr stuff
warmup_steps = 4000
get_lr = lambda step_num: (model_dim**-0.5) * min(step_num ** -0.5, step_num * warmup_steps**(-1.5))
initial_lr = get_lr(1)
label_smoothing_epsilon = 0.1
dropout_rate = 0.1

# adam
beta1 = 0.9
beta2 = 0.98
eps = 1e-9


# set up training
epochs = 10000
max_shifts = 1000000000000000000
train_batch_size = 64
test_batch_size = 16
print_every = 100
stop_if_above = 1.5 # 150% of min val loss


continue_training = False
start_ep = 100
start_step = 17600

d_k = model_dim // attention_heads

# experiment
grad_filter = "high" # high low none



if not continue_training:
  model_params = init_model_params(transformer_blocks, model_dim, d_k, qkv_dim, ff_hidden_size, vocab_size, block_size) # t blocks is hardcoded to 1 atm
  optimizer = optax.inject_hyperparams(optax.adam)(learning_rate=initial_lr, b1=beta1, b2=beta2, eps=eps)
  opt_state = optimizer.init(model_params)
  print("model params initialized.\nstarting training")






loss_tracker = []
global_step = 1
min_val_loss = 10000 # init min val loss as extremely high
stop_training = False # flag to stop training
for epoch in range(epochs):
  if stop_training:
    break
  if continue_training and epoch < start_ep:
    continue
  tokens_per_shift = (block_size + 1)*train_batch_size
  test_tokens_per_shift = (block_size + 1)*test_batch_size
  shifts = len(train_data) - tokens_per_shift
  test_shifts = len(test_data) - test_tokens_per_shift

  local_step = 1
  losses = []

  for shift in range(0, min(shifts, max_shifts), tokens_per_shift):
    global_step += 1
    local_step += 1
    if continue_training and global_step < start_step:
      continue
    steps_start = time.time()

    # update LR
    opt_state.hyperparams['learning_rate'] = get_lr(global_step)

    # gather data and train
    train_tokens = train_data[shift:shift + tokens_per_shift].reshape(-1, block_size + 1) # (B, T) where T = block_size
    xBT = train_tokens[:, :block_size] # get up to prompt_length
    yBT = train_tokens[:, 1:block_size+1] # get the one after prompt_length
    key = jrand.PRNGKey(epoch*shifts + shift)
    model_params, opt_state, loss, grads = train_step_grad_filter(key,
                                                                  model_params, xBT, yBT,
                                                                  opt_state, optimizer,
                                                                  dropout_rate, label_smoothing_epsilon,
                                                                  grad_filter)

    # tracking
    losses.append(loss)
    loss_tracker.append(("train", epoch, global_step, float(loss)))
    if global_step % print_every == 0 or global_step == 0:
      # validation
      test_shift = shift % test_shifts
      test_tokens = test_data[test_shift:test_shift + test_tokens_per_shift].reshape(-1, block_size + 1)
      test_xBT = test_tokens[:, :block_size]
      test_yBT = test_tokens[:, 1:block_size+1]
      test_loss, test_accuracy = model_loss_and_accuracy(model_params, test_xBT, test_yBT)
      loss_tracker.append(("test", epoch, global_step, float(test_loss)))
      
      # tracking
      yhats = inference(model_params, xBT, temp=0.5)
      in_chars = decode(test_xBT[0]).replace('\n', '↵')
      target_char = decode(test_yBT[0]).replace('\n', '↵')
      pred_char = decode(yhats).replace('\n', '↵')
      mean_step_loss = jnp.mean(jnp.array(losses))
      steps_stop = time.time()
      steps_per_second = local_step / (steps_stop - steps_start)
      samples_per_second = steps_per_second
      lr = opt_state.hyperparams['learning_rate'] 
      print(f"e/s={epoch}/{global_step} samples/s={samples_per_second:0.0f} {lr=:0.5f} tloss={mean_step_loss:0.3f} vloss/acc={test_loss:0.3f}/{100*test_accuracy:0.1f}% "
            f"|| val \n'...{target_char}' =?> \n'...{pred_char}'")
      losses = []
      local_step = 0

      # stopping
      #if test_loss > stop_if_above * min_val_loss:
      #  stop_training = True
      #  break
      #else:
      #  min_val_loss = min(test_loss, min_val_loss)
# Out:
# Loading BPE vocab and data from ../../data/preprocesseddictionary_vocab_120.bpe...
# Sample Input: rt in which various materials are fixed to a backing. [frenc
# Tokenized: [96, 106, 87, 110, 87, 76, 49, 81, 25, 49, 87, 88, 40, 96, 81, 45, 19, 58, 87, 108, 117, 114, 81, 40, 37, 58, 112, 96, 111, 79, 81, 68, 39, 28, 115, 45, 112, 87, 67, 40, 25, 12, 110, 54, 109, 20, 79, 96, 118, 25]
# Decoded: rt in which various materials are fixed to a backing. [frenc
# /home/dan/Desktop/ai_gym/.venv/lib/python3.10/site-packages/optax/schedules/_inject.py:34: UserWarning: Explicitly requested dtype float64 requested in asarray is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/jax-ml/jax#current-gotchas for more.
#   return jnp.asarray(x, dtype=dtype)
# model params initialized.
# starting training
# e/s=0/100 samples/s=62 lr=0.00002 tloss=181.277 vloss/acc=93.471/0.5% || val
# '...[from *top1]↵↵Topsail  n. Square sail next above the lowest; fore-and-a' =?>
# '...lôt↵↵!1;;++rxrñrFenrEñenFOFenEenenenstsstGsOstentmxEsenGentenGtsensenen.GUEFE'
# e/s=0/200 samples/s=194 lr=0.00003 tloss=177.061 vloss/acc=98.207/0.3% || val
# '...ements wholly into the body and blood of christ. [medieval latin: related' =?>
# '...UœxUxUEUME88E88EE8M8888E8xEE8EEE8EEEEEEEEEEEEE8EEEE88EEE88E8EE8E'
# e/s=0/300 samples/s=187 lr=0.00005 tloss=181.587 vloss/acc=95.301/0.5% || val
# '... (is not truly depicted). 5 properly (well and truly). [old english: re' =?>
# '...f´´HHHf´´´´atmatfmatffatatatatfatfatatfmatatatatatmmatatmmSatmfmmmatHmmmmmmmmmmmmmm'
# e/s=0/400 samples/s=232 lr=0.00007 tloss=179.037 vloss/acc=95.704/1.1% || val
# '... -sing) (often foll. By over) treat despotically or cruelly. [french: rel' =?>
# '...fNNatm;MsM;;;;EEEEEEEEEEEEEEEEEEEEEEEEEE'
# e/s=0/500 samples/s=200 lr=0.00009 tloss=179.989 vloss/acc=91.349/0.9% || val
# '...j. Not filled.↵↵Unfinished  adj. Not finished; incomplete.↵↵Unfit  adj. (o' =?>
# '...)NNatat!IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIx'
# e/s=0/600 samples/s=213 lr=0.00010 tloss=177.220 vloss/acc=91.703/0.5% || val
# '... up the street). B towards the source of (a river). —adj. 1 directed upwar' =?>
# '...fffxxfEEfffEEEMEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEmEEEEE EEEEEEEEEEEE'
# e/s=0/700 samples/s=194 lr=0.00012 tloss=171.210 vloss/acc=94.469/0.7% || val
# '....  verifiable adj. Verification n. [medieval latin: related to *very]↵↵Verily ' =?>
# '...)NxxatITIImatatatatatatIImTTmTTT—mmmmTTxmTmmmTxxTmxxm—xxTTxxmxxxmTxmx—m'
# e/s=0/800 samples/s=207 lr=0.00014 tloss=167.708 vloss/acc=89.736/0.3% || val
# '...ucher  n. 1 document exchangeable for goods or services. 2 receipt. [from' =?>
# '...fôNHfNfNfNfNNNNNzNNTNTNNNNNNNNNNNNNNzNœNNj—œNNNNzNNNNñôññNNH—NN'
# e/s=1/900 samples/s=138 lr=0.00016 tloss=160.401 vloss/acc=88.820/0.4% || val
# '...lant. 4 (foll. By over) look after; take care of. —n. 1 small portable timep' =?>
# '...NNNx—ññññxññññññññññññññññññññ—ññññññññññññññññxññññññññññññññññ'
# e/s=1/1000 samples/s=197 lr=0.00017 tloss=154.772 vloss/acc=89.549/0.2% || val
# '...out, round) change direction or face another way. B cause to do this. 3 p' =?>
# '...EssmmMMMMmM;mmmmm;mmmmmâmxMmmmmTmsmmmmssmmââsm P 8ñ88888Eññ P8E'
# e/s=1/1100 samples/s=221 lr=0.00019 tloss=147.963 vloss/acc=91.640/2.1% || val
# '...the floor with colloq. Inflict a humiliating defeat on. Wipe off annul (a d' =?>
# '...fffffffffff'&'8'ff'&&Of&O&O8OO&OO88OOOOOO8OOO8OO88888[888O88O8f'
# e/s=1/1200 samples/s=231 lr=0.00021 tloss=143.602 vloss/acc=81.068/1.2% || val
# '...er from washed clothes etc.↵↵Wringing  adj. (in full wringing wet) so wet' =?>
# '...f!!  !;;8;;in;;OO;rOinOOOOO;OOOOO;;OOfffOOfOOO';Or;inO;;in[f;'
# e/s=1/1300 samples/s=238 lr=0.00023 tloss=137.268 vloss/acc=84.536/2.0% || val
# '...e  n. Sausages baked in batter.↵↵Toadstool  n. Fungus, usu. Poisonous, wi' =?>
# '...fufu´´. I´´MIMI'III´I;IOI MIIIIIddUsEUd I U    at    E  E '
# e/s=1/1400 samples/s=233 lr=0.00024 tloss=131.550 vloss/acc=80.442/1.4% || val
# '...ling. B this between nations etc. C business conducted for profit (esp. As ' =?>
# '...ffe éenVVV      E  EEE EE  orEororE EE EEEE  E  EEE     EE   E     E'
# e/s=1/1500 samples/s=197 lr=0.00026 tloss=125.245 vloss/acc=73.801/2.1% || val
# '...y out of) swindle (tricked out of his savings). 3 (foll. By into) caus' =?>
# '...fœœEdId    II IIII EEIEdEEIEEEEEIEEIEEEEdEIEIIEEEE EII EE E IE E'
# e/s=1/1600 samples/s=233 lr=0.00028 tloss=116.484 vloss/acc=62.410/3.6% || val
# '...head  n. Turban-like ornamental knot.↵↵Turmeric  n. 1 e. Indian plant of' =?>
# '...fffllffEf l fEfEEEEffEOEEfEEffEf[EffElfEEffEOEfl EE[[Eorf fEEE'
# e/s=2/1700 samples/s=78 lr=0.00030 tloss=101.056 vloss/acc=60.912/2.2% || val
# '...s  adj. Not adventurous.↵↵Unadvised  adj. 1 indiscreet; rash. 2 without ad' =?>
# '...pS↵↵kkEEe↵eP e EE   e ..  keeeee kkg. eekge.eee.eeeekeeeegegekek'
# e/s=2/1800 samples/s=206 lr=0.00031 tloss=83.166 vloss/acc=36.614/4.2% || val
# '...arriage. 3 (cause to) form a physical or chemical whole (oil will not ' =?>
# '...iqvysissssssssssssssssyssyyy,ssyysssy,sy,,ys,yyyyyyysyyyyyytysys'
# e/s=2/1900 samples/s=208 lr=0.00033 tloss=57.888 vloss/acc=30.229/5.1% || val
# '...↵↵Usaf  abbr. United states air force.↵↵Usage  n. 1 use, treatment (damaged ' =?>
# '...e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e e  e e e e e e  e e e e e '
# e/s=2/2000 samples/s=214 lr=0.00035 tloss=47.390 vloss/acc=19.907/5.5% || val
# '... wayfaring-tree]↵↵Vicar  n. Clergyman of a church of england parish wh' =?>
# '...  ,wssswssssssssssssssgsgggggsmgggmggggggggmgggggggggggggggggmgg'
# e/s=2/2100 samples/s=193 lr=0.00037 tloss=38.898 vloss/acc=14.702/7.4% || val
# '.... 4 disturb with noise. 5 evoke (an echo). —n. 1 watch beside a corpse be' =?>
# '...ae ie tooooooooooooooooo  o  o o     o               o        oo  '
# e/s=2/2200 samples/s=195 lr=0.00038 tloss=33.947 vloss/acc=12.053/7.4% || val
# '...wedded adj.) (foll. By to) obstinately attached or devoted to (a pursuit' =?>
# '...  atatatatatatatatat)ii)iiyii      ii  i ii i                i        i  '
# e/s=2/2300 samples/s=193 lr=0.00040 tloss=29.610 vloss/acc=12.359/7.6% || val
# '...ease, esp. Of children, with a series of short violent coughs followed' =?>
# '...                                                                '
# e/s=2/2400 samples/s=186 lr=0.00042 tloss=26.401 vloss/acc=10.641/9.3% || val
# '...s or experiences of a specified kind (nice work!). 7 (in comb.) Things mad' =?>
# '...f  e                                                            '
# e/s=2/2500 samples/s=192 lr=0.00044 tloss=23.897 vloss/acc=8.918/9.8% || val
# '...int. With a noun) in an exclamatory statement (you fools!). 3 (in general stat' =?>
# '...‘‘‘ññiiiiiiiiiiiiiiiioaioaoioooaooaoa     oo  o   o ioo o    oao'
# e/s=3/2600 samples/s=190 lr=0.00045 tloss=21.639 vloss/acc=7.838/9.2% || val
# '...4 (in full displacement ton) unit of measurement of a ship's weight or ' =?>
# '...↵pp. tq. . ttten en enen       s s sssssssssssssssssssssssssssssssssssen'
# e/s=3/2700 samples/s=192 lr=0.00047 tloss=19.221 vloss/acc=6.391/7.8% || val
# '...of esp. Commercial business done. B transacting of business etc. 2 (in pl.' =?>
# '...,,  ttt     eee eeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee'
# e/s=3/2800 samples/s=189 lr=0.00049 tloss=17.550 vloss/acc=6.782/7.8% || val
# '....  triumphal adj. [french from latin]↵↵Usage  triumphal, meaning ‘of or use' =?>
# '...   E  s    ss  s                                                '
# e/s=3/2900 samples/s=194 lr=0.00051 tloss=15.911 vloss/acc=6.367/7.7% || val
# '...ts]↵↵Twelfth  adj. & n. 1 next after eleventh. 2 each of twelve equal part' =?>
# '...:m                       l        uuuubuu uu)uuuuuuubuubbbubbbsb'
# e/s=3/3000 samples/s=194 lr=0.00052 tloss=14.310 vloss/acc=5.906/6.9% || val
# '...han (another seller).↵↵Undersexed  adj. Having unusually weak sexual de' =?>
# '...eraaeraaaiiiisiiiiiiibbbibiiiiiiiiiibiiiiiibibiiiiiiiiiiiiiibiibib'
# e/s=3/3100 samples/s=192 lr=0.00054 tloss=12.762 vloss/acc=5.487/7.5% || val
# '...luntary.↵↵Unsolved  adj. Not solved.↵↵Unsophisticated  adj. Artless, si' =?>
# '...f   fffffffffffffg    w w                                       '
# e/s=3/3200 samples/s=200 lr=0.00056 tloss=11.183 vloss/acc=5.109/9.2% || val
# '...ge direction, esp. (of the wind) clockwise. 2 change in course or opinion etc' =?>
# '...   ooooo i  irrrrr r                                f        f  '
# e/s=3/3300 samples/s=215 lr=0.00058 tloss=9.579 vloss/acc=5.019/7.2% || val
# '...a voce. —v. (vivas, vivaed, vivaing) = viva-voce. [abbreviation]↵↵Viva2' =?>
# '...c   wn  g h   rrrrrrrrrr         in nin                 f    f ff '
# e/s=4/3400 samples/s=140 lr=0.00059 tloss=8.284 vloss/acc=5.610/8.6% || val
# '...y and a lock. 5 archaic guardian's control.  ward off 1 parry (a blow' =?>
# '...  iaoffffffffffffffffffffffffffffffff fiff fffffifffffffffffffff'
# e/s=4/3500 samples/s=218 lr=0.00061 tloss=7.797 vloss/acc=5.123/6.9% || val
# '...family.↵↵Well-bred  adj. Having or showing good breeding or manners.↵↵Well' =?>
# '...of             s iss sgoi  os      s                f         f '
# e/s=4/3600 samples/s=220 lr=0.00063 tloss=7.222 vloss/acc=4.707/9.1% || val
# '...cricket-bats etc., usu. Growing near water. [old english]↵↵Willow-herb  n' =?>
# '...zzzzMcMMMMm(MMMeMo mm mmmtmmmmmmmmmmmmmtmmmmmmmmmmmmmmmmmmmmmmmm'
# e/s=4/3700 samples/s=217 lr=0.00065 tloss=6.850 vloss/acc=4.534/10.0% || val
# '... the dignity etc. Of (words worthy of the occasion). —n. (pl. -ies) 1 worthy' =?>
# '...       à   à    p  i p p  f       f      f f          f        f'
# e/s=4/3800 samples/s=220 lr=0.00066 tloss=6.377 vloss/acc=4.023/9.8% || val
# '...-s) chief monetary unit of poland. [polish]↵↵Zn  symb. Zinc.↵↵Zodiac  ' =?>
# '...               ii    i o i i    iiio  b h  is g       h     ifp '
# e/s=4/3900 samples/s=219 lr=0.00068 tloss=5.911 vloss/acc=3.915/9.5% || val
# '.... (-ier, -iest) apt to take offence; over-sensitive.  touchily adv. Touchines' =?>
# '...er**   s        pp  i       i       i                            '
# e/s=4/4000 samples/s=214 lr=0.00070 tloss=5.576 vloss/acc=3.736/11.1% || val
# '...handle]↵↵Treatise  n. A written work dealing formally and systematically w' =?>
# '...                    p  f                             i          '
# e/s=4/4100 samples/s=221 lr=0.00069 tloss=5.407 vloss/acc=3.894/10.4% || val
# '...eartily. Tuck into (or away) colloq. Eat (food) heartily (tucked into th' =?>
# '.... i      i   bi ssiisi  fs  f ii  i  s        s          s     s '
# e/s=5/4200 samples/s=65 lr=0.00068 tloss=5.407 vloss/acc=3.853/9.3% || val
# '...s  n. Infectious fever with a purple rash, headaches, and usu. Deliriu' =?>
# '...hr   ii i            i       i              f                   '
# e/s=5/4300 samples/s=216 lr=0.00067 tloss=5.117 vloss/acc=3.938/7.9% || val
# '...g; constant; reliable.  unfailingly adv.↵↵Unfair  adj. Not fair, just,' =?>
# '...o           hw f f    fi          o     i              i        '
# e/s=5/4400 samples/s=218 lr=0.00067 tloss=4.915 vloss/acc=3.880/12.2% || val
# '...e watch). B in or into an active condition (stirred up trouble; the hunt is up' =?>
# '...                                                    f i   w   f '
# e/s=5/4500 samples/s=216 lr=0.00066 tloss=5.009 vloss/acc=3.770/12.0% || val
# '...ancy n. [perhaps from french verdeant from viridis green]↵↵Verdict  n. 1' =?>
# '...                                                      ii   is   '
# e/s=5/4600 samples/s=218 lr=0.00065 tloss=4.749 vloss/acc=3.679/12.7% || val
# '...y a vote (vote of no confidence). 4 votes given by or for a particular gro' =?>
# '...    i                           i p   p i   i        w   i si   '
# e/s=5/4700 samples/s=218 lr=0.00064 tloss=4.668 vloss/acc=3.806/11.6% || val
# '...utline.  make waves colloq. Cause trouble. Wave aside dismiss as intrusiv' =?>
# '...     f nr  t    n    n n   É    vn—                     n       '
# e/s=5/4800 samples/s=216 lr=0.00064 tloss=4.844 vloss/acc=3.712/12.8% || val
# '...t spinning by blows of a lash.↵↵Whippoorwill  n. American nightjar. [imi' =?>
# '...oree    p        p p       p       p         p      p     p b    '
# e/s=5/4900 samples/s=217 lr=0.00063 tloss=4.865 vloss/acc=3.790/11.4% || val
# '...j. (-ier, -iest) showing esp. Verbal wit.  wittily adv. Wittiness n. [old' =?>
# '... rrp     b     s i        f      s p        s      i s     b    '
# e/s=5/5000 samples/s=219 lr=0.00062 tloss=4.570 vloss/acc=3.684/12.2% || val
# '...ertain: perhaps from dutch janke, diminutive of jan john, as a nickname' =?>
# '...        i    i                              (                p s'
# e/s=6/5100 samples/s=207 lr=0.00062 tloss=4.446 vloss/acc=3.608/11.6% || val
# '... nothing to me). F what is caused or produced (turn to stone). G what is ' =?>
# '... àr f    wf    ss  i       f i    p   p    wb      ffi      i   '
# e/s=6/5200 samples/s=218 lr=0.00061 tloss=4.569 vloss/acc=3.574/12.0% || val
# '...nner's spiked shoe.↵↵Track suit  n. Loose warm suit worn for exercising ' =?>
# '...u°°))    p                                                      '
# e/s=6/5300 samples/s=217 lr=0.00061 tloss=4.797 vloss/acc=3.666/11.2% || val
# '...ged collar round the neck. [greek, = three-horned face]↵Trichinosis  n' =?>
# '...      p                 s    bi  s     p p  s    x      p  bp   '
# e/s=6/5400 samples/s=215 lr=0.00060 tloss=4.536 vloss/acc=3.627/11.9% || val
# '.... (pl. -s) 1 large orig. American bird bred for food. 2 its flesh as food' =?>
# '... i  i ir p      s      r  f       rmr  r   r  ir r n nn    rn mr'
# e/s=6/5500 samples/s=215 lr=0.00060 tloss=4.405 vloss/acc=3.707/8.1% || val
# '...aled; obvious.↵↵Unconcern  n. Calmness; indifference; apathy.  unconcerned a' =?>
# '...     fos o  i  ii    r m        nr  n             i  ii    ii  p'
# e/s=6/5600 samples/s=220 lr=0.00059 tloss=4.281 vloss/acc=3.571/14.3% || val
# '...↵↵Unpick  v. Undo the sewing of (stitches, a garment, etc.).↵↵Unpin  v. (-' =?>
# '...             i                    t tr n p  pr t  Ét   p   rt p '
# e/s=6/5700 samples/s=216 lr=0.00059 tloss=4.283 vloss/acc=3.713/11.3% || val
# '...B not yet expired.  validity n. [latin validus strong: related to *val' =?>
# '...o .       s                  r        r      r    rrtr r  r nirr '
# e/s=6/5800 samples/s=219 lr=0.00058 tloss=4.222 vloss/acc=3.594/14.1% || val
# '...ss n. [latin vindicta vengeance: related to *vindicate]↵↵Vine  n. 1 climbing or' =?>
# '...s ris sii s s 3ss    fsr ss is    is r—.  v   s     t i. .    t  .  '
# e/s=7/5900 samples/s=138 lr=0.00058 tloss=4.240 vloss/acc=3.560/12.7% || val
# '...ply a threat, warning, etc. [germanic: related to *wake1]↵↵Waiter  n. Man w' =?>
# '.... .   .  .        oii i iif i    i   i      f( fi  i  prbib r  bi bi'
# e/s=7/6000 samples/s=217 lr=0.00057 tloss=4.146 vloss/acc=3.546/12.8% || val
# '...ang begin action; hurry. [old norse: related to *wave]↵↵Weaver  n. 1 person ' =?>
# '... aer prrvrrrrrrrrrrrrrnnr nrnrrnrnrnrrnnnrnrrnrrrnnnrnrrrnnnrnnnn'
# e/s=7/6100 samples/s=216 lr=0.00057 tloss=4.175 vloss/acc=3.557/15.4% || val
# '...iled by others. —adj. & adv. 1 by wholesale. 2 on a large scale. —v. (-ling)' =?>
# '...   wf s     pi sb    p f  bf  f   i  f      w            f pi   '
# e/s=7/6200 samples/s=219 lr=0.00056 tloss=4.185 vloss/acc=3.604/14.6% || val
# '...ion) corresponding words.  wordless adj. [old english]↵↵Word-blindness  n. = ' =?>
# '...b     sr       f    f fr   fi    fofn in f f . rm   t s. f  fn)vr '
# e/s=7/6300 samples/s=218 lr=0.00056 tloss=4.216 vloss/acc=3.631/11.7% || val
# '...f the jewish year, day of atonement. [hebrew]↵↵Yon  adj. & adv. Literary & di' =?>
# '...    i i   f     s        ii i  ↵↵ pf  p    b  .  i   rw  f    sbsi'
# e/s=7/6400 samples/s=214 lr=0.00055 tloss=4.196 vloss/acc=3.469/11.9% || val
# '...di, = hat]↵↵Topiary  —adj. Concerned with or formed by clipping shrubs, t' =?>
# '...tnv i.ii  p  f si  pfi   f  i    pi bp   ip b p   f fi.    fpi  n'
# e/s=7/6500 samples/s=215 lr=0.00055 tloss=4.187 vloss/acc=3.491/12.8% || val
# '...t has arrived). 2 ship, aircraft, etc. Used to carry soldiers, stores, ' =?>
# '...f                 p  sb  ps *     i      f  s a     fsf  f b  v '
# e/s=7/6600 samples/s=218 lr=0.00054 tloss=4.133 vloss/acc=3.557/12.2% || val
# '...els, stored under a larger bed. —v. (-ling) (foll. By to) submit obsequio' =?>
# '...n t iis   st fpttttiss  osptips  issf  i s  sry  s ssy    iti   '
# e/s=8/6700 samples/s=63 lr=0.00054 tloss=4.191 vloss/acc=3.556/14.5% || val
# '...2 contemptible person. [origin unknown]↵↵Tweak  —v. 1 pinch and twist sharpl' =?>
# '... ↵↵m↵↵roirtmtt ttttrtt  nrr↵↵yrrtntrnnytr—m ptt ntv r. rvntr ryi.  nt'
# e/s=8/6800 samples/s=219 lr=0.00054 tloss=4.127 vloss/acc=3.506/13.7% || val
# '...her. 2 subway.↵↵Underpay  v. (past and past part. -paid) pay too little t' =?>
# '...pi  .  vr iis i  i   f fs  ip  bf i    .  i     . C s f if.   f f  i'
# e/s=8/6900 samples/s=215 lr=0.00053 tloss=4.112 vloss/acc=3.440/16.8% || val
# '...rless.↵↵Unsighted  adj. 1 not sighted or seen. 2 prevented from seeing.↵↵' =?>
# '...  r fii        r  i i    fp ;         s  tssbs    piss  .   st  b'
# e/s=8/7000 samples/s=220 lr=0.00053 tloss=4.199 vloss/acc=3.602/13.3% || val
# '...ds or a pole. 2 spring over in this way. 3 (esp. As vaulted) a make in the form' =?>
# '... r  rr   io    s  .   bsr sibs   s t r     s .   r     sr    r    '
# e/s=8/7100 samples/s=218 lr=0.00052 tloss=4.288 vloss/acc=3.462/13.5% || val
# '...ta life, *amine]↵↵Vitamin b complex  n. Any of a group of vitamins oft' =?>
# '...if ii      rosif  r  p b  i s      f             p (       s frf'
# e/s=8/7200 samples/s=219 lr=0.00052 tloss=4.258 vloss/acc=3.364/15.3% || val
# '... of employees other than by redundancy.↵↵Waste  —v. (-ting) 1 use to no' =?>
# '...    m n      f     n      i n  ori  r .     nr .  . f t tn  ofiin r'
# e/s=8/7300 samples/s=218 lr=0.00052 tloss=4.183 vloss/acc=3.489/14.4% || val
# '...etc. What with colloq. Because of (usu. Several things). [old english]↵↵What' =?>
# '...  . psst  w  ps s   f f   pop(ps p p tffn r vp ir rrirprr  B pfrt'
# e/s=8/7400 samples/s=219 lr=0.00051 tloss=4.158 vloss/acc=3.478/13.3% || val
# '...(grain) free of chaff etc. By an air-current. 2 (foll. By out, away, from' =?>
# '...reryo  r    r          fi i     ii                   i   h i    '
# e/s=8/7500 samples/s=216 lr=0.00051 tloss=4.123 vloss/acc=3.422/15.9% || val
# '...o one's utmost to deal with (a task, difficulty, etc.).  wrestler n. ' =?>
# '...  sfsttfip ns p fin vpfff  fhtif ri p r  fs y (  f       2 pt tt'
# e/s=9/7600 samples/s=207 lr=0.00051 tloss=4.390 vloss/acc=3.565/13.5% || val
# '...p  —n. 1 light fast sound. 2 energy, vigour. 3  a (in full zip-fastener) ' =?>
# '...)rrrrrrrrrr↵↵      r                B   ↵↵                     ↵↵ o'
# e/s=9/7700 samples/s=219 lr=0.00050 tloss=4.128 vloss/acc=3.479/12.4% || val
# '...) Approach in excellence etc. (can't touch him for style). 9 modify (pi' =?>
# '...trnpr ei i  p  . 2 f if     frs fhi f  . v   pi g    fhp pi t   y'
# e/s=9/7800 samples/s=219 lr=0.00050 tloss=4.121 vloss/acc=3.345/16.0% || val
# '... bench in the house of commons occupied by cabinet ministers etc.↵↵Treasur' =?>
# '... y tt i    tr t  . t r    syii  .  y ↵↵ oyf. t nfnrf  (or  frotnrn.  f'
# e/s=9/7900 samples/s=216 lr=0.00050 tloss=4.235 vloss/acc=3.367/16.0% || val
# '...bular bells  n.pl. Orchestral instrument of vertically suspended bras' =?>
# '.... itt yt.  tSn pr   nv 2  f Fn n   nrr   2v . r it.  .   y  . B v  t  . '
# e/s=9/8000 samples/s=218 lr=0.00049 tloss=4.166 vloss/acc=3.468/14.3% || val
# '...se from (unburden; uncage). 4 causing to be no longer (unman). [old englis' =?>
# '...tn nttr         an  t  ip Met ttst t vt   .  r  t tt   rm  ttrt  '
# e/s=9/8100 samples/s=217 lr=0.00049 tloss=4.119 vloss/acc=3.274/19.1% || val
# '...atin unicus from unus one]↵↵Usage  in sense 1, unique cannot be qualified ' =?>
# '...nffhfiii i i i ii ii [ ii   oi   i[        i r     i     i↵↵  .   '
# e/s=9/8200 samples/s=217 lr=0.00049 tloss=4.051 vloss/acc=3.492/15.7% || val
# '.... 3 (often foll. By on, upon) advocate (an action or argument etc.) Emphatical' =?>
# '...tt psrt      i .      .  ep orsi .  sfrRafr pr fos   *  s f    s r '
# e/s=9/8300 samples/s=217 lr=0.00049 tloss=4.040 vloss/acc=3.356/14.0% || val
# '...ches, carrying a road or railway across a valley or hollow. [latin via wa' =?>
# '...    fitfrt tf ff  tfrt fftt  f rftttf rft ttrt tr  f trpShftt   '
# e/s=10/8400 samples/s=133 lr=0.00048 tloss=4.095 vloss/acc=3.293/17.4% || val
# '...doos, -dooed) affect by voodoo; bewitch. [dahomey]↵↵Voracious  adj. 1 ' =?>
# '...   fs)s  ff fsff   p sfs fi       fs pri   fs i2 b r v f hfr  w. '
# e/s=10/8500 samples/s=220 lr=0.00048 tloss=4.030 vloss/acc=3.358/14.6% || val
# '...e (a hand etc.) In this way. 2 a show a sinuous or sweeping motion as of a ' =?>
# '...i r  iyt t y n. . t vr .  frrfrrtvCv. Cf t. .  vt v. . n ftr r. rtrq tfvp'
# e/s=10/8600 samples/s=216 lr=0.00048 tloss=4.056 vloss/acc=3.421/14.3% || val
# '... a knife; whipped behind the door). 4 slang steal. 5 slang a excel. B def' =?>
# '...    fxtf r.  fispprfytvfi ifpti    h   iivvt  tE  fa t tf hf x fy'
# e/s=10/8700 samples/s=215 lr=0.00047 tloss=4.044 vloss/acc=3.383/15.0% || val
# '...o *wit]↵↵Witness  —n. 1 = *eyewitness. 2 a person giving sworn testimony. B' =?>
# '...p     w  )i   igt r  rs . 3 f  h h  v     vft  f   t i   vf    rn'
# e/s=10/8800 samples/s=215 lr=0.00047 tloss=4.067 vloss/acc=3.425/14.8% || val
# '... int. (also yah boo) expressing derision or defiance. [imitative]↵↵Yahoo ' =?>
# '...         ↵↵ i  ii    v  ohrr v  . vtnn.  t n t    r  Lf  f  ii it t'
# e/s=10/8900 samples/s=213 lr=0.00047 tloss=4.085 vloss/acc=3.453/14.0% || val
# '...izes. [french or italian]↵↵Tomboy  n. Boisterous girl who enjoys activit' =?>
# '...y   rrnr    v r V  errtvvt vvn. O v ttr  v vttyn ntt vtttt  tO rt '
# e/s=10/9000 samples/s=214 lr=0.00047 tloss=4.028 vloss/acc=3.381/14.6% || val
# '...sp. People, walking, marching, etc. 3 long walk. 4 slang derog. Promiscu' =?>
# '...su fr mr[   vrr. n  rr.   er rr. rreortrn. Ba n. r. tntrr. rr. frott. n n'
# e/s=10/9100 samples/s=213 lr=0.00046 tloss=4.017 vloss/acc=3.385/14.7% || val
# '...-legged stand for a camera etc. 2 stool, table, or utensil resting on thre' =?>
# '...   foh. fgyn t i. f rf    .  if  i  . p . . Sv. S   t.    y  r t    .    '
# e/s=11/9200 samples/s=46 lr=0.00046 tloss=4.055 vloss/acc=3.313/14.1% || val
# '...rf  —n. (pl. -s or turves) 1 a layer of grass etc. With earth and matted ' =?>
# '...     f f n puv wi ff v v°   i i f ss      f          if.     ↵↵   '
# e/s=11/9300 samples/s=215 lr=0.00046 tloss=4.069 vloss/acc=3.320/17.1% || val
# '...; austere, simple.↵↵Uncoil  v. Unwind.↵↵Uncoloured  adj. 1 having no colo' =?>
# '... stt st     httiiht . C vrrivi. —v. r iyffC( p —i  .    ht      .   i'
# e/s=11/9400 samples/s=212 lr=0.00046 tloss=3.996 vloss/acc=3.364/17.3% || val
# '...ed  adj. Not opposed.↵↵Unorganized  adj. (also -ised) not organized.↵↵Un' =?>
# '...   rv.  r rn  n  n fvrv  y r.   n     rbrrrvhrvr. Dir .  r v      b '
# e/s=11/9500 samples/s=215 lr=0.00045 tloss=4.011 vloss/acc=3.234/18.7% || val
# '...he number of hydrogen atoms it can displace or combine with. [latin valentia' =?>
# '...o   f tf     v hr      f    vr  f iSfi       vr      r   i  r O '
# e/s=11/9600 samples/s=213 lr=0.00045 tloss=4.042 vloss/acc=3.244/16.4% || val
# '...d to *villa]↵↵Villain  n. 1 wicked person. 2 chief evil character in a pla' =?>
# '...   n ninrir v rhn   nt  yr vv n  fr   tf    f        y   vt v   '
# e/s=11/9700 samples/s=215 lr=0.00045 tloss=4.075 vloss/acc=3.223/17.2% || val
# '...ss (wanton wind; wanton destruction). 3 luxuriant; unrestrained (wanton' =?>
# '.... q .   ont t nr nn nnMf nn  ni É  r  ↵↵ in   n rnn. Mrf n nn n n n '
# e/s=11/9800 samples/s=213 lr=0.00045 tloss=4.103 vloss/acc=3.385/17.1% || val
# '...better, best) 1 (usu. Predic.) In good health. 2 (predic.) A in a sati' =?>
# '...    n r       i     r   i r r i    r   o  r        i rr  rrp   i'
# e/s=11/9900 samples/s=216 lr=0.00044 tloss=4.051 vloss/acc=3.379/13.7% || val
# '... will). 4 expressing a request as a question (will you please open the wind' =?>
# '...r. ttfasthi i v fo h  a pa  ga seg   gs sS   . s     .      sJ     '
# e/s=11/10000 samples/s=217 lr=0.00044 tloss=4.058 vloss/acc=3.347/17.8% || val
# '... related to *worse]↵↵Worsted  n. 1 fine woollen yarn. 2 fabric made from thi' =?>
# '...         fi i  f f w  .  h yffff. B   it ifyvB ff. fsh x   h  B f. '
# e/s=12/10100 samples/s=168 lr=0.00044 tloss=4.093 vloss/acc=3.407/15.4% || val
# '...fermented by added bacteria. [turkish]↵↵Yogi  n. (pl. -s) devotee of yoga' =?>
# '...err tt t  nn ty  t tn t  hn  rr     n n     rin t nif hf. B   f   '
# e/s=12/10200 samples/s=213 lr=0.00044 tloss=4.071 vloss/acc=3.884/15.5% || val
# '...uch to.↵Top2  n. Toy spinning on a point when set in motion. [old english]↵↵T' =?>
# '...c↵↵s      p   php ↵↵ et  pf Bfoor [et  s f  e f s a g; sf   g h s '
# e/s=12/10300 samples/s=217 lr=0.00044 tloss=4.090 vloss/acc=3.272/15.2% || val
# '..., through the skin, lungs, or leaves; perspire.  transpiration n. (in sense 3' =?>
# '... n.       v  . F f.  f  [fpfh f p fsohn iihtF ih     f  i siff   f '
# e/s=12/10400 samples/s=215 lr=0.00043 tloss=4.101 vloss/acc=3.354/16.0% || val
# '...l flat-bladed tool for spreading mortar etc. 2 scoop for lifting small p' =?>
# '... fff fnrin v vv     n   t  fv B vn  n      t2n  n  .    v. ↵↵)n   v '
# e/s=12/10500 samples/s=213 lr=0.00043 tloss=4.165 vloss/acc=3.271/16.9% || val
# '...sort, class, or kind. 2 person, thing, or event exemplifying a class or group' =?>
# '...aaaosaospns sn i   s i ii  s                             as     '
# e/s=12/10600 samples/s=215 lr=0.00043 tloss=4.085 vloss/acc=3.309/17.1% || val
# '.... 3 unfair (unequal contest).  unequally adv.↵↵Unequaled  adj. (brit. -' =?>
# '... .        i   f f  f    f  f    f f2 i sv  i f s iss pg tip   pf '
# e/s=12/10700 samples/s=213 lr=0.00043 tloss=4.064 vloss/acc=3.247/19.3% || val
# '... wound. 2 colloq. Relax.↵↵Unwinking  adj. 1 not winking. 2 vigilant.↵↵Unwis' =?>
# '...      sb h  gs   e p  f fri r. Rt r  v vh voiv. i  fif  f.  vi . fv '
# e/s=12/10800 samples/s=216 lr=0.00043 tloss=3.983 vloss/acc=3.299/16.8% || val
# '...e. 2 (of a statement etc.) True.  veracity n. [latin verax from verus true]' =?>
# '...t  —tyv r    v rf  f   fr  Serfr     fiti  p vn ryt ftt S t   tf '
# e/s=13/10900 samples/s=109 lr=0.00042 tloss=3.983 vloss/acc=3.171/18.9% || val
# '...al display unit  n. Computing device displaying data on a screen.↵Visual' =?>
# '...   pf of ii Bffi  t  f  ↵↵ y     .  r. Be n.  f  v)s v v. f b  fssoon'
# e/s=13/11000 samples/s=215 lr=0.00042 tloss=3.932 vloss/acc=3.249/14.9% || val
# '...er for washing and cleaning.↵↵Washing-up  n. 1 process of washing dishes ' =?>
# '...    i ip    t↵↵Con  stif t(   ont  r t C v n  tCl ont.    tf  t onf tt'
# e/s=13/11100 samples/s=212 lr=0.00042 tloss=3.949 vloss/acc=3.329/15.3% || val
# '...responding to the functions of the adj.) 1 what thing or things? (what is your ' =?>
# '... t   t.  E. —h  poryp  fpi rsi ↵↵Ex   vi tfi(st        vhfyf s p vv'
# e/s=13/11200 samples/s=215 lr=0.00042 tloss=3.953 vloss/acc=3.258/16.9% || val
# '...ions for the fingers to turn it.↵↵Wing-span  n. (also wing-spread) measuremen' =?>
# '...   uehom    r n.  i  n  i 2  p   s r si f   fh    u2f i  n     p '
# e/s=13/11300 samples/s=215 lr=0.00042 tloss=3.993 vloss/acc=3.214/16.7% || val
# '...shore who tries to bring about a shipwreck for plunder or profit.↵↵Wren  n. M' =?>
# '...wf f f f  f t fif  f p w ii p     i f si  riiss Ll   gfs  . f . ↵↵L'
# e/s=13/11400 samples/s=215 lr=0.00041 tloss=3.958 vloss/acc=3.233/17.9% || val
# '...reaction with a known concentration of reagent.  titration n. [french titre ti' =?>
# '...pr  vv p hrtt  hirr  v v  gv    v h   ↵↵Oerrt  r    tr.Of vv t  r '
# e/s=13/11500 samples/s=218 lr=0.00041 tloss=3.914 vloss/acc=3.227/18.6% || val
# '...d copy of a drawing etc. 2 act of tracing.↵↵Tracing-paper  n. Translucent p' =?>
# '...      i     g   B f fs  ffrfhsi   ↵↵ est  r. f  . rvyBr r fie vvof  '
# e/s=13/11600 samples/s=217 lr=0.00041 tloss=3.909 vloss/acc=3.191/18.0% || val
# '... tribo rub]↵↵Tribulation  n. Great affliction. [latin tribulum threshing-sledg' =?>
# '...     fw       ) f p     pnv w     fniS fif foi fn     tSo     oi'
# e/s=14/11700 samples/s=43 lr=0.00041 tloss=3.913 vloss/acc=3.214/19.8% || val
# '... swelling]↵↵Tubercle  n. Small rounded swelling on the body or in an organ, e' =?>
# '...ih fi s   i f f vif n fixiis fi   hifn st  wiAg i)s   f  sai↵↵A  '
# e/s=14/11800 samples/s=215 lr=0.00041 tloss=3.869 vloss/acc=3.285/17.0% || val
# '...t or between disputants. —v. (-ring) (often foll. By for, in, etc.) Act as' =?>
# '...orr  Caah f sf ph n hn     . s r   t n  r.   p h   n s  v s C  b   '
# e/s=14/11900 samples/s=217 lr=0.00041 tloss=3.823 vloss/acc=3.264/17.2% || val
# '...whole formed from parts or members. B political unit so formed. 3 = *tr' =?>
# '...   vopo  poi(Dhyp f pbip)iw p   pf h p p   o p      p f  (yf b  '
# e/s=14/12000 samples/s=214 lr=0.00040 tloss=3.859 vloss/acc=3.211/19.0% || val
# '...n guerrilla  n. Terrorist operating in an urban area.↵↵Urbanize  v. (also -is' =?>
# '...or  à ftn  t       v s    ↵↵ oor  v  n Foo gini   n  rii isiv    '
# e/s=14/12100 samples/s=213 lr=0.00040 tloss=3.866 vloss/acc=3.222/19.7% || val
# '...s) 1 right to reject a measure, resolution, etc. Unilaterally. 2 reject' =?>
# '...ttt   i   i  (ivfi f. v  (ipf spiiifif  pi ti)  ↵↵ os rivfrhf  . 3i'
# e/s=14/12200 samples/s=215 lr=0.00040 tloss=3.879 vloss/acc=3.257/17.6% || val
# '...ormal human figure. B circumference of this. 2 narrow middle of a violin, ' =?>
# '...r   mi   n  g g n nni 3 n  n  ni  v     h niMn. M n    fvoot i  n'
# e/s=14/12300 samples/s=214 lr=0.00040 tloss=3.817 vloss/acc=3.218/17.7% || val
# '...vive (a difficult period etc.). 4 get to the windward of (a cape etc.). ' =?>
# '...   ff i f h   fng  f  f r fr p2r irp r r  f   f  f ↵↵Pref  frirh '
# e/s=14/12400 samples/s=216 lr=0.00040 tloss=3.802 vloss/acc=3.210/17.2% || val
# '...mmon in less formal contexts.↵↵Whoa  int. Used to stop or slow a horse etc. [' =?>
# '...   f t.  ↵↵ eti v ff. S   (op in   naif v  ish  hh iz ( hfth v f  e'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 413
#     411 # tracking
#     412 losses.append(loss)
# --> 413 loss_tracker.append(("train", epoch, global_step, float(loss)))
#     414 if global_step % print_every == 0 or global_step == 0:
#     415   # validation
#     416   test_shift = shift % test_shifts
#
# File ~/Desktop/ai_gym/.venv/lib/python3.10/site-packages/jax/_src/array.py:298, in ArrayImpl.__float__(self)
#     296 def __float__(self):
#     297   core.check_scalar_conversion(self)
# --> 298   return self._value.__float__()
#
# File ~/Desktop/ai_gym/.venv/lib/python3.10/site-packages/jax/_src/profiler.py:333, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     330 @wraps(func)
#     331 def wrapper(*args, **kwargs):
#     332   with TraceAnnotation(name, **decorator_kwargs):
# --> 333     return func(*args, **kwargs)
#     334   return wrapper
#
# File ~/Desktop/ai_gym/.venv/lib/python3.10/site-packages/jax/_src/array.py:628, in ArrayImpl._value(self)
#     626 if self._npy_value is None:
#     627   if self.is_fully_replicated:
# --> 628     self._npy_value = self._single_device_array_to_np_array()
#     629     self._npy_value.flags.writeable = False
#     630     return cast(np.ndarray, self._npy_value)
#
# KeyboardInterrupt:

# %%
# stats and norms
# run before graphing in next cell
from pprint import pprint

def pprint_namedtuple(nt):
  nt = nt._replace(blocks=dict(nt.blocks._asdict()))
  pprint(dict(nt._asdict()))
  print()


parameter_shapes_and_counts = jax.tree_util.tree_map(lambda t: f"{t.shape} => {t.size}", grads)
parameter_count = jax.tree_util.tree_map(lambda t: t.size, grads)
parameter_total = jax.tree.reduce(lambda a, b: a + b, parameter_count)
print(f"Parameters: {parameter_total:,}")
pprint_namedtuple(parameter_shapes_and_counts)


print("Grad norms:")
grad_norms = jax.tree_util.tree_map(jnp.linalg.norm, grads)
pprint_namedtuple(grad_norms)
print()
# Out:
# Parameters: 19,829,760
# {'blocks': {'attn_norm_b': '(6, 512) => 3072',
#             'attn_norm_w': '(6, 1, 512) => 3072',
#             'ffnorm_b': '(6, 512) => 3072',
#             'ffnorm_w': '(6, 1, 512) => 3072',
#             'w1': '(6, 512, 2048) => 6291456',
#             'w2': '(6, 512, 2048) => 6291456',
#             'w3': '(6, 2048, 512) => 6291456',
#             'w_k': '(6, 8, 64, 64) => 196608',
#             'w_o': '(6, 8, 64, 64) => 196608',
#             'w_q': '(6, 8, 64, 64) => 196608',
#             'w_v': '(6, 8, 64, 64) => 196608'},
#  'embedding_projection': '(120, 512) => 61440',
#  'output_norm_b': '(512,) => 512',
#  'output_norm_w': '(1, 512) => 512',
#  'positional_embeddings': '(64, 512) => 32768',
#  'to_logits_w': '(512, 120) => 61440'}
#
# Grad norms:
# {'blocks': {'attn_norm_b': Array(0.000356, dtype=float32),
#             'attn_norm_w': Array(0.00030412, dtype=float32),
#             'ffnorm_b': Array(0., dtype=float32),
#             'ffnorm_w': Array(0., dtype=float32),
#             'w1': Array(0.18028581, dtype=float32),
#             'w2': Array(0.20107384, dtype=float32),
#             'w3': Array(0.23110104, dtype=float32),
#             'w_k': Array(0.0051799, dtype=float32),
#             'w_o': Array(0.04161203, dtype=float32),
#             'w_q': Array(0.00786463, dtype=float32),
#             'w_v': Array(0.0404928, dtype=float32)},
#  'embedding_projection': Array(0.01312608, dtype=float32),
#  'output_norm_b': Array(0., dtype=float32),
#  'output_norm_w': Array(0., dtype=float32),
#  'positional_embeddings': Array(0.00518323, dtype=float32),
#  'to_logits_w': Array(0.01425596, dtype=float32)}

# %%
# graphing
# run cell above for this one to work
from matplotlib import pyplot as plt
loss_tracker = [item for item in loss_tracker if type(item) == type((2,))]
steps_per_epoch = 0
for item in loss_tracker:
  if item[2] > steps_per_epoch:
    steps_per_epoch = item[2]


def moving_average(xs, ys, window):
  queue = []
  mays = []
  for elem in ys:
    if len(queue) < window:
      queue.append(elem)
    if len(queue) < window:
      continue
    elif len(queue) == window:
      mays.append(sum(queue)/window)
      queue.pop(0)
      queue.append(elem)
  
  return xs[:-window + 1], mays


trainx, trainy = zip(*[(step, loss) for losstype, epoch, step, loss in loss_tracker if losstype=="train"])
window_size = 5 # steps
trainx, trainy = moving_average(trainx, trainy, window_size)
testx, testy = zip(*[(step, loss) for losstype, epoch, step, loss in loss_tracker if losstype=="test" ])
testx, testy = moving_average(testx, testy, window_size)

plt.title(f'grad filter: high-pass 90th %tile')
plt.plot(trainx, jnp.log(jnp.array(trainy)), c='orange', label='train loss')
plt.plot(testx, jnp.log(jnp.array(testy)), c='green', label='val loss')
plt.xlabel('step')
plt.ylabel('log(loss)')
plt.legend()
plt.show()

# %%
prompt = """Abbacy  n. (pl. -ies) office or jurisdiction of an abbot or abbess. [latin: related to *abbot]

Meep  n. """
temp = 0.4

@jax.jit
def inference(model_params : ModelParams, xBT, temp=0.5):
  key = jrand.PRNGKey(0)
  logits = forward(key, model_params, xBT)[0, :, :] # the first Batch
  probs = jax.nn.softmax(logits / temp, axis=-1)
  get_token = lambda channel: jrand.choice(jrand.PRNGKey(int(1000*time.time())), channel.shape[-1], p=channel)
  ts = jax.vmap(get_token, in_axes=0, out_axes=0)(probs) # just take the first T in the first batch ig
  return ts


print(len(prompt))
import time
key = jrand.PRNGKey(int(100*time.time()))
completion = []

token_prompt = encode(prompt)

print(decode(token_prompt), end='')
for i in range(1000):
  token_prompt = encode(prompt)
  context = token_prompt[-block_size:]
  xBT = jnp.array(context)[None, :] # fake batch of 1
  next_token = decode([inference(model_params, xBT, temp=temp)[-1]])
  print(next_token, end='')
  prompt += next_token

# %%
# save weights

import pickle

model_path = 'weights.pickle'

with open(model_path, 'wb') as file:
  pickle.dump(model_params, file)

# %%
# load weights
with open(model_path, 'rb') as file:
  model_params_pickle = pickle.load(file)
