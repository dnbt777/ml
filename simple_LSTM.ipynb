# %%
#imports
import jax
import jax.numpy as jnp
import jax.random as random
import optax
from tokenizers import CharBPETokenizer


gpu_device = jax.device_get('gpu')[0]
cpu_device = jax.device_get('cpu')[0]
# LSTM
# xs = B, input_size = B, T, C
# h = c = y = B, output_size = B, T, logits_size = B, T, vocab_size

# %%
#dataset
with open('data/shakespeare.txt', 'r') as file:
  dataset = file.read()

# tokenize
vocab = sorted(list(set(dataset)))
print("vocab length:", len(vocab))

token_to_char = dict(enumerate(vocab))
char_to_token = dict([(v, k) for k, v in token_to_char.items()])
decode = lambda tokens: "".join([token_to_char[int(token)] for token in tokens])
encode = lambda chars: jnp.array([char_to_token[c] for c in chars])

print("dog", encode("dog"), decode(encode("dog")))

dataset_tokens = encode(dataset)
# Out:
# vocab length: 65
# dog [42 53 45] dog

# %%
lstm_blocks = 2
sequence_length = 50
model_size = 128

input_size = len(vocab) # just do one-hot for now
hidden_size = model_size
output_size = len(vocab) # logits => one-hot => tokens


# init LSTM params
def init_LSTM_params(key, lstm_blocks, input_size, model_size, output_size):
  layers = 8
  keys = random.split(key, layers*lstm_blocks + 2)
  hxconcat_size = input_size + model_size
  he = lambda rkey, shape: random.normal(rkey, shape=shape) * jnp.sqrt(2 / shape[0])
  params = [
    {
      "wU" : he(keys[layers*i + 0], (hxconcat_size, model_size)),
      "bU" : jnp.zeros((model_size,)),
      "wC" : he(keys[layers*i + 6], (hxconcat_size, model_size)),
      "bC" : jnp.zeros((model_size,)),
      "wF1": he(keys[layers*i + 1], (hxconcat_size, model_size)),
      "bF1": jnp.zeros((model_size,)),
      "wF2": he(keys[layers*i + 2], (hxconcat_size, model_size)),
      "bF2": jnp.zeros((model_size,)),
      "wO" : he(keys[layers*i + 3], (hxconcat_size, model_size)),
      "bO" : jnp.zeros((model_size,)),
      # this is for the y layer, which i am probably imlementing wrong.
      "wY1" : he(keys[layers*i + 4], (model_size, output_size)),
      "bY1" : jnp.zeros((output_size,)),
      "wY2" : he(keys[layers*i + 5], (output_size, output_size)),
      "bY2" : jnp.zeros((output_size,)),
    }
    for i in range(lstm_blocks)
  ]
  params[0].update(
    {
    "h0" : random.normal(keys[layers*(layers - 1) + 0], shape=(model_size, )) * jnp.sqrt(2 / model_size),
    "c0" : random.normal(keys[layers*(layers - 1) + 1], shape=(model_size, )) * jnp.sqrt(2 / model_size),
  })
  return params

# x: input_size
# h: hidden_size (same as model_size)
# c: hidden_size (same as model_size)



def lstm_step(lstm_params, xs, h, c, i):
  hxconcat = jax.lax.concatenate([h, xs[:, i]], dimension=1) #B, h ++ B, C => B, h+c
  # update gate
  update = jax.nn.sigmoid(hxconcat @ lstm_params[i]["wU"] + lstm_params[i]["bU"])
  candidate = jax.nn.tanh(hxconcat @ lstm_params[i]["wC"] + lstm_params[i]["bC"])
  c = c + update * candidate # (batch, c) => (batch, c)
  # forget gate
  forget1 = jax.nn.sigmoid(hxconcat @ lstm_params[i]["wF1"] + lstm_params[i]["bF1"])
  forget2 = jax.nn.tanh(hxconcat @ lstm_params[i]["wF2"] + lstm_params[i]["bF2"])
  forget = forget1 * forget2
  c = c + forget # (batch, c) => (batch, c)

  # output
  o = jax.nn.sigmoid(hxconcat @ lstm_params[i]["wO"] + lstm_params[i]["bO"])  # B, model_size
  h = jax.nn.tanh(c) * o # (B, model_size)
  return h, c

# LSTM forward
import functools
@functools.partial(jax.jit, static_argnames=['batches'])
def lstm_forward(batches, lstm_params, xs):
  logits_ts = []
  lstm_block = 0
  steps = 0
  # initialize h and c as random/learnable params
  h = jnp.tile(lstm_params[0]["h0"], (batches, 1))
  c = jnp.tile(lstm_params[0]["c0"], (batches, 1))
  T = xs.shape[1]
  # take xs and pass each xt through the same SINGULAR block. don't update the weight layer. there is only one layer.
  while steps < T:
    # iterate through all LSTM blocks, and get the output from the final one
    # send h and c from one block to the next?
    while lstm_block < len(lstm_params):
      hxconcat = jax.lax.concatenate([h, xs[:, steps]], dimension=1) #B, h ++ B, C => B, h+c
      # update gate
      update = jax.nn.sigmoid(hxconcat @ lstm_params[lstm_block]["wU"] + lstm_params[lstm_block]["bU"])
      candidate = jax.nn.tanh(hxconcat @ lstm_params[lstm_block]["wC"] + lstm_params[lstm_block]["bC"])
      c = c + update * candidate # (batch, c) => (batch, c)
      # forget gate
      forget1 = jax.nn.sigmoid(hxconcat @ lstm_params[lstm_block]["wF1"] + lstm_params[lstm_block]["bF1"])
      forget2 = jax.nn.tanh(hxconcat @ lstm_params[lstm_block]["wF2"] + lstm_params[lstm_block]["bF2"])
      forget = forget1 * forget2
      c = c + forget # (batch, c) => (batch, c)

      # output
      o = jax.nn.sigmoid(hxconcat @ lstm_params[lstm_block]["wO"] + lstm_params[lstm_block]["bO"])  # B, model_size
      h = jax.nn.tanh(c) * o # (B, model_size)

      lstm_block += 1
    
    lstm_block = len(lstm_params) - 1
    y = h @ lstm_params[lstm_block]['wY1'] + lstm_params[lstm_block]["bY1"]
    #y = y @ lstm_params[i]['wY2'] + lstm_params[i]["bY2"]

    logits_ts.append(y)
    steps += 1
  logits = jnp.transpose(jnp.array(logits_ts), axes=(1, 0, 2)) # T, B, C => B, T, C
  return logits

@jax.jit
def loss(lstm_params, xs, ys):
  batches = xs.shape[0] # B, T, C
  logits = lstm_forward(batches, lstm_params, xs)
  vocab_size = logits.shape[-1]
  ys_one_hot = jax.nn.one_hot(ys, vocab_size, axis=-1)
  logprobs = jax.nn.log_softmax(logits, axis=-1)
  crossentropylosses = -jnp.sum(ys_one_hot * logprobs, axis=-1)
  crossentropyloss = jnp.mean(crossentropylosses)
  return crossentropyloss

lr = 2e-3 # thanks karpathy
optimizer = optax.adam(learning_rate=lr)

# make optimizer a static arg in jit or it breaks
@jax.jit
def train(lstm_params, xs, ys, opt_state):
  step_loss, grads = jax.value_and_grad(loss)(lstm_params, xs, ys)
  param_updates, updated_opt_state = optimizer.update(grads, opt_state, lstm_params)
  updated_lstm_params = optax.apply_updates(lstm_params, param_updates)
  return updated_lstm_params, updated_opt_state, step_loss, grads


# set up lstm params
keys = random.split(random.PRNGKey(123), 20)
lstm_params = init_LSTM_params(keys[0], lstm_blocks, input_size, model_size, output_size)
opt_state = optimizer.init(lstm_params)

# train
# for now just overfit on small sample idk lol
dataset_tokens = jnp.array(dataset_tokens)
train_tokens = dataset_tokens[:int(len(dataset_tokens)*0.9)]
test_tokens = dataset_tokens[int(len(dataset_tokens)*0.9):]

train_batch_size = 10 # 10 sequences per batch
val_batch_size = 3 # nx3

epochs = 1000
for epoch in range(epochs):
  samples = (len(train_tokens) - 1) // sequence_length
  for i in range(0, len(train_tokens) - 1 - sequence_length*train_batch_size, sequence_length*train_batch_size):
    xtokens = train_tokens[i:i+sequence_length*train_batch_size]
    ytokens = train_tokens[i+1:i+sequence_length*train_batch_size+1]

    xtokens_batch = xtokens.reshape(-1, sequence_length)
    ytokens_batch = ytokens.reshape(-1, sequence_length) # B, T where T = sequence_length

    xembeds_batch = jax.nn.one_hot(xtokens_batch, len(vocab), axis=-1)

    # train example
    logits_batch = lstm_forward(xembeds_batch.shape[0], lstm_params, xembeds_batch)
    prediction_batch = jnp.argmax(logits_batch, axis=-1)

    # val batch
    
    j = i % ((len(test_tokens) - 1)//((val_batch_size)*sequence_length))
    idx = j*val_batch_size*sequence_length
    xtokens_val_batch = test_tokens[idx:idx+sequence_length*val_batch_size].reshape(-1, sequence_length) # batches of sequences lstm block count size
    ytokens_val_batch = test_tokens[idx+1:idx+sequence_length*val_batch_size+1].reshape(-1, sequence_length)
    xembeds_val_batch = jax.nn.one_hot(xtokens_val_batch, len(vocab), axis=-1)
    
    logits_val_batch = lstm_forward(xembeds_val_batch.shape[0], lstm_params, xembeds_val_batch)
    prediction_val_batch = jnp.argmax(logits_val_batch, axis=-1)
    ys_onehot = jax.nn.one_hot(ytokens_val_batch, len(vocab), axis=-1)
    logprobs = jax.nn.log_softmax(logits_val_batch, axis=-1)
    crossentropies = -jnp.sum(ys_onehot*logprobs,axis=-1)
    val_loss = jnp.mean(crossentropies) #lmao
    val_accuracy = jnp.mean(prediction_val_batch == ytokens_val_batch)


    lstm_params, opt_state, step_loss, grads = train(lstm_params, xembeds_batch, ytokens_batch, opt_state)
    x = decode(xtokens_batch[0]).replace('\n', ' ')
    y = decode(ytokens_batch[0]).replace('\n', ' ')
    yhat = decode(prediction_batch[0]).replace('\n', ' ')
    print(epoch, epoch * samples + i, f"{step_loss:1.4f}", "pred:", x, "=>", y, "?=", yhat)
    print("VAL::", f"loss: {val_loss:1.4f}", f"accuracy: {val_accuracy:1.4f}" )
    print()
# Out:
# 0 0 4.3112 pred: First Citizen: Before we proceed any further, hear => irst Citizen: Before we proceed any further, hear  ?= kdd;;;;;;;;K;UUUUUXXXXXXX;;;;;;;;;;;;;;;;;;ssssDDs
# VAL:: loss: 4.3243 accuracy: 0.0267
#
# 0 500 4.2132 pred:  citizens, the patricians good. What authority sur => citizens, the patricians good. What authority surf ?=  ,  ;;;;;;;;;;;fffffffffffffffLLLLLLLLLLLLLLLLLLLL
# VAL:: loss: 4.3335 accuracy: 0.0200
#
# 0 1000 4.1373 pred: Second Citizen: Would you proceed especially again => econd Citizen: Would you proceed especially agains ?= g;;;;;;;;;;;;;;;xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# VAL:: loss: 4.1055 accuracy: 0.0267
#
# 0 1500 3.9755 pred: say it was for his country he did it to please his => ay it was for his country he did it to please his  ?= RRR;;;;;Yeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee
# VAL:: loss: 3.9501 accuracy: 0.0667
#
# 0 2000 3.8776 pred: itizen: Soft! who comes here?  Second Citizen: Wor => tizen: Soft! who comes here?  Second Citizen: Wort ?= R;;;;;;;;;;;;nnnnnnnnnnnnnnnneeeeeeeeeeeeeeeeeeeee
# VAL:: loss: 3.8723 accuracy: 0.0467
#
# 0 2500 3.7749 pred: now we have strong arms too.  MENENIUS: Why, maste => ow we have strong arms too.  MENENIUS: Why, master ?= yyy;;eeleeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee
# VAL:: loss: 3.7885 accuracy: 0.0733
#
# 0 3000 3.7343 pred: ever Appear in your impediment. For the dearth, Th => ver Appear in your impediment. For the dearth, The ?= RRfs;ueeeeee           eeeeeeeeeeeeeeeeeeeeeeeeeee
# VAL:: loss: 3.7368 accuracy: 0.0800
#
# 0 3500 3.5905 pred: y wholesome act established against the rich, and  =>  wholesome act established against the rich, and p ?= ka                            eeeeeeeeeeeeeeeeeeee
# VAL:: loss: 3.6443 accuracy: 0.0667
#
# 0 4000 3.5672 pred:  our disgrace with a tale: but, an 't please you,  => our disgrace with a tale: but, an 't please you, d ?= au    eeeeeeeeeeeee e s
# VAL:: loss: 3.5790 accuracy: 0.1400
#
# 0 4500 3.5003 pred: r'd--  First Citizen: Well, sir, what answer made  => 'd--  First Citizen: Well, sir, what answer made t ?= llll
# VAL:: loss: 3.5545 accuracy: 0.1267
#
# 0 5000 3.5489 pred: or heart, the arm our soldier, Our steed the leg,  => r heart, the arm our soldier, Our steed the leg, t ?= do
# VAL:: loss: 3.4762 accuracy: 0.1467
#
# 0 5500 3.4149 pred: ttle-- Patience awhile, you'll hear the belly's an => tle-- Patience awhile, you'll hear the belly's ans ?= aal
# VAL:: loss: 3.4468 accuracy: 0.1400
#
# 0 6000 3.3676 pred: eart, to the seat o' the brain; And, through the c => art, to the seat o' the brain; And, through the cr ?= Ra
# VAL:: loss: 3.5043 accuracy: 0.1267
#
# 0 6500 3.3947 pred: ?  First Citizen: It was an answer: how apply you  =>   First Citizen: It was an answer: how apply you t ?= aaa
# VAL:: loss: 3.3229 accuracy: 0.1533
#
# 0 7000 3.3829 pred:  the lowest, basest, poorest, Of this most wise re => the lowest, basest, poorest, Of this most wise reb ?= aa
# VAL:: loss: 3.3230 accuracy: 0.1400
#
# 0 7500 3.2360 pred: ive good words to thee will flatter Beneath abhorr => ve good words to thee will flatter Beneath abhorri ?= oo
# VAL:: loss: 3.4560 accuracy: 0.1333
#
# 0 8000 3.2804 pred:  A sick man's appetite, who desires most that Whic => A sick man's appetite, who desires most that Which ?= y
# VAL:: loss: 3.2273 accuracy: 0.1533
#
# 1 179 3.4423 pred: First Citizen: Before we proceed any further, hear => irst Citizen: Before we proceed any further, hear  ?= oooeee
# VAL:: loss: 3.4459 accuracy: 0.1267
#
# 1 679 3.1590 pred:  citizens, the patricians good. What authority sur => citizens, the patricians good. What authority surf ?= a    eee
# VAL:: loss: 3.1827 accuracy: 0.1533
#
# 1 1179 3.2981 pred: Second Citizen: Would you proceed especially again => econd Citizen: Would you proceed especially agains ?= o
# VAL:: loss: 3.1992 accuracy: 0.1400
#
# 1 1679 3.1685 pred: say it was for his country he did it to please his => ay it was for his country he did it to please his  ?= oo    ee
# VAL:: loss: 3.4465 accuracy: 0.1267
#
# 1 2179 3.3073 pred: itizen: Soft! who comes here?  Second Citizen: Wor => tizen: Soft! who comes here?  Second Citizen: Wort ?= oooe
# VAL:: loss: 3.1504 accuracy: 0.1533
#
# 1 2679 3.2881 pred: now we have strong arms too.  MENENIUS: Why, maste => ow we have strong arms too.  MENENIUS: Why, master ?= yoo
# VAL:: loss: 3.1640 accuracy: 0.1400
#
# 1 3179 3.1917 pred: ever Appear in your impediment. For the dearth, Th => ver Appear in your impediment. For the dearth, The ?= oo
# VAL:: loss: 3.4515 accuracy: 0.1267
#
# 1 3679 3.2097 pred: y wholesome act established against the rich, and  =>  wholesome act established against the rich, and p ?= o
# VAL:: loss: 3.1379 accuracy: 0.1533
#
# 1 4179 3.2685 pred:  our disgrace with a tale: but, an 't please you,  => our disgrace with a tale: but, an 't please you, d ?=
# VAL:: loss: 3.1514 accuracy: 0.1400
#
# 1 4679 3.3248 pred: r'd--  First Citizen: Well, sir, what answer made  => 'd--  First Citizen: Well, sir, what answer made t ?= o
# VAL:: loss: 3.4373 accuracy: 0.1267
#
# 1 5179 3.3996 pred: or heart, the arm our soldier, Our steed the leg,  => r heart, the arm our soldier, Our steed the leg, t ?= oo
# VAL:: loss: 3.1362 accuracy: 0.1533
#
# 1 5679 3.2447 pred: ttle-- Patience awhile, you'll hear the belly's an => tle-- Patience awhile, you'll hear the belly's ans ?= oo
# VAL:: loss: 3.1478 accuracy: 0.1400
#
# 1 6179 3.2457 pred: eart, to the seat o' the brain; And, through the c => art, to the seat o' the brain; And, through the cr ?= o
# VAL:: loss: 3.4091 accuracy: 0.1333
#
# 1 6679 3.2761 pred: ?  First Citizen: It was an answer: how apply you  =>   First Citizen: It was an answer: how apply you t ?= o
# VAL:: loss: 3.1380 accuracy: 0.1533
#
# 1 7179 3.2788 pred:  the lowest, basest, poorest, Of this most wise re => the lowest, basest, poorest, Of this most wise reb ?=
# VAL:: loss: 3.1461 accuracy: 0.1467
#
# 1 7679 3.1210 pred: ive good words to thee will flatter Beneath abhorr => ve good words to thee will flatter Beneath abhorri ?= o
# VAL:: loss: 3.3845 accuracy: 0.1333
#
# 1 8179 3.2037 pred:  A sick man's appetite, who desires most that Whic => A sick man's appetite, who desires most that Which ?=
# VAL:: loss: 3.1308 accuracy: 0.1533
#
# 2 358 3.3455 pred: First Citizen: Before we proceed any further, hear => irst Citizen: Before we proceed any further, hear  ?= oo
# VAL:: loss: 3.3720 accuracy: 0.1333
#
# 2 858 3.0783 pred:  citizens, the patricians good. What authority sur => citizens, the patricians good. What authority surf ?=
# VAL:: loss: 3.1236 accuracy: 0.1533
#
# 2 1358 3.2276 pred: Second Citizen: Would you proceed especially again => econd Citizen: Would you proceed especially agains ?=
# VAL:: loss: 3.1338 accuracy: 0.1467
#
# 2 1858 3.1073 pred: say it was for his country he did it to please his => ay it was for his country he did it to please his  ?=
# VAL:: loss: 3.3631 accuracy: 0.1333
#
# 2 2358 3.2608 pred: itizen: Soft! who comes here?  Second Citizen: Wor => tizen: Soft! who comes here?  Second Citizen: Wort ?= o
# VAL:: loss: 3.1201 accuracy: 0.1533
#
# 2 2858 3.2284 pred: now we have strong arms too.  MENENIUS: Why, maste => ow we have strong arms too.  MENENIUS: Why, master ?=
# VAL:: loss: 3.1238 accuracy: 0.1533
#
# 2 3358 3.1360 pred: ever Appear in your impediment. For the dearth, Th => ver Appear in your impediment. For the dearth, The ?=
# VAL:: loss: 3.3670 accuracy: 0.1333
#
# 2 3858 3.1406 pred: y wholesome act established against the rich, and  =>  wholesome act established against the rich, and p ?=
# VAL:: loss: 3.1151 accuracy: 0.1533
#
# 2 4358 3.1946 pred:  our disgrace with a tale: but, an 't please you,  => our disgrace with a tale: but, an 't please you, d ?=
# VAL:: loss: 3.1197 accuracy: 0.1533
#
# 2 4858 3.2584 pred: r'd--  First Citizen: Well, sir, what answer made  => 'd--  First Citizen: Well, sir, what answer made t ?=
# VAL:: loss: 3.3654 accuracy: 0.1333
#
# 2 5358 3.3292 pred: or heart, the arm our soldier, Our steed the leg,  => r heart, the arm our soldier, Our steed the leg, t ?= o
# VAL:: loss: 3.1158 accuracy: 0.1533
#
# 2 5858 3.2068 pred: ttle-- Patience awhile, you'll hear the belly's an => tle-- Patience awhile, you'll hear the belly's ans ?=
# VAL:: loss: 3.1183 accuracy: 0.1533
#
# 2 6358 3.2003 pred: eart, to the seat o' the brain; And, through the c => art, to the seat o' the brain; And, through the cr ?=
# VAL:: loss: 3.3547 accuracy: 0.1333
#
# 2 6858 3.2346 pred: ?  First Citizen: It was an answer: how apply you  =>   First Citizen: It was an answer: how apply you t ?=
# VAL:: loss: 3.1132 accuracy: 0.1533
#
# 2 7358 3.2443 pred:  the lowest, basest, poorest, Of this most wise re => the lowest, basest, poorest, Of this most wise reb ?=
# VAL:: loss: 3.1107 accuracy: 0.1533
#
# 2 7858 3.0995 pred: ive good words to thee will flatter Beneath abhorr => ve good words to thee will flatter Beneath abhorri ?= o
# VAL:: loss: 3.3376 accuracy: 0.1333
#
# 2 8358 3.1613 pred:  A sick man's appetite, who desires most that Whic => A sick man's appetite, who desires most that Which ?=
# VAL:: loss: 3.0998 accuracy: 0.1533
#
# 3 537 3.3029 pred: First Citizen: Before we proceed any further, hear => irst Citizen: Before we proceed any further, hear  ?= o
# VAL:: loss: 3.3274 accuracy: 0.1333
#
# 3 1037 3.0594 pred:  citizens, the patricians good. What authority sur => citizens, the patricians good. What authority surf ?=
# VAL:: loss: 3.0921 accuracy: 0.1533
#
# 3 1537 3.1906 pred: Second Citizen: Would you proceed especially again => econd Citizen: Would you proceed especially agains ?=
# VAL:: loss: 3.0975 accuracy: 0.1533
#
# 3 2037 3.0741 pred: say it was for his country he did it to please his => ay it was for his country he did it to please his  ?=
# VAL:: loss: 3.3207 accuracy: 0.1333
#
# 3 2537 3.2178 pred: itizen: Soft! who comes here?  Second Citizen: Wor => tizen: Soft! who comes here?  Second Citizen: Wort ?=
# VAL:: loss: 3.0917 accuracy: 0.1533
#
# 3 3037 3.1868 pred: now we have strong arms too.  MENENIUS: Why, maste => ow we have strong arms too.  MENENIUS: Why, master ?=
# VAL:: loss: 3.0939 accuracy: 0.1533
#
# 3 3537 3.1111 pred: ever Appear in your impediment. For the dearth, Th => ver Appear in your impediment. For the dearth, The ?=
# VAL:: loss: 3.3272 accuracy: 0.1333
#
# 3 4037 3.1218 pred: y wholesome act established against the rich, and  =>  wholesome act established against the rich, and p ?=
# VAL:: loss: 3.0899 accuracy: 0.1533
#
# 3 4537 3.1743 pred:  our disgrace with a tale: but, an 't please you,  => our disgrace with a tale: but, an 't please you, d ?=
# VAL:: loss: 3.0965 accuracy: 0.1533
#
# 3 5037 3.2277 pred: r'd--  First Citizen: Well, sir, what answer made  => 'd--  First Citizen: Well, sir, what answer made t ?=
# VAL:: loss: 3.3273 accuracy: 0.1333
#
# 3 5537 3.2851 pred: or heart, the arm our soldier, Our steed the leg,  => r heart, the arm our soldier, Our steed the leg, t ?=
# VAL:: loss: 3.0926 accuracy: 0.1533
#
# 3 6037 3.1787 pred: ttle-- Patience awhile, you'll hear the belly's an => tle-- Patience awhile, you'll hear the belly's ans ?=
# VAL:: loss: 3.0992 accuracy: 0.1533
#
# 3 6537 3.1726 pred: eart, to the seat o' the brain; And, through the c => art, to the seat o' the brain; And, through the cr ?=
# VAL:: loss: 3.3195 accuracy: 0.1333
#
# 3 7037 3.2017 pred: ?  First Citizen: It was an answer: how apply you  =>   First Citizen: It was an answer: how apply you t ?=
# VAL:: loss: 3.0919 accuracy: 0.1533
#
# 3 7537 3.2195 pred:  the lowest, basest, poorest, Of this most wise re => the lowest, basest, poorest, Of this most wise reb ?=
# VAL:: loss: 3.0921 accuracy: 0.1533
#
# 3 8037 3.0734 pred: ive good words to thee will flatter Beneath abhorr => ve good words to thee will flatter Beneath abhorri ?=
# VAL:: loss: 3.3057 accuracy: 0.1333
#
# 3 8537 3.1331 pred:  A sick man's appetite, who desires most that Whic => A sick man's appetite, who desires most that Which ?=
# VAL:: loss: 3.0771 accuracy: 0.1533
#
# 4 716 3.2791 pred: First Citizen: Before we proceed any further, hear => irst Citizen: Before we proceed any further, hear  ?=
# VAL:: loss: 3.2972 accuracy: 0.1333
#
# 4 1216 3.0308 pred:  citizens, the patricians good. What authority sur => citizens, the patricians good. What authority surf ?=
# VAL:: loss: 3.0676 accuracy: 0.1533
#
# 4 1716 3.1653 pred: Second Citizen: Would you proceed especially again => econd Citizen: Would you proceed especially agains ?=
# VAL:: loss: 3.0721 accuracy: 0.1533
#
# 4 2216 3.0462 pred: say it was for his country he did it to please his => ay it was for his country he did it to please his  ?=
# VAL:: loss: 3.2940 accuracy: 0.1333
#
# 4 2716 3.1914 pred: itizen: Soft! who comes here?  Second Citizen: Wor => tizen: Soft! who comes here?  Second Citizen: Wort ?=
# VAL:: loss: 3.0644 accuracy: 0.1533
#
# 4 3216 3.1576 pred: now we have strong arms too.  MENENIUS: Why, maste => ow we have strong arms too.  MENENIUS: Why, master ?=
# VAL:: loss: 3.0646 accuracy: 0.1533
#
# 4 3716 3.0821 pred: ever Appear in your impediment. For the dearth, Th => ver Appear in your impediment. For the dearth, The ?=
# VAL:: loss: 3.3007 accuracy: 0.1333
#
# 4 4216 3.0943 pred: y wholesome act established against the rich, and  =>  wholesome act established against the rich, and p ?=
# VAL:: loss: 3.0619 accuracy: 0.1533
#
# 4 4716 3.1426 pred:  our disgrace with a tale: but, an 't please you,  => our disgrace with a tale: but, an 't please you, d ?=
# VAL:: loss: 3.0645 accuracy: 0.1533
#
# 4 5216 3.1981 pred: r'd--  First Citizen: Well, sir, what answer made  => 'd--  First Citizen: Well, sir, what answer made t ?=
# VAL:: loss: 3.2997 accuracy: 0.1333
#
# 4 5716 3.2514 pred: or heart, the arm our soldier, Our steed the leg,  => r heart, the arm our soldier, Our steed the leg, t ?=
# VAL:: loss: 3.0628 accuracy: 0.1533
#
# 4 6216 3.1487 pred: ttle-- Patience awhile, you'll hear the belly's an => tle-- Patience awhile, you'll hear the belly's ans ?=
# VAL:: loss: 3.0676 accuracy: 0.1533
#
# 4 6716 3.1429 pred: eart, to the seat o' the brain; And, through the c => art, to the seat o' the brain; And, through the cr ?=
# VAL:: loss: 3.2940 accuracy: 0.1333
#
# 4 7216 3.1701 pred: ?  First Citizen: It was an answer: how apply you  =>   First Citizen: It was an answer: how apply you t ?=
# VAL:: loss: 3.0615 accuracy: 0.1533
#
# 4 7716 3.1890 pred:  the lowest, basest, poorest, Of this most wise re => the lowest, basest, poorest, Of this most wise reb ?=
# VAL:: loss: 3.0605 accuracy: 0.1533
#
# 4 8216 3.0438 pred: ive good words to thee will flatter Beneath abhorr => ve good words to thee will flatter Beneath abhorri ?=
# VAL:: loss: 3.2790 accuracy: 0.1333
#
# 4 8716 3.1038 pred:  A sick man's appetite, who desires most that Whic => A sick man's appetite, who desires most that Which ?=
# VAL:: loss: 3.0462 accuracy: 0.1533
#
# 5 895 3.2487 pred: First Citizen: Before we proceed any further, hear => irst Citizen: Before we proceed any further, hear  ?=
# VAL:: loss: 3.2692 accuracy: 0.1333
#
# 5 1395 3.0037 pred:  citizens, the patricians good. What authority sur => citizens, the patricians good. What authority surf ?=
# VAL:: loss: 3.0369 accuracy: 0.1533
#
# 5 1895 3.1365 pred: Second Citizen: Would you proceed especially again => econd Citizen: Would you proceed especially agains ?=
# VAL:: loss: 3.0415 accuracy: 0.1533
#
# 5 2395 3.0168 pred: say it was for his country he did it to please his => ay it was for his country he did it to please his  ?=
# VAL:: loss: 3.2657 accuracy: 0.1333
#
# 5 2895 3.1595 pred: itizen: Soft! who comes here?  Second Citizen: Wor => tizen: Soft! who comes here?  Second Citizen: Wort ?=
# VAL:: loss: 3.0343 accuracy: 0.1533
#
# 5 3395 3.1256 pred: now we have strong arms too.  MENENIUS: Why, maste => ow we have strong arms too.  MENENIUS: Why, master ?=
# VAL:: loss: 3.0355 accuracy: 0.1533
#
# 5 3895 3.0518 pred: ever Appear in your impediment. For the dearth, Th => ver Appear in your impediment. For the dearth, The ?=
# VAL:: loss: 3.2721 accuracy: 0.1333
#
# 5 4395 3.0653 pred: y wholesome act established against the rich, and  =>  wholesome act established against the rich, and p ?=
# VAL:: loss: 3.0329 accuracy: 0.1533
#
# 5 4895 3.1123 pred:  our disgrace with a tale: but, an 't please you,  => our disgrace with a tale: but, an 't please you, d ?=                  e
# VAL:: loss: 3.0369 accuracy: 0.1667
#
# 5 5395 3.1668 pred: r'd--  First Citizen: Well, sir, what answer made  => 'd--  First Citizen: Well, sir, what answer made t ?=                  e
# VAL:: loss: 3.2687 accuracy: 0.1400
#
# 5 5895 3.2142 pred: or heart, the arm our soldier, Our steed the leg,  => r heart, the arm our soldier, Our steed the leg, t ?=            e
# VAL:: loss: 3.0348 accuracy: 0.1600
#
# 5 6395 3.1159 pred: ttle-- Patience awhile, you'll hear the belly's an => tle-- Patience awhile, you'll hear the belly's ans ?=                   e            e     e
# VAL:: loss: 3.0399 accuracy: 0.1933
#
# 5 6895 3.1114 pred: eart, to the seat o' the brain; And, through the c => art, to the seat o' the brain; And, through the cr ?=           e           e               e    e  e
# VAL:: loss: 3.2624 accuracy: 0.1467
#
# 5 7395 3.1334 pred: ?  First Citizen: It was an answer: how apply you  =>   First Citizen: It was an answer: how apply you t ?=              e                      e
# VAL:: loss: 3.0326 accuracy: 0.1533
#
# 5 7895 3.1562 pred:  the lowest, basest, poorest, Of this most wise re => the lowest, basest, poorest, Of this most wise reb ?=                                   e
# VAL:: loss: 3.0311 accuracy: 0.1933
#
# 5 8395 3.0111 pred: ive good words to thee will flatter Beneath abhorr => ve good words to thee will flatter Beneath abhorri ?=                    e
# VAL:: loss: 3.2469 accuracy: 0.1400
#
# 5 8895 3.0710 pred:  A sick man's appetite, who desires most that Whic => A sick man's appetite, who desires most that Which ?=
# VAL:: loss: 3.0155 accuracy: 0.1533
#
# 6 1074 3.2162 pred: First Citizen: Before we proceed any further, hear => irst Citizen: Before we proceed any further, hear  ?=
# VAL:: loss: 3.2366 accuracy: 0.1333
#
# 6 1574 2.9735 pred:  citizens, the patricians good. What authority sur => citizens, the patricians good. What authority surf ?=
# VAL:: loss: 3.0057 accuracy: 0.1533
#
# 6 2074 3.1031 pred: Second Citizen: Would you proceed especially again => econd Citizen: Would you proceed especially agains ?=
# VAL:: loss: 3.0085 accuracy: 0.1600
#
# 6 2574 2.9847 pred: say it was for his country he did it to please his => ay it was for his country he did it to please his  ?=                e           e                   e
# VAL:: loss: 3.2304 accuracy: 0.1400
#
# 6 3074 3.1259 pred: itizen: Soft! who comes here?  Second Citizen: Wor => tizen: Soft! who comes here?  Second Citizen: Wort ?=                e        e
# VAL:: loss: 3.0039 accuracy: 0.1533
#
# 6 3574 3.0888 pred: now we have strong arms too.  MENENIUS: Why, maste => ow we have strong arms too.  MENENIUS: Why, master ?=
# VAL:: loss: 3.0015 accuracy: 0.1800
#
# 6 4074 3.0190 pred: ever Appear in your impediment. For the dearth, Th => ver Appear in your impediment. For the dearth, The ?=
# VAL:: loss: 3.2394 accuracy: 0.1400
#
# 6 4574 3.0328 pred: y wholesome act established against the rich, and  =>  wholesome act established against the rich, and p ?=                         e            e
# VAL:: loss: 3.0015 accuracy: 0.1533
#
# 6 5074 3.0763 pred:  our disgrace with a tale: but, an 't please you,  => our disgrace with a tale: but, an 't please you, d ?=               e  e         e
# VAL:: loss: 3.0034 accuracy: 0.1933
#
# 6 5574 3.1298 pred: r'd--  First Citizen: Well, sir, what answer made  => 'd--  First Citizen: Well, sir, what answer made t ?=                  e                e
# VAL:: loss: 3.2370 accuracy: 0.1600
#
# 6 6074 3.1723 pred: or heart, the arm our soldier, Our steed the leg,  => r heart, the arm our soldier, Our steed the leg, t ?=            e                              e
# VAL:: loss: 3.0029 accuracy: 0.1533
#
# 6 6574 3.0807 pred: ttle-- Patience awhile, you'll hear the belly's an => tle-- Patience awhile, you'll hear the belly's ans ?=                t ee            e     e  e
# VAL:: loss: 3.0078 accuracy: 0.1933
#
# 6 7074 3.0755 pred: eart, to the seat o' the brain; And, through the c => art, to the seat o' the brain; And, through the cr ?=           e t         e  e            e    e  e
# VAL:: loss: 3.2282 accuracy: 0.1667
#
# 6 7574 3.0917 pred: ?  First Citizen: It was an answer: how apply you  =>   First Citizen: It was an answer: how apply you t ?=              e       e              e
# VAL:: loss: 3.0007 accuracy: 0.1600
#
# 6 8074 3.1187 pred:  the lowest, basest, poorest, Of this most wise re => the lowest, basest, poorest, Of this most wise reb ?=              e                    e        e
# VAL:: loss: 2.9974 accuracy: 0.1933
#
# 6 8574 2.9742 pred: ive good words to thee will flatter Beneath abhorr => ve good words to thee will flatter Beneath abhorri ?=          e         e  te                  e   e
# VAL:: loss: 3.2075 accuracy: 0.1600
#
# 6 9074 3.0356 pred:  A sick man's appetite, who desires most that Whic => A sick man's appetite, who desires most that Which ?=                          e                e    e
# VAL:: loss: 2.9821 accuracy: 0.1533
#
# 7 1253 3.1791 pred: First Citizen: Before we proceed any further, hear => irst Citizen: Before we proceed any further, hear  ?=           e                              e    e
# VAL:: loss: 3.1968 accuracy: 0.1467
#
# 7 1753 2.9404 pred:  citizens, the patricians good. What authority sur => citizens, the patricians good. What authority surf ?=      e      e                    e      e
# VAL:: loss: 2.9711 accuracy: 0.1533
#
# 7 2253 3.0669 pred: Second Citizen: Would you proceed especially again => econd Citizen: Would you proceed especially agains ?=            e
# VAL:: loss: 2.9725 accuracy: 0.2000
#
# 7 2753 2.9497 pred: say it was for his country he did it to please his => ay it was for his country he did it to please his  ?=        e       e           e                   e
# VAL:: loss: 3.1925 accuracy: 0.1600
#
# 7 3253 3.0873 pred: itizen: Soft! who comes here?  Second Citizen: Wor => tizen: Soft! who comes here?  Second Citizen: Wort ?=               ee  e     e                 e
# VAL:: loss: 2.9673 accuracy: 0.1533
#
# 7 3753 3.0484 pred: now we have strong arms too.  MENENIUS: Why, maste => ow we have strong arms too.  MENENIUS: Why, master ?=        e e                               e
# VAL:: loss: 2.9648 accuracy: 0.2000
#
# 7 4253 2.9828 pred: ever Appear in your impediment. For the dearth, Th => ver Appear in your impediment. For the dearth, The ?=                    t                 e       e   e
# VAL:: loss: 3.2051 accuracy: 0.1600
#
# 7 4753 2.9966 pred: y wholesome act established against the rich, and  =>  wholesome act established against the rich, and p ?=                     e   e          t e t   e t
# VAL:: loss: 2.9634 accuracy: 0.1800
#
# 7 5253 3.0359 pred:  our disgrace with a tale: but, an 't please you,  => our disgrace with a tale: but, an 't please you, d ?=            e te  et t     te   t  t  t           t
# VAL:: loss: 2.9677 accuracy: 0.2267
#
# 7 5753 3.0880 pred: r'd--  First Citizen: Well, sir, what answer made  => 'd--  First Citizen: Well, sir, what answer made t ?=             t    e         t    tee  t      t    t
# VAL:: loss: 3.2029 accuracy: 0.1867
#
# 7 6253 3.1259 pred: or heart, the arm our soldier, Our steed the leg,  => r heart, the arm our soldier, Our steed the leg, t ?=    e     t e t   t   t            t     t e t    t
# VAL:: loss: 2.9664 accuracy: 0.1800
#
# 7 6753 3.0392 pred: ttle-- Patience awhile, you'll hear the belly's an => tle-- Patience awhile, you'll hear the belly's ans ?=         t    e ttee    t      te   t e te      t
# VAL:: loss: 2.9722 accuracy: 0.2400
#
# 7 7253 3.0351 pred: eart, to the seat o' the brain; And, through the c => art, to the seat o' the brain; And, through the cr ?=         t e t  t t  t e te          t e    et e te
# VAL:: loss: 3.1862 accuracy: 0.1867
#
# 7 7753 3.0448 pred: ?  First Citizen: It was an answer: how apply you  =>   First Citizen: It was an answer: how apply you t ?=         t    e      te  t  t       te  t     t   t
# VAL:: loss: 2.9641 accuracy: 0.1800
#
# 7 8253 3.0761 pred:  the lowest, basest, poorest, Of this most wise re => the lowest, basest, poorest, Of this most wise reb ?=   e    e    te      te          t e  t    te   t
# VAL:: loss: 2.9591 accuracy: 0.2400
#
# 7 8753 2.9325 pred: ive good words to thee will flatter Beneath abhorr => ve good words to thee will flatter Beneath abhorri ?=  e       e    t  t e  te   t              et ee
# VAL:: loss: 3.1665 accuracy: 0.1867
#
# 7 9253 2.9957 pred:  A sick man's appetite, who desires most that Whic => A sick man's appetite, who desires most that Which ?=              t         tee t       t    t e    e
# VAL:: loss: 2.9436 accuracy: 0.1733
#
# 8 1432 3.1404 pred: First Citizen: Before we proceed any further, hear => irst Citizen: Before we proceed any further, hear  ?=           e          te t           t    e   te
# VAL:: loss: 3.1576 accuracy: 0.1867
#
# 8 1932 2.9049 pred:  citizens, the patricians good. What authority sur => citizens, the patricians good. What authority surf ?=      e      e  e                 e  t   e     t
# VAL:: loss: 2.9312 accuracy: 0.1733
#
# 8 2432 3.0261 pred: Second Citizen: Would you proceed especially again => econd Citizen: Would you proceed especially agains ?=            e         t   te      t          t
# VAL:: loss: 2.9310 accuracy: 0.2400
#
# 8 2932 2.9100 pred: say it was for his country he did it to please his => ay it was for his country he did it to please his  ?=       te  t   te  te      te t   t  t         te
# VAL:: loss: 3.1529 accuracy: 0.1867
#
# 8 3432 3.0437 pred: itizen: Soft! who comes here?  Second Citizen: Wor => tizen: Soft! who comes here?  Second Citizen: Wort ?=    e          ee  e    te            t    e
# VAL:: loss: 2.9260 accuracy: 0.1800
#
# 8 3932 3.0032 pred: now we have strong arms too.  MENENIUS: Why, maste => ow we have strong arms too.  MENENIUS: Why, master ?=    te  e e t      tt   t                 e  t
# VAL:: loss: 2.9234 accuracy: 0.2400
#
# 8 4432 2.9417 pred: ever Appear in your impediment. For the dearth, Th => ver Appear in your impediment. For the dearth, The ?=            t  t    t           t   t e t  t  e   e
# VAL:: loss: 3.1639 accuracy: 0.1867
#
# 8 4932 2.9569 pred: y wholesome act established against the rich, and  =>  wholesome act established against the rich, and p ?=    e       t e      e   e  tt t    t e t  ee tt  t
# VAL:: loss: 2.9247 accuracy: 0.2000
#
# 8 5432 2.9915 pred:  our disgrace with a tale: but, an 't please you,  => our disgrace with a tale: but, an 't please you, d ?=     t     te te  ettt t   te   tt t  te  t       t
# VAL:: loss: 2.9290 accuracy: 0.2467
#
# 8 5932 3.0418 pred: r'd--  First Citizen: Well, sir, what answer made  => 'd--  First Citizen: Well, sir, what answer made t ?=             t    e    e    t    teet tt  e  tet  t
# VAL:: loss: 3.1632 accuracy: 0.1867
#
# 8 6432 3.0754 pred: or heart, the arm our soldier, Our steed the leg,  => r heart, the arm our soldier, Our steed the leg, t ?=    e t   t e tt  t   t            t     t e t    t
# VAL:: loss: 2.9266 accuracy: 0.2200
#
# 8 6932 2.9959 pred: ttle-- Patience awhile, you'll hear the belly's an => tle-- Patience awhile, you'll hear the belly's ans ?= e       t t  e ttee    t      te t t e te      tt
# VAL:: loss: 2.9341 accuracy: 0.2533
#
# 8 7432 2.9883 pred: eart, to the seat o' the brain; And, through the c => art, to the seat o' the brain; And, through the cr ?=      t  t e t  t t  t e te t        t e    et e te
# VAL:: loss: 3.1449 accuracy: 0.1933
#
# 8 7932 3.0008 pred: ?  First Citizen: It was an answer: how apply you  =>   First Citizen: It was an answer: how apply you t ?=         tet  e      tet tt tt  e   te  ttee  t   t
# VAL:: loss: 2.9303 accuracy: 0.2267
#
# 8 8432 3.0298 pred:  the lowest, basest, poorest, Of this most wise re => the lowest, basest, poorest, Of this most wise reb ?=   e t  e    tet     te          t e  te   te   t
# VAL:: loss: 2.9169 accuracy: 0.2400
#
# 8 8932 2.8854 pred: ive good words to thee will flatter Beneath abhorr => ve good words to thee will flatter Beneath abhorri ?=  e t    te    t  t e  te   t  t         t ettee
# VAL:: loss: 3.1181 accuracy: 0.1867
#
# 8 9432 2.9560 pred:  A sick man's appetite, who desires most that Whic => A sick man's appetite, who desires most that Which ?=      e tet   tte       tee t       te   t e    e
# VAL:: loss: 2.9049 accuracy: 0.2133
#
# 9 1611 3.0928 pred: First Citizen: Before we proceed any further, hear => irst Citizen: Before we proceed any further, hear  ?=      t    e          te te      tt  t    e   te
# VAL:: loss: 3.1094 accuracy: 0.1867
#
# 9 2111 2.8661 pred:  citizens, the patricians good. What authority sur => citizens, the patricians good. What authority surf ?=      e    t e tet   e    t      he  tt  e     t
# VAL:: loss: 2.8905 accuracy: 0.1933
#
# 9 2611 2.9799 pred: Second Citizen: Would you proceed especially again => econd Citizen: Would you proceed especially agains ?=       t    e    e    t   te      t          tt
# VAL:: loss: 2.8833 accuracy: 0.2400
#
# 9 3111 2.8614 pred: say it was for his country he did it to please his => ay it was for his country he did it to please his  ?=    t  tet t   te  to      te t   t  t         te
# VAL:: loss: 3.1129 accuracy: 0.1867
#
# 9 3611 2.9973 pred: itizen: Soft! who comes here?  Second Citizen: Wor => tizen: Soft! who comes here?  Second Citizen: Wort ?=    e         tee to    te            t    e
# VAL:: loss: 2.8761 accuracy: 0.2200
#
# 9 4111 2.9559 pred: now we have strong arms too.  MENENIUS: Why, maste => ow we have strong arms too.  MENENIUS: Why, master ?=    te  ete t      tt   t                ee  tet
# VAL:: loss: 2.8759 accuracy: 0.2533
#
# 9 4611 2.9032 pred: ever Appear in your impediment. For the dearth, Th => ver Appear in your impediment. For the dearth, The ?=  e    ee t tt t    tt    t     t   t e t  t  e  he
# VAL:: loss: 3.1300 accuracy: 0.1933
#
# 9 5111 2.9147 pred: y wholesome act established against the rich, and  =>  wholesome act established against the rich, and p ?=   ee       tte     te t e  tt tt   t e tetee tt  t
# VAL:: loss: 2.8717 accuracy: 0.2467
#
# 9 5611 2.9500 pred:  our disgrace with a tale: but, an 't please you,  => our disgrace with a tale: but, an 't please you, d ?=     t t   te tet ettt t   te   tt t  te  t       t
# VAL:: loss: 2.8804 accuracy: 0.2733
#
# 9 6111 2.9934 pred: r'd--  First Citizen: Well, sir, what answer made  => 'd--  First Citizen: Well, sir, what answer made t ?=        ite  tet te    e    t te teet tt  e  tet  t
# VAL:: loss: 3.1227 accuracy: 0.1933
#
# 9 6611 3.0186 pred: or heart, the arm our soldier, Our steed the leg,  => r heart, the arm our soldier, Our steed the leg, t ?=   te te  t e tt  t   t    t    e  t     t e te   t
# VAL:: loss: 2.8795 accuracy: 0.2267
#
# 9 7111 2.9476 pred: ttle-- Patience awhile, you'll hear the belly's an => tle-- Patience awhile, you'll hear the belly's ans ?= e       t t  e tteet   t      te t t e te      tt
# VAL:: loss: 2.8860 accuracy: 0.2667
#
# 9 7611 2.9395 pred: eart, to the seat o' the brain; And, through the c => art, to the seat o' the brain; And, through the cr ?=      t  t e t  t t  t e te t        t e    et e te
# VAL:: loss: 3.0979 accuracy: 0.1933
#
# 9 8111 2.9356 pred: ?  First Citizen: It was an answer: how apply you  =>   First Citizen: It was an answer: how apply you t ?=         tet te      tet tt tt  e   te ettee  t   t
# VAL:: loss: 2.8797 accuracy: 0.2400
#
# 9 8611 2.9795 pred:  the lowest, basest, poorest, Of this most wise re => the lowest, basest, poorest, Of this most wise reb ?=   e te e    tet     te          t e  te   te   te
# VAL:: loss: 2.8743 accuracy: 0.2600
#
# 9 9111 2.8309 pred: ive good words to thee will flatter Beneath abhorr => ve good words to thee will flatter Beneath abhorri ?=  e t    te    t  t e  tet  t  t         t ettee
# VAL:: loss: 3.0715 accuracy: 0.1867
#
# 9 9611 2.9049 pred:  A sick man's appetite, who desires most that Whic => A sick man's appetite, who desires most that Which ?=      e tet   tte       tee t       te   t et  ee e
# VAL:: loss: 2.8593 accuracy: 0.2533
#
# 10 1790 3.0427 pred: First Citizen: Before we proceed any further, hear => irst Citizen: Before we proceed any further, hear  ?=      tot te    e     te te      tt  t    e   te t
# VAL:: loss: 3.0612 accuracy: 0.2000
#
# 10 2290 2.8242 pred:  citizens, the patricians good. What authority sur => citizens, the patricians good. What authority surf ?=  e   e    the tet   e t  t      het tt  e     t
# VAL:: loss: 2.8443 accuracy: 0.2667
#
# 10 2790 2.9331 pred: Second Citizen: Would you proceed especially again => econd Citizen: Would you proceed especially agains ?=       tot te    h    to  te      t  e ett   tt t
# VAL:: loss: 2.8417 accuracy: 0.3000
#
# 10 3290 2.8217 pred: say it was for his country he did it to please his => ay it was for his country he did it to please his  ?=    to tet to  tet to      te t t te th  e  t  tet
# VAL:: loss: 3.0584 accuracy: 0.2333
#
# 10 3790 2.9488 pred: itizen: Soft! who comes here?  Second Citizen: Wor => tizen: Soft! who comes here?  Second Citizen: Wort ?=    e         tee to    te     oe e   tot te    e
# VAL:: loss: 2.8333 accuracy: 0.2867
#
# 10 4290 2.8993 pred: now we have strong arms too.  MENENIUS: Why, maste => ow we have strong arms too.  MENENIUS: Why, master ?=    te  ete t      tt   th               ee  tet
# VAL:: loss: 2.8310 accuracy: 0.3000
#
# 10 4790 2.8497 pred: ever Appear in your impediment. For the dearth, Th => ver Appear in your impediment. For the dearth, The ?=  e     e t tt to   tte   te    ti  t e t  t  e  he
# VAL:: loss: 3.0761 accuracy: 0.2067
#
# 10 5290 2.8590 pred: y wholesome act established against the rich, and  =>  wholesome act established against the rich, and p ?=  tee       tte     te t e  tt tt   the tetee tt  t
# VAL:: loss: 2.8258 accuracy: 0.2733
#
# 10 5790 2.9008 pred:  our disgrace with a tale: but, an 't please you,  => our disgrace with a tale: but, an 't please you, d ?= e   t t   te tet ettt t   te   tt t  te  t       t
# VAL:: loss: 2.8347 accuracy: 0.2933
#
# 10 6290 2.9351 pred: r'd--  First Citizen: Well, sir, what answer made  => 'd--  First Citizen: Well, sir, what answer made t ?=        ite  tit te    e    t te teet tt  e  tet  t
# VAL:: loss: 3.0712 accuracy: 0.2067
#
# 10 6790 2.9509 pred: or heart, the arm our soldier, Our steed the leg,  => r heart, the arm our soldier, Our steed the leg, t ?=   te t   the tte te  t    t    e  t     t e te   t
# VAL:: loss: 2.8311 accuracy: 0.2533
#
# 10 7290 2.8955 pred: ttle-- Patience awhile, you'll hear the belly's an => tle-- Patience awhile, you'll hear the belly's ans ?= e       t t  e tteet   t      te t t e te      tt
# VAL:: loss: 2.8367 accuracy: 0.2800
#
# 10 7790 2.8808 pred: eart, to the seat o' the brain; And, through the c => art, to the seat o' the brain; And, through the cr ?=      th the t  t te the te tt       the    et e te
# VAL:: loss: 3.0508 accuracy: 0.2267
#
# 10 8290 2.8679 pred: ?  First Citizen: It was an answer: how apply you  =>   First Citizen: It was an answer: how apply you t ?=     t   tit te      tet tt tt  e   te ettee  t   t
# VAL:: loss: 2.8276 accuracy: 0.2600
#
# 10 8790 2.9239 pred:  the lowest, basest, poorest, Of this most wise re => the lowest, basest, poorest, Of this most wise reb ?= e e te      tet     te        e thet te   tet  te
# VAL:: loss: 2.8155 accuracy: 0.3067
#
# 10 9290 2.7763 pred: ive good words to thee will flatter Beneath abhorr => ve good words to thee will flatter Beneath abhorri ?=  e t    te    th the  tet  t  t     e   t ettee
# VAL:: loss: 3.0213 accuracy: 0.2267
#
# 10 9790 2.8487 pred:  A sick man's appetite, who desires most that Whic => A sick man's appetite, who desires most that Which ?=   t te tet   ttee  t   tee t   te  te   thet  hete
# VAL:: loss: 2.8017 accuracy: 0.2800
#
# 11 1969 2.9895 pred: First Citizen: Before we proceed any further, hear => irst Citizen: Before we proceed any further, hear  ?= e    tot te    e     te te      tt  to   e   te t
# VAL:: loss: 3.0128 accuracy: 0.2267
#
# 11 2469 2.7766 pred:  citizens, the patricians good. What authority sur => citizens, the patricians good. What authority surf ?= te  te    the tet  tett  to     het tt  e  t  t
# VAL:: loss: 2.7875 accuracy: 0.3000
#
# 11 2969 2.8776 pred: Second Citizen: Would you proceed especially again => econd Citizen: Would you proceed especially agains ?=       tot te    h    to  te      t    ett   tt tt
# VAL:: loss: 2.7950 accuracy: 0.3067
#
# 11 3469 2.7725 pred: say it was for his country he did it to please his => ay it was for his country he did it to please his  ?=    to tet to  tet to      te t t to th  e  t  tet
# VAL:: loss: 3.0101 accuracy: 0.2200
#
# 11 3969 2.8958 pred: itizen: Soft! who comes here?  Second Citizen: Wor => tizen: Soft! who comes here?  Second Citizen: Wort ?= e te    e    tee to    te     oe e   tot te    h
# VAL:: loss: 2.7777 accuracy: 0.3000
#
# 11 4469 2.8402 pred: now we have strong arms too.  MENENIUS: Why, maste => ow we have strong arms too.  MENENIUS: Why, master ?=    te  ete t      tt   th    o          he  tet
# VAL:: loss: 2.7859 accuracy: 0.3067
#
# 11 4969 2.7917 pred: ever Appear in your impediment. For the dearth, Th => ver Appear in your impediment. For the dearth, The ?=  e    ee teto to   tte   te    ti  the t  t  e  he
# VAL:: loss: 3.0212 accuracy: 0.2267
#
# 11 5469 2.8074 pred: y wholesome act established against the rich, and  =>  wholesome act established against the rich, and p ?=  tee       tte     te t e  tt tt   the tetee tt  t
# VAL:: loss: 2.7712 accuracy: 0.3000
#
# 11 5969 2.8471 pred:  our disgrace with a tale: but, an 't please you,  => our disgrace with a tale: but, an 't please you, d ?= t   t t  ete tet etttht   te   tt t  te  t       t
# VAL:: loss: 2.7838 accuracy: 0.3000
#
# 11 6469 2.8729 pred: r'd--  First Citizen: Well, sir, what answer made  => 'd--  First Citizen: Well, sir, what answer made t ?= e      ite  tit te    e    t te teet tt  e  tet  t
# VAL:: loss: 3.0255 accuracy: 0.2333
#
# 11 6969 2.8808 pred: or heart, the arm our soldier, Our steed the leg,  => r heart, the arm our soldier, Our steed the leg, t ?=   te te  the tte te  t    t    e  t     the te   t
# VAL:: loss: 2.7719 accuracy: 0.2667
#
# 11 7469 2.8424 pred: ttle-- Patience awhile, you'll hear the belly's an => tle-- Patience awhile, you'll hear the belly's ans ?= eee    et t  e tteet   to     te tethe te      tt
# VAL:: loss: 2.7804 accuracy: 0.3133
#
# 11 7969 2.8232 pred: eart, to the seat o' the brain; And, through the c => art, to the seat o' the brain; And, through the cr ?=  t   th the t  t te the te tt   e   the    ethe te
# VAL:: loss: 3.0093 accuracy: 0.2267
#
# 11 8469 2.8028 pred: ?  First Citizen: It was an answer: how apply you  =>   First Citizen: It was an answer: how apply you t ?=    ite  tit te      tet tt tt  e   te  ttee  t   t
# VAL:: loss: 2.7687 accuracy: 0.2667
#
# 11 8969 2.8626 pred:  the lowest, basest, poorest, Of this most wise re => the lowest, basest, poorest, Of this most wise reb ?= t e te e    tet     te        e thet te   tet  te
# VAL:: loss: 2.7616 accuracy: 0.3133
#
# 11 9469 2.7201 pred: ive good words to thee will flatter Beneath abhorr => ve good words to thee will flatter Beneath abhorri ?= te to   thu   th the  tet  to t     e   t ettee
# VAL:: loss: 2.9780 accuracy: 0.2267
#
# 11 9969 2.7941 pred:  A sick man's appetite, who desires most that Whic => A sick man's appetite, who desires most that Which ?=   t te tet   ttee  t   the t   te  te   thet  hete
# VAL:: loss: 2.7488 accuracy: 0.3000
#
# 12 2148 2.9320 pred: First Citizen: Before we proceed any further, hear => irst Citizen: Before we proceed any further, hear  ?= et   tot te    e     th te      tt  to   e   te t
# VAL:: loss: 2.9600 accuracy: 0.2333
#
# 12 2648 2.7362 pred:  citizens, the patricians good. What authority sur => citizens, the patricians good. What authority surf ?= tet te    the tot  tott  to     het tt  e  t  t
# VAL:: loss: 2.7357 accuracy: 0.3067
#
# 12 3148 2.8176 pred: Second Citizen: Would you proceed especially again => econd Citizen: Would you proceed especially agains ?=       tot te    hu   tou toe     t  e ett   to tt
# VAL:: loss: 2.7389 accuracy: 0.3133
#
# 12 3648 2.7252 pred: say it was for his country he did it to please his => ay it was for his country he did it to please his  ?=  t to tet tou tet tou   e te t t to th  e  t  tet
# VAL:: loss: 2.9614 accuracy: 0.2400
#
# 12 4148 2.8371 pred: itizen: Soft! who comes here?  Second Citizen: Wor => tizen: Soft! who comes here?  Second Citizen: Wort ?= e te    ou   tee tou   te     oe e   tot te    h
# VAL:: loss: 2.7242 accuracy: 0.3200
#
# 12 4648 2.7798 pred: now we have strong arms too.  MENENIUS: Why, maste => ow we have strong arms too.  MENENIUS: Why, master ?=    te  ete te e   tte  th    oo         he  tet
# VAL:: loss: 2.7356 accuracy: 0.3133
#
# 12 5148 2.7399 pred: ever Appear in your impediment. For the dearth, Th => ver Appear in your impediment. For the dearth, The ?=  e    ee teto tou  toee  te    ti  the t  t  e  he
# VAL:: loss: 2.9764 accuracy: 0.2267
#
# 12 5648 2.7501 pred: y wholesome act established against the rich, and  =>  wholesome act established against the rich, and p ?=  tee       tte     te t e  tt tt   the tetee tt  t
# VAL:: loss: 2.7170 accuracy: 0.3133
#
# 12 6148 2.7931 pred:  our disgrace with a tale: but, an 't please you,  => our disgrace with a tale: but, an 't please you, d ?= t   t t  ete tet etttht   te   tt te te  t       t
# VAL:: loss: 2.7388 accuracy: 0.3067
#
# 12 6648 2.8084 pred: r'd--  First Citizen: Well, sir, what answer made  => 'd--  First Citizen: Well, sir, what answer made t ?= e     oite  tit te    h    tete teet tt  e  tet  t
# VAL:: loss: 2.9770 accuracy: 0.2333
#
# 12 7148 2.8108 pred: or heart, the arm our soldier, Our steed the leg,  => r heart, the arm our soldier, Our steed the leg, t ?=   te te  the tte te  te   t    e  t     the te   t
# VAL:: loss: 2.7183 accuracy: 0.2867
#
# 12 7648 2.7862 pred: ttle-- Patience awhile, you'll hear the belly's an => tle-- Patience awhile, you'll hear the belly's ans ?= e e    et t  e tteet   tou    te tethe te      tt
# VAL:: loss: 2.7332 accuracy: 0.3200
#
# 12 8148 2.7644 pred: eart, to the seat o' the brain; And, through the c => art, to the seat o' the brain; And, through the cr ?=  t   thuthe te t te the teett   e   the    ethe te
# VAL:: loss: 2.9474 accuracy: 0.2467
#
# 12 8648 2.7311 pred: ?  First Citizen: It was an answer: how apply you  =>   First Citizen: It was an answer: how apply you t ?=    it   tit te      tet tt tt  e   te  ttee  tou t
# VAL:: loss: 2.7142 accuracy: 0.2867
#
# 12 9148 2.7976 pred:  the lowest, basest, poorest, Of this most wise re => the lowest, basest, poorest, Of this most wise reb ?= the teu     tet     teu       e thet te   tet  te
# VAL:: loss: 2.7129 accuracy: 0.3067
#
# 12 9648 2.6631 pred: ive good words to thee will flatter Beneath abhorr => ve good words to thee will flatter Beneath abhorri ?= te tou  thu   thuthe  tht  to t     e   thettee
# VAL:: loss: 2.9314 accuracy: 0.2400
#
# 12 10148 2.7380 pred:  A sick man's appetite, who desires most that Whic => A sick man's appetite, who desires most that Which ?=   t te tet   ttee  th  the t   te  teu  thet  hete
# VAL:: loss: 2.6883 accuracy: 0.3067
#
# 13 2327 2.8730 pred: First Citizen: Before we proceed any further, hear => irst Citizen: Before we proceed any further, hear  ?= et   tot te    e     th toe     tt  to   e   te t
# VAL:: loss: 2.9205 accuracy: 0.2467
#
# ...
# VAL:: loss: 2.7729 accuracy: 0.3133
#
# 194 37726 1.2100 pred: ever Appear in your impediment. For the dearth, Th => ver Appear in your impediment. For the dearth, The ?=  er Appear in tour htaltinen   Wor the biari,e Whe
# VAL:: loss: 2.7140 accuracy: 0.3533
#
# 194 38226 1.1384 pred: y wholesome act established against the rich, and  =>  wholesome act established against the rich, and p ?=  sholesore asciisprnlictes anrinst the sechi nnd t
# VAL:: loss: 2.8908 accuracy: 0.2733
#
# 194 38726 1.2516 pred:  our disgrace with a tale: but, an 't please you,  => our disgrace with a tale: but, an 't please you, d ?= tur dissrace aith slthle. wet  nndwt teoete Hou  w
# VAL:: loss: 2.8351 accuracy: 0.3267
#
# 194 39226 1.1680 pred: r'd--  First Citizen: Well, sir, what answer made  => 'd--  First Citizen: Well, sir, what answer made t ?= sd--  First Citizen: Well  tede weot tn wer tak  t
# VAL:: loss: 2.7775 accuracy: 0.3467
#
# 194 39726 1.0758 pred: or heart, the arm our soldier, Our steed the leg,  => r heart, the arm our soldier, Our steed the leg, t ?=   heart, the rre our mtrv,dds Ofr ctend ihe bivo t
# VAL:: loss: 2.8806 accuracy: 0.3133
#
# 194 40226 1.1159 pred: ttle-- Patience awhile, you'll hear the belly's an => tle-- Patience awhile, you'll hear the belly's ans ?= hle-- Patience aneise  wou  l hesr the belly s and
# VAL:: loss: 2.8908 accuracy: 0.3133
#
# 194 40726 1.1627 pred: eart, to the seat o' the brain; And, through the c => art, to the seat o' the brain; And, through the cr ?=  kt, to the stat tn the ceecne Tnd  wheyugh the se
# VAL:: loss: 2.8017 accuracy: 0.3400
#
# 194 41226 0.9483 pred: ?  First Citizen: It was an answer: how apply you  =>   First Citizen: It was an answer: how apply you t ?=   First Citizen: I  tal snswn wer  hem wnlet aou t
# VAL:: loss: 2.8866 accuracy: 0.3200
#
# 194 41726 1.1687 pred:  the lowest, basest, poorest, Of this most wise re => the lowest, basest, poorest, Of this most wise reb ?= the rivest, metese, muor ste Of thes aemt fil  him
# VAL:: loss: 2.7959 accuracy: 0.3333
#
# 194 42226 1.1687 pred: ive good words to thee will flatter Beneath abhorr => ve good words to thee will flatter Beneath abhorri ?= te good worss th the  shtl teit er Becoad  allerse
# VAL:: loss: 2.6996 accuracy: 0.3267
#
# 194 42726 1.2430 pred:  A sick man's appetite, who desires most that Whic => A sick man's appetite, who desires most that Which ?=   sick min's arletitis whi geltnes oo t that Which
# VAL:: loss: 2.8951 accuracy: 0.3067
#
# 195 34905 0.9365 pred: First Citizen: Before we proceed any further, hear => irst Citizen: Before we proceed any further, hear  ?= irst Citizen: Wenore se praue d atd toriies  we r
# VAL:: loss: 2.7042 accuracy: 0.3667
#
# 195 35405 1.3591 pred:  citizens, the patricians good. What authority sur => citizens, the patricians good. What authority surf ?= totizens, the brtricians aood   hat ansh r sh aurs
# VAL:: loss: 2.8812 accuracy: 0.3267
#
# 195 35905 1.0622 pred: Second Citizen: Would you proceed especially again => econd Citizen: Would you proceed especially agains ?= econd Citizen: Weuld you hraue d ar ereanl  anains
# VAL:: loss: 2.7446 accuracy: 0.3533
#
# 195 36405 1.1702 pred: say it was for his country he did it to please his => ay it was for his country he did it to please his  ?= ay pt wel aor mas aountry he pid it to tuaake hish
# VAL:: loss: 2.7069 accuracy: 0.3733
#
# 195 36905 1.1926 pred: itizen: Soft! who comes here?  Second Citizen: Wor => tizen: Soft! who comes here?  Second Citizen: Wort ?= tizen: Toft  The houes aaaes  Fecond Citizen: Weue
# VAL:: loss: 2.9166 accuracy: 0.2867
#
# 195 37405 1.0767 pred: now we have strong arms too.  MENENIUS: Why, maste => ow we have strong arms too.  MENENIUS: Why, master ?= dw we have strong tr   tord  MENENIUS: Whao matt r
# VAL:: loss: 2.7607 accuracy: 0.3333
#
# 195 37905 1.2127 pred: ever Appear in your impediment. For the dearth, Th => ver Appear in your impediment. For the dearth, The ?=  er Appear in tou  ht ltiment  Wor the piare,e Whe
# VAL:: loss: 2.7063 accuracy: 0.3467
#
# 195 38405 1.1285 pred: y wholesome act established against the rich, and  =>  wholesome act established against the rich, and p ?=  tholesooe ait isernlictes anrinst the sechi nnd t
# VAL:: loss: 2.9228 accuracy: 0.2667
#
# 195 38905 1.2324 pred:  our disgrace with a tale: but, an 't please you,  => our disgrace with a tale: but, an 't please you, d ?= tur dissrace aith slthle. iet  nndwt taoete Bou  w
# VAL:: loss: 2.8109 accuracy: 0.3400
#
# 195 39405 1.1628 pred: r'd--  First Citizen: Well, sir, what answer made  => 'd--  First Citizen: Well, sir, what answer made t ?= sd--  First Citizen: Well  tede whot tndwer tok  t
# VAL:: loss: 2.7980 accuracy: 0.3133
#
# 195 39905 1.0879 pred: or heart, the arm our soldier, Our steed the leg,  => r heart, the arm our soldier, Our steed the leg, t ?=   heart, the rre our mtrv,dd  Ofr stend ihe wivo t
# VAL:: loss: 2.9008 accuracy: 0.2800
#
# 195 40405 1.1238 pred: ttle-- Patience awhile, you'll hear the belly's an => tle-- Patience awhile, you'll hear the belly's ans ?= hle-- Patience aieile  tou  l hesr the belly s and
# VAL:: loss: 2.9106 accuracy: 0.3267
#
# 195 40905 1.1544 pred: eart, to the seat o' the brain; And, through the c => art, to the seat o' the brain; And, through the cr ?=  rt, to the geat tn the ceecne Ynd  wheyugh the se
# VAL:: loss: 2.8037 accuracy: 0.3400
#
# 195 41405 0.9488 pred: ?  First Citizen: It was an answer: how apply you  =>   First Citizen: It was an answer: how apply you t ?=   First Citizen: I  tal snswn wer  hew wnlet aou t
# VAL:: loss: 2.9112 accuracy: 0.3000
#
# 195 41905 1.1598 pred:  the lowest, basest, poorest, Of this most wise re => the lowest, basest, poorest, Of this most wise reb ?= the rosest  metese, muor ste Of thes aest fil  him
# VAL:: loss: 2.8030 accuracy: 0.3133
#
# 195 42405 1.1618 pred: ive good words to thee will flatter Beneath abhorr => ve good words to thee will flatter Beneath abhorri ?= te good eorss th the  shtl teit er Becoet  allerse
# VAL:: loss: 2.6977 accuracy: 0.3533
#
# 195 42905 1.2226 pred:  A sick man's appetite, who desires most that Whic => A sick man's appetite, who desires most that Which ?=  lsick mikes anpetite  whasgeltnes aa t that Which
# VAL:: loss: 2.9250 accuracy: 0.2867
#
# 196 35084 0.9256 pred: First Citizen: Before we proceed any further, hear => irst Citizen: Before we proceed any further, hear  ?= irst Citizen: Wenore se praue d atd toriies  we r
# VAL:: loss: 2.6639 accuracy: 0.3800
#
# 196 35584 1.3524 pred:  citizens, the patricians good. What authority sur => citizens, the patricians good. What authority surf ?= totizenst the prtricians aood   hat anshir sh aurs
# VAL:: loss: 2.9303 accuracy: 0.3133
#
# 196 36084 1.0669 pred: Second Citizen: Would you proceed especially again => econd Citizen: Would you proceed especially agains ?= econd Citizen: Weuld you hraue v ar ereanl  anains
# VAL:: loss: 2.7658 accuracy: 0.3400
#
# 196 36584 1.1735 pred: say it was for his country he did it to please his => ay it was for his country he did it to please his  ?= ay it wil aor has aountsy he pid it touTuaake his
# VAL:: loss: 2.6761 accuracy: 0.3733
#
# 196 37084 1.1860 pred: itizen: Soft! who comes here?  Second Citizen: Wor => tizen: Soft! who comes here?  Second Citizen: Wort ?= tizen: Soft  The houes aaae   Fecond Citizen: Weu
# VAL:: loss: 2.8777 accuracy: 0.3133
#
# 196 37584 1.0643 pred: now we have strong arms too.  MENENIUS: Why, maste => ow we have strong arms too.  MENENIUS: Why, master ?= dw we have strong tr   tord  MENENIUS: Whao makt r
# VAL:: loss: 2.7704 accuracy: 0.3467
#
# 196 38084 1.2011 pred: ever Appear in your impediment. For the dearth, Th => ver Appear in your impediment. For the dearth, The ?=  er Appear in tou  ht eaieeno  Wor the ciare,e Whe
# VAL:: loss: 2.7029 accuracy: 0.3467
#
# 196 38584 1.1257 pred: y wholesome act established against the rich, and  =>  wholesome act established against the rich, and p ?=  tholeseme ast iseanlictes anainst the sechi nnd t
# VAL:: loss: 2.8983 accuracy: 0.2800
#
# 196 39084 1.2230 pred:  our disgrace with a tale: but, an 't please you,  => our disgrace with a tale: but, an 't please you, d ?= tur dissrace aith slthle. wet  nndwt teoete Tour w
# VAL:: loss: 2.7753 accuracy: 0.3533
#
# 196 39584 1.1531 pred: r'd--  First Citizen: Well, sir, what answer made  => 'd--  First Citizen: Well, sir, what answer made t ?= sd--  First Citizen: Well  tede whot tn wer take t
# VAL:: loss: 2.7686 accuracy: 0.3333
#
# 196 40084 1.0796 pred: or heart, the arm our soldier, Our steed the leg,  => r heart, the arm our soldier, Our steed the leg, t ?=   heart, the rre our strl,dr  Ofr cuand ihe bivo t
# VAL:: loss: 2.9335 accuracy: 0.3000
#
# 196 40584 1.1273 pred: ttle-- Patience awhile, you'll hear the belly's an => tle-- Patience awhile, you'll hear the belly's ans ?= hle-- Patience anhile  iou ll hesr the belly s and
# VAL:: loss: 2.8781 accuracy: 0.3400
#
# 196 41084 1.1702 pred: eart, to the seat o' the brain; And, through the c => art, to the seat o' the brain; And, through the cr ?=  rt, to the seav on the ceecne Tnd  wheyugh the sh
# VAL:: loss: 2.8465 accuracy: 0.3333
#
# 196 41584 0.9543 pred: ?  First Citizen: It was an answer: how apply you  =>   First Citizen: It was an answer: how apply you t ?=   First Citizen: C  tal snswnster  he  wnlet aou t
# VAL:: loss: 2.9188 accuracy: 0.3067
#
# 196 42084 1.1684 pred:  the lowest, basest, poorest, Of this most wise re => the lowest, basest, poorest, Of this most wise reb ?= the ronest, metest, moor st  Of thes aest tit  hem
# VAL:: loss: 2.8665 accuracy: 0.3333
#
# 196 42584 1.1725 pred: ive good words to thee will flatter Beneath abhorr => ve good words to thee will flatter Beneath abhorri ?= te good eorss th the  shtl teit er Benoet  alleree
# VAL:: loss: 2.7042 accuracy: 0.3333
#
# 196 43084 1.2431 pred:  A sick man's appetite, who desires most that Whic => A sick man's appetite, who desires most that Which ?=  lsick mikee anpetite  wha geaenes yo t that Which
# VAL:: loss: 2.9318 accuracy: 0.3000
#
# 197 35263 0.9451 pred: First Citizen: Before we proceed any further, hear => irst Citizen: Before we proceed any further, hear  ?= irst Citizen: Wenore se praue d atd toriies  we r
# VAL:: loss: 2.6310 accuracy: 0.3667
#
# 197 35763 1.3456 pred:  citizens, the patricians good. What authority sur => citizens, the patricians good. What authority surf ?= totizens, the prtricians aood   hat ansher sh aura
# VAL:: loss: 2.9174 accuracy: 0.3200
#
# 197 36263 1.0652 pred: Second Citizen: Would you proceed especially again => econd Citizen: Would you proceed especially agains ?= econd Citizen: Whuld yourhraue d ar ereanl  anains
# VAL:: loss: 2.7872 accuracy: 0.3333
#
# 197 36763 1.1862 pred: say it was for his country he did it to please his => ay it was for his country he did it to please his  ?= ,y it whl aor has aomntsy he pid it to toaade his
# VAL:: loss: 2.6397 accuracy: 0.3600
#
# 197 37263 1.2531 pred: itizen: Soft! who comes here?  Second Citizen: Wor => tizen: Soft! who comes here?  Second Citizen: Wort ?= tizen: Oof   The domes aaaes  Fecond Citizen: Ih
# VAL:: loss: 2.9849 accuracy: 0.2867
#
# 197 37763 1.0699 pred: now we have strong arms too.  MENENIUS: Why, maste => ow we have strong arms too.  MENENIUS: Why, master ?= dw we have strong on   tord  MENENIUS: Wha  matt r
# VAL:: loss: 2.7608 accuracy: 0.3467
#
# 197 38263 1.1907 pred: ever Appear in your impediment. For the dearth, Th => ver Appear in your impediment. For the dearth, The ?=  er Appear in tour htalaiten   Wor the ciars,e Whe
# VAL:: loss: 2.6426 accuracy: 0.3600
#
# 197 38763 1.1308 pred: y wholesome act established against the rich, and  =>  wholesome act established against the rich, and p ?=  tholeseoe ast iseanlictes anrinst the sechi wnd t
# VAL:: loss: 2.9293 accuracy: 0.2933
#
# 197 39263 1.2402 pred:  our disgrace with a tale: but, an 't please you,  => our disgrace with a tale: but, an 't please you, d ?= tur dishrace aith slthye. iut  nndwt teoene Tour w
# VAL:: loss: 2.7661 accuracy: 0.3533
#
# 197 39763 1.1469 pred: r'd--  First Citizen: Well, sir, what answer made  => 'd--  First Citizen: Well, sir, what answer made t ?= sd--  First Citizen: Well  tede weot sn wer take t
# VAL:: loss: 2.7450 accuracy: 0.3400
#
# 197 40263 1.0673 pred: or heart, the arm our soldier, Our steed the leg,  => r heart, the arm our soldier, Our steed the leg, t ?=   heart, the rrt our surl,dss Ofr suend ihe wevo t
# VAL:: loss: 2.9135 accuracy: 0.2800
#
# 197 40763 1.1208 pred: ttle-- Patience awhile, you'll hear the belly's an => tle-- Patience awhile, you'll hear the belly's ans ?= hle-- Patiense anh le  wou ll hesr the belly s and
# VAL:: loss: 2.9010 accuracy: 0.3067
#
# 197 41263 1.1849 pred: eart, to the seat o' the brain; And, through the c => art, to the seat o' the brain; And, through the cr ?=  rt, to the geat tn the ceecne Ynd  theyugh the sr
# VAL:: loss: 2.8682 accuracy: 0.3133
#
# 197 41763 0.9792 pred: ?  First Citizen: It was an answer: how apply you  =>   First Citizen: It was an answer: how apply you t ?=   First Citizen: I  tal snswnster: hes snlet aourt
# VAL:: loss: 2.9170 accuracy: 0.2800
#
# 197 42263 1.1697 pred:  the lowest, basest, poorest, Of this most wise re => the lowest, basest, poorest, Of this most wise reb ?= the risest  metest, maorsste Of thes aest til  tim
# VAL:: loss: 2.8398 accuracy: 0.3333
#
# 197 42763 1.1619 pred: ive good words to thee will flatter Beneath abhorr => ve good words to thee will flatter Beneath abhorri ?= te good eorss th the  shtl teit er Benoet  allerse
# VAL:: loss: 2.7640 accuracy: 0.3400
#
# 197 43263 1.2277 pred:  A sick man's appetite, who desires most that Whic => A sick man's appetite, who desires most that Which ?=  lsick min s anletitis whisgiatnes aa t that Whinh
# VAL:: loss: 2.9633 accuracy: 0.2933
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 181
#     179 x = decode(xtokens_batch[0]).replace('\n', ' ')
#     180 y = decode(ytokens_batch[0]).replace('\n', ' ')
# --> 181 yhat = decode(prediction_batch[0]).replace('\n', ' ')
#     182 print(epoch, epoch * samples + i, f"{step_loss:1.4f}", "pred:", x, "=>", y, "?=", yhat)
#     183 print("VAL::", f"loss: {val_loss:1.4f}", f"accuracy: {val_accuracy:1.4f}" )
#
# Cell In[3], line 11, in <lambda>(tokens)
#       9 token_to_char = dict(enumerate(vocab))
#      10 char_to_token = dict([(v, k) for k, v in token_to_char.items()])
# ---> 11 decode = lambda tokens: "".join([token_to_char[int(token)] for token in tokens])
#      12 encode = lambda chars: jnp.array([char_to_token[c] for c in chars])
#      14 print("dog", encode("dog"), decode(encode("dog")))
#
# Cell In[3], line 11, in <listcomp>(.0)
#       9 token_to_char = dict(enumerate(vocab))
#      10 char_to_token = dict([(v, k) for k, v in token_to_char.items()])
# ---> 11 decode = lambda tokens: "".join([token_to_char[int(token)] for token in tokens])
#      12 encode = lambda chars: jnp.array([char_to_token[c] for c in chars])
#      14 print("dog", encode("dog"), decode(encode("dog")))
#
# File ~/Desktop/ai_gym/.venv/lib/python3.10/site-packages/jax/_src/array.py:302, in ArrayImpl.__int__(self)
#     300 def __int__(self):
#     301   core.check_scalar_conversion(self)
# --> 302   return self._value.__int__()
#
# File ~/Desktop/ai_gym/.venv/lib/python3.10/site-packages/jax/_src/profiler.py:333, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     330 @wraps(func)
#     331 def wrapper(*args, **kwargs):
#     332   with TraceAnnotation(name, **decorator_kwargs):
# --> 333     return func(*args, **kwargs)
#     334   return wrapper
#
# File ~/Desktop/ai_gym/.venv/lib/python3.10/site-packages/jax/_src/array.py:628, in ArrayImpl._value(self)
#     626 if self._npy_value is None:
#     627   if self.is_fully_replicated:
# --> 628     self._npy_value = self._single_device_array_to_np_array()
#     629     self._npy_value.flags.writeable = False
#     630     return cast(np.ndarray, self._npy_value)
#
# KeyboardInterrupt:

# %%
def inference(key, chars):
  xtokens = encode(chars)
  xembed = jax.nn.one_hot(xtokens, len(vocab))[None, :] # artificial single batch
  logits = lstm_forward(xembed.shape[0], lstm_params, xembed)[0][-1] # logits of the first B and last T in the B T C. should be (C,)
  yhattokens = random.choice(key, a=logits.shape[0], p=jax.nn.softmax(logits)) # no need for axis=-1 since logits are (C,)
  sequence = yhattokens
  return sequence

steps = 1000
keys = random.split(random.PRNGKey(121233), steps)
temperature = 0.5
text = "a"*50
print(text, end='')
for i in range(steps):
  yseq = inference(keys[i], text[-sequence_length:])
  next_char = decode([yseq])[-1]
  text += next_char
  print(next_char, end='')
# Out:
# aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaathiost Catizen:
# To hare atreabror
# it te'e, shere to die diceave thie
# seef in, sufarebs you hilp bil singre. He ars uspreite be af yiur make, though the what's an
# beromy wis af
# pitle?
#
# Secoun;
# Cicizen:
# Ye make it wankeve' the Mart it us is foreids ans gobre, in cumant, and ofrbeis deremit oowe ars you affericis ue and wim nourt ie whond rikinh hour;ay weal, he pave prabead.
# Butatgeng, she sead we! 's the suais abe you caverit; ant thee,
# The, you mave, way, avenery, well ag make you herenowh your mone fort,
# Unat he matse be one hask hise fis thing mpeat; ug, you thay whole soo't, and
# The praciunge the are weak's theowe ditizen:
# 'Thear be ankent, the sunfres,
# Benowe dise fare.
#
# Seiy.
#
# Secofl.
# Seving Cavield you anattily wall of iallyI my,e ghis byow
# For cike ith abeid ao' thiong reming
# you is and of off bin whike hay in the pagricivino goon.
# IW shas henkad ut, you arvenowe are updeecm furis.
# Whe'ss rempit baurin the will? courtr suand ricpist e apreflood.
# Hain to theares,
# Thay suplerien w

# %%
jax.tree_util.tree_map(jnp.linalg.norm, grads)
# Out:
# [{'bC': Array(0.00382806, dtype=float32),
#   'bF1': Array(0.00067422, dtype=float32),
#   'bF2': Array(0.00351771, dtype=float32),
#   'bO': Array(0.00102159, dtype=float32),
#   'bU': Array(0.00061966, dtype=float32),
#   'bY1': Array(0., dtype=float32),
#   'bY2': Array(0., dtype=float32),
#   'c0': Array(0.00768698, dtype=float32),
#   'h0': Array(0.00609007, dtype=float32),
#   'wC': Array(0.00712224, dtype=float32),
#   'wF1': Array(0.00125441, dtype=float32),
#   'wF2': Array(0.00654482, dtype=float32),
#   'wO': Array(0.0019007, dtype=float32),
#   'wU': Array(0.0011529, dtype=float32),
#   'wY1': Array(0., dtype=float32),
#   'wY2': Array(0., dtype=float32)},
#  {'bC': Array(0.00296637, dtype=float32),
#   'bF1': Array(0.00067843, dtype=float32),
#   'bF2': Array(0.00304542, dtype=float32),
#   'bO': Array(0.06423178, dtype=float32),
#   'bU': Array(0.00065218, dtype=float32),
#   'bY1': Array(0.08539081, dtype=float32),
#   'bY2': Array(0., dtype=float32),
#   'wC': Array(0.0122483, dtype=float32),
#   'wF1': Array(0.00278899, dtype=float32),
#   'wF2': Array(0.01255963, dtype=float32),
#   'wO': Array(0.31585217, dtype=float32),
#   'wU': Array(0.00270591, dtype=float32),
#   'wY1': Array(0.42604887, dtype=float32),
#   'wY2': Array(0., dtype=float32)}]
