# %% [markdown]
# experiment: first, train it on my posts
# make a language one first
#
# then.. hmm, not sure?
#
# maybe make a small one that can play a game at super low res? and RL it?
#
# have one that determines reward/punishment and one that decides actions?
# not sure lol but i want to win at panda bomber

# %%
import jax
import jax.numpy as jnp
import jax.random as jrand
import optax
import functools # for partial


dataset_path = "../data/shakespeare.txt"
with open(dataset_path, 'r') as f:
  dataset_chars = f.read()


vocab = list(set(dataset_chars))
vocab_size = len(vocab)



token_to_char_dict = dict(enumerate(vocab))
char_to_token_dict = (dict([(b, a) for a, b in token_to_char_dict.items()]))

encode = lambda word: jnp.array([char_to_token_dict[c] for c in word])
decode = lambda tokens: "".join([token_to_char_dict[t] for t in tokens.tolist()])

test_word = "lmaoooo"
print(test_word, encode(test_word), decode(encode(test_word)))


dataset = encode(dataset_chars)
split = 0.9
dataset_token_count = len(dataset)
split_idx = int(dataset_token_count*0.9)

train_data = dataset[:split_idx]
test_data = dataset[split_idx:]


def init_model_params(key, attention_blocks, model_dim, kq_dim, forward_mlp_hidden_layers, embedding_table_hidden_layers, vocab_size, output_mlp_hidden_layers, attention_heads):
  # inits model params
  # function body logic:
  #   generate params for the main transformer blocks
  #   the embed table
  #   and the final output MLP

  key_types = 3 # (+ 3) + len(embedding_table_hidden_layers)*2)*100
  keys = jrand.split(key, key_types)
  # weight initialization functions
  # he for sigmoid, xavier for tanh
  he = lambda rkey, shape : jrand.normal(rkey, shape) * jnp.sqrt(2.0 / shape[0])
  xavier = lambda rkey, shape : jrand.normal(rkey, shape) * jnp.sqrt(2.0 / (shape[0] + shape[1]))

  # mlp takes an input embedding and outputs an embedding.
  mlp_all_layer_sizes = jax.lax.concatenate([
    jnp.array([model_dim]),
    jnp.array(forward_mlp_hidden_layers),
    jnp.array([model_dim])],
    0
  )
  mlp_all_layer_shapes = [(a, b) for a, b in zip(mlp_all_layer_sizes, mlp_all_layer_sizes[1:])]

  d_q = kq_dim
  d_k = d_q
  d_v = kq_dim # for now

  kqv_key_count = attention_blocks*attention_heads*4
  forward_mlp_key_count = len(forward_mlp_hidden_layers)*2
  attention_block_keys = jrand.split(keys[0], kqv_key_count + forward_mlp_key_count)
  model_params = [
    {
      "attention_params" : [
        {
          "Wq" : xavier(attention_block_keys[attention_block*attention_head + 0], (model_dim, d_q//attention_heads)), # B, T, C => B, T, q
          "Wk" : xavier(attention_block_keys[attention_block*attention_head + 1], (model_dim, d_k//attention_heads)), # B, T, C => B, T, k
          "Wv" : xavier(attention_block_keys[attention_block*attention_head + 2], (model_dim, d_v//attention_heads)), # B, T, C => B, T, V.        B, T, T, @ B, T, V => B, T, V
          "Wout" : xavier(attention_block_keys[attention_block*attention_head + 2], (d_v//attention_heads, model_dim//attention_heads)), # B, T, V => B, T, C  ## i could just have one maybe?
        }
        for attention_head in range(attention_heads)
      ],
      "forward_mlp_params" : [
        {
          "W" : xavier(attention_block_keys[attention_block + layer], shape),
          "b" : he(attention_block_keys[attention_block + layer + 1], (shape[1],)),
        }
        for layer, shape in enumerate(mlp_all_layer_shapes)
      ],
    }
    for attention_block in range(attention_blocks)
  ]

  # embed table params
  embed_table_keys = jrand.split(keys[1], 2*len(embedding_table_hidden_layers))
  embed_table_all_layer_sizes = jax.lax.concatenate([
    jnp.array([vocab_size]),
    jnp.array(embedding_table_hidden_layers),
    jnp.array([model_dim])], 0)
  embed_table_all_layer_shapes = [(a, b) for a, b in zip(embed_table_all_layer_sizes, embed_table_all_layer_sizes[1:])]
  embedding_table_params = [
        {
          "W" : xavier(embed_table_keys[layer + 0], shape),
          "b" : he(embed_table_keys[layer + 1], (shape[1],)),
        }
        for layer, shape in enumerate(embed_table_all_layer_shapes)
  ]

  model_params[0].update({
    "embedding_table_params" : embedding_table_params
  })

  output_mlp_all_layer_sizes = jax.lax.concatenate([
    jnp.array([model_dim]),
    jnp.array(output_mlp_hidden_layers),
    jnp.array([vocab_size])
  ], 0)

  # output MLP params. this takes the contextual embeddings and turns them into logits
  output_mlp_keys = jrand.split(keys[2], 2*len(output_mlp_hidden_layers))
  output_mlp_all_layer_shapes = [(a, b) for a, b in zip(output_mlp_all_layer_sizes, output_mlp_all_layer_sizes[1:])]
  output_mlp_params = [
    {
      "W" : xavier(output_mlp_keys[layer + 0], shape),
      "b" : he(output_mlp_keys[layer + 1], (shape[1],))
    }
    for layer, shape in enumerate(output_mlp_all_layer_shapes)
  ]
  model_params[-1].update({
    "output_mlp_params" : output_mlp_params
  })

  return model_params



# for both the mlp in attention blocks and the final output mlp.
# in fact... i could probably use this for the embed table too. lmao
@jax.jit
def mlp_forward(mlp_params, x_input):
  #linear = lambda x, params: (lambda x, W, b: x @ W + b)(x, params["W"], params["b"])

  # doesnt work if leading axis sizes are different for some reason :(
  #return jax.lax.scan(linear, contextual_embeddings, attention_block_params["forward"])

  x = x_input
  for layer_params in mlp_params:
    x = jax.nn.tanh(x @ layer_params["W"] + layer_params["b"]) # tanh : -1, 1
  
  return x


@functools.partial(jax.jit, static_argnames=["vocab_size"])
def embed_tokens(embedding_table_params, xBT, vocab_size=vocab_size):
  xBTC = jax.nn.one_hot(xBT, num_classes=vocab_size)
  return mlp_forward(embedding_table_params, xBTC)



@jax.jit
def attention(attention_params, d_k, xBTC):
  # iterate through each attention head
  # inefficient but its a start. may optimize later.
  for i, attention_head in enumerate(attention_params):
    Q = xBTC @ attention_head["Wq"] # (B, T, C) @ (C, kq_dim) => (B, T, kq_dim)
    K = xBTC @ attention_head["Wk"] # (B, T, C) @ (C, kq_dim) => (B, T, kq_dim)
    V = xBTC @ attention_head["Wv"] # (B, T, C) @ (C, d_v) => (B, T, d_v)
    attention_table = jax.nn.softmax((Q @ jnp.transpose(K, (0, 2, 1)))/d_k) # (B, T, kq_dim) @ (B, kq_dim, T) => (B, T, T)

    Z = attention_table @ V  #  (B, T, T) @ (B, T, d_v) => (B, T, d_v)
    contextual_update_fragment = Z @ attention_head["Wout"] # (B, T, d_v) @ (d_v, C) => (B, T, C)

    # concat attention heads
    if i == 0:
      contextual_update = contextual_update_fragment
    else:
      contextual_update = jax.lax.concatenate([contextual_update, contextual_update_fragment], 2)

  return contextual_update

def norm(channel):
  epsilon = 1e-7
  return (channel - jnp.mean(channel)) / jnp.sqrt(jnp.var(channel) + epsilon)


def layer_norm(BTC):
  # norm over C
  # var = σ^2
  # we want to divide by the standard deviation
  return jax.vmap(norm, in_axes=-1, out_axes=-1)(BTC)


### forward
@jax.jit
def forward(model_params, xBTC, d_k):
  for attention_block in range(len(model_params)):
    ## attention
    contextual_embeddings = attention(
      model_params[attention_block]["attention_params"],
      d_k,
      xBTC
    ) # B, T, C

    # skip connection or whatever
    mlp_out = mlp_forward(model_params[attention_block]["forward_mlp_params"], contextual_embeddings)
    residual = layer_norm(mlp_out)
    xBTC = xBTC + residual

  # finally, do something with the output
  # doesnt matter what. predict the next token. take the next action. lol its whatever.
  # for now just do next token prediction. implement a normal transformer
  xBTC = mlp_forward(model_params[-1]["output_mlp_params"], xBTC)

  return xBTC


@jax.jit
def inference(key, model_params, xBT, d_k, temperature=0.5):
  embedding_table_params = model_params[0]["embedding_table_params"]
  xBTC = embed_tokens(embedding_table_params, xBT)
  yBTC = forward(model_params, xBTC, d_k)
  next_token_logits = yBTC[0][-1] # the first B and last T in (B, T, C)
  #next_token_probs = jax.nn.softmax(next_token_logits, axis=-1) # (C,)
  # argmax for display
  probs = jax.nn.softmax(next_token_logits / (0.01 + temperature))
  a = jnp.arange(probs.shape[-1])
  return jrand.choice(key, a, replace=True, p=probs, axis=-1)


@jax.jit
def loss_func(model_params, xBT, yB, d_k):
  embedding_table_params = model_params[0]["embedding_table_params"]
  xBTC = embed_tokens(embedding_table_params, xBT)
  yBTC = forward(model_params, xBTC, d_k)
  next_token_logits = yBTC[:, -1, :] # the last T in (B, T, C)
  # honestly this is stupid!!! C is a list of attributes of a token, 'logits' is the wrong datatype, even if theyre both represented as float
  # fuck it just do baseline for now
  next_token_probs = jax.nn.softmax(next_token_logits, axis=-1) # (B, C)
  true_token_probs = jax.nn.one_hot(yB, next_token_probs.shape[-1], axis=-1) # (B, C)
  batch_crossentropy = -true_token_probs * jax.nn.log_softmax(next_token_probs)
  return jnp.mean(batch_crossentropy)


# static args optimizer
@functools.partial(jax.jit, static_argnames=["optimizer"])
def train_step(model_params, xBT, yB, d_k, opt_state, optimizer):
  loss, grads = jax.value_and_grad(loss_func)(model_params, xBT, yB, d_k)
  param_updates, updated_opt_state = optimizer.update(grads, opt_state, model_params)
  updated_model_params = optax.apply_updates(model_params, param_updates)
  return updated_model_params, updated_opt_state, loss, grads



# model params
attention_blocks = 2
attention_heads = 8
model_dim = 512
kq_dim = 1024
d_k = model_dim // attention_heads

forward_mlp_hidden_layers = [
  1024,
  1024,
  1024,
]

output_mlp_hidden_layers = [
  1024,
  1024,
  1024,
]

embedding_table_hidden_layers = [
  1024,
  1024,
  1024
]


# set up training
key = jrand.PRNGKey(112367)
model_params = init_model_params(key, attention_blocks, model_dim, kq_dim, forward_mlp_hidden_layers, embedding_table_hidden_layers, vocab_size, output_mlp_hidden_layers, attention_heads)

lr = 3e-4 # karpathy style
optimizer = optax.adamw(learning_rate=lr)
opt_state = optimizer.init(model_params)


epochs = 1000
train_batch_size = 100
val_batch_size = 100
max_sequence_length = 29 + 1 # xlen + ylen

tokens_per_step = train_batch_size*max_sequence_length




# todo masking
# Out:
# lmaoooo [17 59 29  3  3  3  3] lmaoooo

# %%
for epoch in range(epochs):
  steps = len(train_data) // (tokens_per_step) # idk calculate train_dataset_size // batch_size
  for step in range(steps):
    test_tokens = train_data[step*tokens_per_step:(step+1)*tokens_per_step].reshape(-1, max_sequence_length) # (B, T) where T = max seq len
    xBT = test_tokens[:, :-1] # get all but last token in each sequence
    # i need to turn this into every preceding subsequence. i.e. "abcd" => (xss, ys) => ([a, ab, abc], [b, c, d])
    yB = test_tokens[:, -1] # lol ez
    inference_key = jrand.PRNGKey(epoch * step + step)
    yhat = inference(inference_key, model_params, xBT, d_k)
    model_params, opt_state, loss, grads = train_step(model_params, xBT, yB, d_k, opt_state, optimizer)

    in_chars = decode(xBT[0]).replace('\n', '↵')
    target_char = decode(jnp.array([yB[0]]))
    pred_char = decode(jnp.array([yhat]))

    print(f"{epoch}, {step}, {loss}, '{in_chars}' => '{pred_char}' =?> '{target_char}'")
# Out:
# 0, 0, 0.06378274410963058, 'First Citizen:↵Before we proc' => 'n' =?> 'e'
# 0, 1, 0.0638112798333168, 'ever↵Appear in your impedimen' => 'v' =?> 't'
# 0, 2, 0.06376562267541885, 'eart, to the seat o' the brai' => 'n' =?> 'n'
# 0, 3, 0.0638321116566658, 'usands of these quarter'd sla' => 'r' =?> 'v'
# 0, 4, 0.06387902796268463, 'eads on at noon: but I do won' => 's' =?> 'd'
# 0, 5, 0.06390633434057236, 'ould not↵sell him an hour fro' => 't' =?> 'm'
# 0, 6, 0.06394306570291519, '↵↵VIRGILIA:↵Indeed, no, by yo' => 'a' =?> 'u'
# 0, 7, 0.06381576508283615, 'ow put your shields before yo' => 'r' =?> 'u'
# 0, 8, 0.0637977123260498, ':↵Thy friend no less↵Than tho' => 'o' =?> 's'
# 0, 9, 0.0638524666428566, 'de to endure friends, that yo' => 'e' =?> 'u'
# 0, 10, 0.06382378935813904, ' charter to extol her blood,↵' => ' ' =?> 'W'
# 0, 11, 0.06383182108402252, 'is yours. What is't?↵↵CORIOLA' => 'j' =?> 'N'
# 0, 12, 0.06386390328407288, 'do you?↵↵Both:↵Why, how are w' => 'i' =?> 'e'
# 0, 13, 0.06388010084629059, 'ging of your beards; and your' => 'r' =?> ' '
# 0, 14, 0.06394399702548981, 'IUS:↵Now it's twenty-seven: e' => 's' =?> 'v'
# 0, 15, 0.06383411586284637, 'ort his honours↵From where he' => 'a' =?> ' '
# 0, 16, 0.06381019949913025, 'ixt doing them neither↵good n' => 'a' =?> 'o'
# 0, 17, 0.06381605565547943, 'venture all his limbs for hon' => 'i' =?> 'o'
# 0, 18, 0.0638078898191452, ' from the people.↵↵BRUTUS:↵Ma' => 'o' =?> 'r'
# 0, 19, 0.06385868787765503, '↵CORIOLANUS:↵What must I say?' => 'e' =?> '
# '
# 0, 20, 0.06382395327091217, ' appear,↵Their needless vouch' => 'h' =?> 'e'
# 0, 21, 0.06384923309087753, 'pake against↵Your liberties a' => 'a' =?> 'n'
# 0, 22, 0.06394752860069275, 'ide well in his person wrough' => 'o' =?> 't'
# 0, 23, 0.06391528993844986, 'ss.↵↵CORIOLANUS:↵Why, this wa' => 't' =?> 's'
# 0, 24, 0.06379755586385727, 'e himself!↵It makes the consu' => '?' =?> 'l'
# 0, 25, 0.06396821141242981, 'e dust.↵↵BRUTUS:↵Manifest tre' => 'n' =?> 'a'
# 0, 26, 0.06384988129138947, ' house;↵Leave us to cure this' => 'n' =?> ' '
# 0, 27, 0.06387408822774887, 'at has he done to Rome that's' => ' ' =?> ' '
# 0, 28, 0.06384105980396271, 'hing↵too rough;↵You must retu' => 'n' =?> 'r'
# 0, 29, 0.06385912001132965, ' they have pardons, being ask' => 'a' =?> '''
# 0, 30, 0.06386391073465347, 'dile:↵With old Menenius, and ' => 'o' =?> 't'
# 0, 31, 0.06389506161212921, 'n the people!↵Call me their t' => '3' =?> 'r'
# 0, 32, 0.0639362558722496, ':↵There is a world elsewhere.' => 'e' =?> '
# '
# 0, 33, 0.06385402381420135, 'ods,↵I'ld with thee every foo' => 'r' =?> 't'
# 0, 34, 0.06383875757455826, ''s the↵news in Rome? I have a' => 'e' =?> ' '
# 0, 35, 0.06393937021493912, 'love's upon↵This enemy town. ' => 'i' =?> 'I'
# 0, 36, 0.06381961703300476, '↵Great hurt and mischief; the' => 'i' =?> 'r'
# 0, 37, 0.06388133019208908, 'lf.↵↵CORIOLANUS:↵You bless me' => 'i' =?> ','
# 0, 38, 0.06382055580615997, 'nd but one half of what he wa' => 'w' =?> 's'
# 0, 39, 0.06385032087564468, 'neighbours: we wish'd Coriola' => 'a' =?> 'n'
# 0, 40, 0.06385017186403275, 'ow, your news?↵You have made ' => 't' =?> 'f'
# 0, 41, 0.06380774080753326, 'ue which they so seem to fear' => 't' =?> '.'
# 0, 42, 0.06388984620571136, ' was sometime his general; wh' => 'n' =?> 'o'
# 0, 43, 0.06381591409444809, ''d me↵Thus, with his speechle' => 'r' =?> 's'
# 0, 44, 0.06385821104049683, '↵I let forth your half-pint o' => ' ' =?> 'f'
# 0, 45, 0.06387084722518921, 'e, indeed. Their latest refug' => 'r' =?> 'e'
# 0, 46, 0.06382623314857483, 'tors to you.↵↵CORIOLANUS:↵I b' => 'e' =?> 'e'
# 0, 47, 0.0638321042060852, 'a name,↵Whose repetition will' => 't' =?> ' '
# 0, 48, 0.06382624059915543, 'ible for you to displace it w' => 'a' =?> 'i'
# 0, 49, 0.06385724991559982, 'ods,↵And make triumphant fire' => 'r' =?> 's'
# 0, 50, 0.06385818868875504, 'ords.↵↵All The Lords:↵You are' => 'e' =?> ' '
# 0, 51, 0.0639166533946991, 'peace!↵The man is noble and h' => ' ' =?> 'i'
# 0, 52, 0.06378598511219025, 'am subtle, false and treacher' => 'o' =?> 'o'
# 0, 53, 0.06388009339570999, 'ur grace to pardon me, and wi' => ' ' =?> 't'
# 0, 54, 0.06385371834039688, 'r Anne,↵Wife to thy Edward, t' => '-' =?> 'o'
# 0, 55, 0.06393473595380783, 'ul, when angels are so angry.' => 'i' =?> '
# '
# 0, 56, 0.06390323489904404, ' would I were, to be revenged' => 'a' =?> ' '
# 0, 57, 0.06385789811611176, 'Well, well, put up your sword' => 'e' =?> '.'
# 0, 58, 0.0637657567858696, 'him worse:↵Therefore, for God' => 'n' =?> '''
# 0, 59, 0.06384091079235077, 'ward actions shows itself↵Aga' => 'e' =?> 'i'
# 0, 60, 0.06384693086147308, 're now, and what you are;↵Wit' => 'a' =?> 'h'
# 0, 61, 0.06384707242250443, 'ses pierce the clouds and ent' => 'o' =?> 'e'
# 0, 62, 0.06383303552865982, 'urrent.↵O, that your young no' => 'i' =?> 'b'
# 0, 63, 0.0638878270983696, ' and you, my noble lords.↵↵QU' => 'i' =?> 'E'
# 0, 64, 0.06385016441345215, 'tom of the deep,↵And mock'd t' => 'H' =?> 'h'
# 0, 65, 0.06386203318834305, '↵Second Murderer:↵What, shall' => 'a' =?> ' '
# 0, 66, 0.06391927599906921, 'rderer:↵My voice is now the k' => 'e' =?> 'i'
# 0, 67, 0.0638078823685646, 'ates you.↵↵CLARENCE:↵O, no, h' => 'n' =?> 'e'
# 0, 68, 0.0638512447476387, 'EDWARD IV:↵Take heed you dall' => 'o' =?> 'y'
# 0, 69, 0.06385310739278793, 'o him injury to scorn his cor' => 'r' =?> 's'
# 0, 70, 0.06385602802038193, 'call us wretches, orphans, ca' => 'r' =?> 's'
# 0, 71, 0.06385818868875504, 'ar lord Clarence!↵↵DUCHESS OF' => '?' =?> ' '
# 0, 72, 0.06380543857812881, 'ould fetch the prince.↵↵HASTI' => 'i' =?> 'N'
# 0, 73, 0.06391405314207077, 'cond Citizen:↵Marry, we were ' => ' ' =?> 's'
# 0, 74, 0.06386621296405792, ' down my sons were toss'd,↵Fo' => 's' =?> 'r'
# 0, 75, 0.06394658982753754, 'To those whose dealings have ' => 'e' =?> 'd'
# 0, 76, 0.06391096115112305, 'ich is no grief to give.↵↵GLO' => 't' =?> 'U'
# 0, 77, 0.06388502568006516, 'yself shalt highly be employ'' => 'a' =?> 'd'
# 0, 78, 0.0638478547334671, 'TESBY:↵Ay, on my life; and ho' => 'e' =?> 'p'
# 0, 79, 0.06383304297924042, 'all my heart.↵I am in your de' => 't' =?> 'b'
# 0, 80, 0.06384091079235077, ' come upon your cue, my lord↵' => 'e' =?> 'W'
# 0, 81, 0.06383088231086731, 're triumphing at mine enemies' => 'n' =?> ','
# 0, 82, 0.06383997946977615, ' never look'd for better at h' => ' ' =?> 'i'
# 0, 83, 0.0638091191649437, 'l as long a-doing:↵And yet wi' => 'a' =?> 't'
# 0, 84, 0.0638313740491867, 'th entreat your grace;↵To vis' => 'n' =?> 'i'
# 0, 85, 0.06383317708969116, '↵And almost shoulder'd in the' => 'o' =?> ' '
# 0, 86, 0.06382393836975098, 'Mayor:↵Do, good my lord, your' => 'e' =?> ' '
# 0, 87, 0.06383688747882843, 'trary.↵↵QUEEN ELIZABETH:↵The ' => ' ' =?> 'k'
# 0, 88, 0.06394506990909576, 'curse,↵Which ever since hath ' => 'n' =?> 'k'
# 0, 89, 0.06387423723936081, ' parts beyond the sea↵Where h' => 'r' =?> 'e'
# 0, 90, 0.06388118118047714, 'ed me.↵↵KING RICHARD III:↵Wel' => 'e' =?> 'l'
# 0, 91, 0.06385616958141327, 'to dull delay;↵Delay leads im' => 'i' =?> 'p'
# 0, 92, 0.06388811767101288, 'QUEEN MARGARET:↵Bear with me;' => 'i' =?> ' '
# 0, 93, 0.06384893506765366, 'UCHESS OF YORK:↵Why should ca' => 'w' =?> 'l'
# 0, 94, 0.063883475959301, 'll perish↵And never look upon' => 't' =?> ' '
# 0, 95, 0.06385941803455353, ' what dignity, what honour,↵C' => 'o' =?> 'a'
# 0, 96, 0.06390387564897537, 'ge.↵The loss you have is but ' => 'n' =?> 'a'
# 0, 97, 0.06391002982854843, ', by my George, my garter, an' => 'a' =?> 'd'
# 0, 98, 0.06381713598966599, 'in my daughter to thy will?↵↵' => 'n' =?> 'K'
# 0, 99, 0.06384336203336716, 'reign:↵Please it your majesty' => 't' =?> ' '
# 0, 100, 0.06378180533647537, ' Blunt,↵And Rice ap Thomas wi' => 's' =?> 't'
# 0, 101, 0.06386419385671616, 'gracious liege.↵↵KING RICHARD' => 'r' =?> ' '
# 0, 102, 0.0638580322265625, 'from troop to troop↵Went thro' => '3' =?> 'u'
# 0, 103, 0.06382885575294495, 'peak well: fool, do not flatt' => 'r' =?> 'e'
# 0, 104, 0.06381805986166, 'you do fight in safeguard of ' => 'n' =?> 'y'
# 0, 105, 0.06385833024978638, 'And I will stand the hazard o' => ' ' =?> 'f'
# 0, 106, 0.06379785388708115, ' liege!↵↵THOMAS MOWBRAY:↵Each' => 't' =?> ' '
# 0, 107, 0.06375402212142944, 's↵In name of lendings for you' => 'o' =?> 'r'
# 0, 108, 0.06380803138017654, 'd.↵Good uncle, let this end w' => 'r' =?> 'h'
# 0, 109, 0.06389506161212921, 'l full of Edward's sacred blo' => ' ' =?> 'o'
# 0, 110, 0.0638822540640831, 's arrival here in arms:↵Ask h' => 'a' =?> 'i'
# 0, 111, 0.06386268138885498, 'furbish new the name of John ' => 's' =?> 'a'
# 0, 112, 0.06390495598316193, ' the stranger paths of banish' => ' ' =?> 'm'
# 0, 113, 0.0638686865568161, 'ozen winter spent,↵Return wit' => 'u' =?> 'h'
# 0, 114, 0.06384105980396271, 'ut that I was a journeyman to' => 'a' =?> ' '
# 0, 115, 0.06384105235338211, 'o an oyster-wench;↵A brace of' => ' ' =?> ' '
# 0, 116, 0.06384214013814926, ' last,↵For violent fires soon' => 'a' =?> ' '
# 0, 117, 0.06384090334177017, ' thy anointed body to the cur' => 'n' =?> 'e'
# 0, 118, 0.06383997201919556, 'ent? ah, how long↵Shall tende' => 't' =?> 'r'
# 0, 119, 0.06384706497192383, 'speak thy mind; and let him n' => 'o' =?> 'e'
# 0, 120, 0.06377855688333511, ''d crown,↵Wipe off the dust t' => 'e' =?> 'h'
# 0, 121, 0.06385710090398788, 'oke his staff, resign'd his s' => 't' =?> 't'
# 0, 122, 0.06387113779783249, 'g commons: for their love↵Lie' => 'i' =?> 's'
# 0, 123, 0.06385724991559982, ' approved service and desert.' => 'D' =?> '
# '
# 0, 124, 0.06383411586284637, 'KE OF YORK:↵Even in condition' => 's' =?> ' '
# 0, 125, 0.06383303552865982, 'e will disperse ourselves: fa' => 's' =?> 'r'
# 0, 126, 0.06379399448633194, 'MERLE:↵Yea, my lord. How broo' => 'i' =?> 'k'
# 0, 127, 0.06387422978878021, ' lord,↵Hath clouded all thy h' => 'o' =?> 'a'
# 0, 128, 0.06391927599906921, ' heart!↵Three Judases, each o' => 'a' =?> 'n'
# 0, 129, 0.06386512517929077, ' by my dull and heavy eye,↵My' => 'o' =?> ' '
# 0, 130, 0.06383288651704788, 's of blood↵Rain'd from the wo' => 'u' =?> 'u'
# 0, 131, 0.06381251662969589, 'her hath no further scope↵Tha' => 's' =?> 'n'
# 0, 132, 0.06384105235338211, 'g Phaethon,↵Wanting the manag' => 'i' =?> 'e'
# 0, 133, 0.06383968144655228, 'in our commonwealth:↵All must' => 'o' =?> ' '
# 0, 134, 0.06379877775907516, 'plants thou graft'st may neve' => ';' =?> 'r'
# 0, 135, 0.063824862241745, 'heaven, I'll throw at all:↵I ' => 'i' =?> 'h'
# 0, 136, 0.06384120136499405, 't Richard's subject?↵Thieves ' => 'e' =?> 'a'
# 0, 137, 0.06387314945459366, 'KE:↵I thought you had been wi' => 'i' =?> 'l'
# 0, 138, 0.06389506161212921, 'iven me at the font,↵But 'tis' => 'n' =?> ' '
# 0, 139, 0.06387192010879517, 'me; the children yet unborn.↵' => 'o' =?> 'S'
# 0, 140, 0.06383875012397766, 'roke ascends my throne,↵The t' => 'o' =?> 'i'
# 0, 141, 0.06387005001306534, 'e thee! welcome, Bolingbroke!' => 'i' =?> '''
# 0, 142, 0.06392809003591537, 'ine honour, by my life, by my' => ' ' =?> ' '
# 0, 143, 0.06383302807807922, ', that he stares and looks↵So' => 'a' =?> ' '
# 0, 144, 0.06389027833938599, 'NRY BOLINGBROKE:↵Rise up, goo' => 'a' =?> 'd'
# 0, 145, 0.0637606754899025, 'r, did he not?↵↵Servant:↵He d' => 't' =?> 'i'
# 0, 146, 0.0638788640499115, ' his heart that gives it me!↵' => ' ' =?> 'F'
# 0, 147, 0.06392838060855865, 'r taking may appear↵At large ' => 'e' =?> 'd'
# 0, 148, 0.0638657808303833, 's, and cut off their heads.↵↵' => ':' =?> 'G'
# 0, 149, 0.06388811767101288, 'For this time, all the rest d' => 'n' =?> 'e'
# 0, 150, 0.06382716447114944, '↵↵ROMEO:↵Out--↵↵BENVOLIO:↵Of ' => ' ' =?> 'l'
# 0, 151, 0.06380880624055862, 'ir;↵He that is strucken blind' => 'r' =?> ' '
# 0, 152, 0.06390200555324554, ' you have learned it without ' => 's' =?> 'b'
# 0, 153, 0.063849076628685, '-I never shall forget it,--↵O' => 'n' =?> 'f'
# 0, 154, 0.06383997201919556, 'y's eyes doth share the glory' => ' ' =?> ','
# 0, 155, 0.06378272920846939, 'ight.↵↵MERCUTIO:↵And so did I' => 'i' =?> '.'
# 0, 156, 0.06392192840576172, ' manners shall lie all in one' => 'i' =?> ' '
# 0, 157, 0.06386727839708328, ' take no note of him:↵It is m' => 'r' =?> 'y'
# 0, 158, 0.063824862241745, ' of love it is to me,↵That I ' => 'e' =?> 'm'
# 0, 159, 0.06379739940166473, 'air than she:↵Be not her maid' => ' ' =?> ','
# 0, 160, 0.06386296451091766, 'from their sight;↵And but tho' => 'o' =?> 'u'
# 0, 161, 0.06378719955682755, ' a dream,↵Too flattering-swee' => 't' =?> 't'
# 0, 162, 0.06382731348276138, 'e qualities:↵For nought so vi' => 'i' =?> 'l'
# 0, 163, 0.06389012932777405, 'ing, pupil mine.↵↵ROMEO:↵And ' => 'T' =?> 'b'
# 0, 164, 0.06383349746465683, 'MERCUTIO:↵That's as much as t' => 'i' =?> 'o'
# 0, 165, 0.06381604820489883, 'OLIO:↵She will indite him to ' => 'r' =?> 's'
# 0, 166, 0.06379985809326172, 'lady--Lord,↵Lord! when 'twas ' => 's' =?> 'a'
# 0, 167, 0.06381590664386749, ' what a head have I!↵It beats' => 'o' =?> ' '
# 0, 168, 0.06383875012397766, 'stay alone↵Till holy church i' => 'n' =?> 'n'
# 0, 169, 0.06380558013916016, ' such a greeting: villain am ' => 't' =?> 'I'
# 0, 170, 0.06382949650287628, 'didst consort him here,↵Shalt' => ' ' =?> ' '
# 0, 171, 0.06381899863481522, ' and attend our will:↵Mercy b' => 't' =?> 'u'
# 0, 172, 0.06388811767101288, ' and my dearer lord?↵Then, dr' => 'r' =?> 'e'
# 0, 173, 0.06387902051210403, 'and I; for Romeo is exiled:↵H' => 'e' =?> 'e'
# 0, 174, 0.06381064653396606, ':↵Yet 'banished'? Hang up phi' => ';' =?> 'l'
# 0, 175, 0.06374955177307129, 'll,↵And usest none in that tr' => 'W' =?> 'u'
# 0, 176, 0.06379089504480362, 'love;↵And bid her, mark you m' => 'r' =?> 'e'
# 0, 177, 0.06395554542541504, 'greetings, love, to thee.↵↵JU' => 'e' =?> 'L'
# 0, 178, 0.06384461373090744, ' Saint Peter's Church and Pet' => 'r' =?> 'e'
# 0, 179, 0.06377578526735306, ' demesnes, youthful, and nobl' => 'i' =?> 'y'
# 0, 180, 0.06388332694768906, 'ps for Tybalt's death,↵And th' => 'o' =?> 'e'
# 0, 181, 0.06382623314857483, 'undertake↵A thing like death ' => 's' =?> 't'
# 0, 182, 0.06381604820489883, 'h merry look.↵↵CAPULET:↵How n' => ' ' =?> 'o'
# 0, 183, 0.06391298025846481, 'omeo comes?↵Or, if I live, is' => ' ' =?> ' '
# 0, 184, 0.06380202621221542, 'l-a-day, that ever I was born' => 'o' =?> '!'
# 0, 185, 0.06391513347625732, 'ay bear her to church:↵For th' => 'n' =?> 'o'
# 0, 186, 0.06379586458206177, 'And breathed such life with k' => 't' =?> 'i'
# 0, 187, 0.06381575018167496, ' poverty, and not thy will.↵↵' => 'a' =?> 'A'
# 0, 188, 0.0638236328959465, 'o behold my lady's face;↵But ' => 'r' =?> 'c'
# 0, 189, 0.0638367310166359, 'o sunder his that was thine e' => ' ' =?> 'n'
# 0, 190, 0.06383425742387772, 'estorative.↵Thy lips are warm' => 'r' =?> '.'
# 0, 191, 0.06384677439928055, 'd, was husband to that Juliet' => 'I' =?> ';'
# 0, 192, 0.06382191181182861, ' while Verona by that name is' => 'e' =?> ' '
# 0, 193, 0.06388934701681137, 'thy father.↵And thine, Lord C' => 't' =?> 'l'
# 0, 194, 0.06392621994018555, 'n from the usurper's head.↵↵E' => 'a' =?> 'D'
# 0, 195, 0.06385385990142822, 'ast thou injured both thyself' => ' ' =?> ' '
# 0, 196, 0.06388348340988159, ' safe? such safety finds↵The ' => 's' =?> 't'
# 0, 197, 0.06384461373090744, '? I cannot rest↵Until the whi' => 'n' =?> 't'
# 0, 198, 0.06382191926240921, 'r's blood open it again:↵He i' => ' ' =?> 's'
# 0, 199, 0.06381251662969589, 'FORD:↵So cowards fight when t' => '?' =?> 'h'
# 0, 200, 0.06377147138118744, 'ory,↵And rob his temples of t' => 's' =?> 'h'
# 0, 201, 0.06385695934295654, 'not for my life but weep with' => 'i' =?> ' '
# 0, 202, 0.06386297196149826, 'r'd oak.↵By many hands your f' => 'e' =?> 'a'
# 0, 203, 0.06383796781301498, 'ides fiercely fought:↵But whe' => 'o' =?> 't'
# 0, 204, 0.063908651471138, ',' if Warwick bid him stay.↵↵' => 't' =?> 'E'
# 0, 205, 0.0638270229101181, '↵But, Clifford, tell me, dids' => 'v' =?> 't'
# 0, 206, 0.06376466900110245, 'e.↵↵NORTHUMBERLAND:↵No, nor y' => 'i' =?> 'o'
# 0, 207, 0.06385185569524765, ' any longer conference,↵Since' => 'e' =?> ' '
# 0, 208, 0.06382068991661072, 'tland; both bound to revenge,' => ' ' =?> '
# '
# 0, 209, 0.06373149901628494, 'an doth me.↵Who's this? O God' => 'e' =?> '!'
# 0, 210, 0.06383519619703293, 'bull:↵Away! for death doth ho' => 'o' =?> 'l'
# 0, 211, 0.06393010169267654, 'rk fetch down the head,↵Your ' => ' ' =?> 'f'
# 0, 212, 0.06384091079235077, 'ill, so both may shoot.↵↵Firs' => 'o' =?> 't'
# 0, 213, 0.06385616958141327, ' go along with us; for as we ' => 't' =?> 't'
# 0, 214, 0.06389613449573517, '↵↵LADY GREY:↵Therefore I came' => 'e' =?> ' '
# 0, 215, 0.06381821632385254, '↵↵KING EDWARD IV:↵Brothers, y' => 'i' =?> 'o'
# 0, 216, 0.0638899877667427, ',↵That rends the thorns and i' => 'r' =?> 's'
# 0, 217, 0.06381496787071228, 'proacheth boldly to our prese' => 's' =?> 'n'
# 0, 218, 0.06388411670923233, '↵To link with him that were n' => 'e' =?> 'o'
# 0, 219, 0.06386513262987137, ' protest, in sight of heaven,' => 'e' =?> '
# '
# 0, 220, 0.06386034935712814, 'y hand, thy faith irrevocable' => 'e' =?> ','
# 0, 221, 0.06388333439826965, 'nd ourselves;↵In them and in ' => 'u' =?> 'o'
# 0, 222, 0.06387422978878021, ' me that he hath done me wron' => 'e' =?> 'g'
# 0, 223, 0.06389614194631577, 'n our way in silent sort:↵For' => 's' =?> ' '
# 0, 224, 0.06380895525217056, 'o;↵To free King Henry from im' => 'a' =?> 'p'
# 0, 225, 0.06380079686641693, 'ou go along?↵↵Huntsman:↵Bette' => 'e' =?> 'r'
# 0, 226, 0.06377780437469482, 'peed;↵For, till I see them he' => 't' =?> 'r'
# 0, 227, 0.0639243870973587, 'll content with that alone.↵↵' => 't' =?> 'G'
# 0, 228, 0.06385494023561478, 't not of large pay.↵3 KING HE' => ' ' =?> 'N'
# 0, 229, 0.0639120414853096, 'ors, march amain towards Cove' => 'o' =?> 'n'
# 0, 230, 0.0638631135225296, 'r Lancaster!↵↵GLOUCESTER:↵The' => 'e' =?> ' '
# 0, 231, 0.06392484903335571, 'he conquest to my foe.↵Thus y' => ' ' =?> 'i'
# 0, 232, 0.06383195519447327, ' HENRY VI↵↵QUEEN MARGARET:↵Gr' => 'q' =?> 'e'
# 0, 233, 0.06396545469760895, 'attle; hence we will not budg' => 's' =?> 'e'
# 0, 234, 0.06392129510641098, 'GLOUCESTER:↵Why should she li' => 'a' =?> 'v'
# 0, 235, 0.06388010084629059, 'ings misdoubteth every bush;↵' => 's' =?> 'A'
# 0, 236, 0.0638720765709877, 'er;↵And this word 'love,' whi' => 'i' =?> 'c'
# 0, 237, 0.06375157833099365, 'what to say. We will give you' => 'e' =?> ' '
# 0, 238, 0.06386527419090271, 'him not to stay. You, sir,↵Ch' => 'u' =?> 'a'
# 0, 239, 0.06385616958141327, 'ters a thousand waiting upon ' => 'v' =?> 't'
# 0, 240, 0.06382068991661072, 'n, all:↵He makes a July's day' => ' ' =?> ' '
# 0, 241, 0.06383968144655228, 'es↵Of our most gracious mistr' => 'n' =?> 'e'
# 0, 242, 0.06381590664386749, 's; you lie, you lie:↵I say th' => 'i' =?> 'o'
# 0, 243, 0.06393010914325714, 'd day, Camillo.↵↵CAMILLO:↵Hai' => 'a' =?> 'l'
# 0, 244, 0.06380895525217056, ' of his body.↵↵POLIXENES:↵How' => 'e' =?> ' '
# 0, 245, 0.06385494023561478, 'e was a man--↵↵HERMIONE:↵Nay,' => 'a' =?> ' '
# 0, 246, 0.06386034190654755, ' bold'st titles, ay, and priv' => 'r' =?> 'y'
# 0, 247, 0.06382949650287628, 'ck I credit?↵↵First Lord:↵I h' => ' ' =?> 'a'
# 0, 248, 0.06384105235338211, 'prisoner,↵I am innocent as yo' => 'e' =?> 'u'
# 0, 249, 0.06397360563278198, 'ueen's life? a gracious innoc' => 'O' =?> 'e'
# 0, 250, 0.06381374597549438, 'ES:↵A callat↵Of boundless ton' => 'a' =?> 'g'
# 0, 251, 0.06381669640541077, 'll me father? better burn it ' => 'i' =?> 'n'
# 0, 252, 0.06384922564029694, 's worth the use on't.↵↵CLEOME' => 'P' =?> 'N'
# 0, 253, 0.06385292857885361, ',↵I know not how it tastes; t' => 'v' =?> 'h'
# 0, 254, 0.06382623314857483, 'on, with mere conceit and fea' => 'n' =?> 'r'
# 0, 255, 0.06386081129312515, 'othing but despair. A thousan' => 'a' =?> 'd'
# 0, 256, 0.06378751248121262, 'a,↵I prithee, call't. For thi' => 'n' =?> 's'
# 0, 257, 0.06382623314857483, 'e↵sea mocked them; and how th' => 'a' =?> 'e'
# 0, 258, 0.0638512447476387, 'If never, yet that Time himse' => 't' =?> 'l'
# 0, 259, 0.06386605650186539, 'sweet birds, O, how they sing' => 's' =?> '!'
# 0, 260, 0.06383209675550461, 'weet sir; no, I beseech you, ' => 'n' =?> 's'
# 0, 261, 0.06378179043531418, 't,↵Should pass this way as yo' => 'i' =?> 'u'
# 0, 262, 0.06389397382736206, 'hat nature makes. You see, sw' => 'D' =?> 'e'
# 0, 263, 0.06388549506664276, 'he does or seems↵But smacks o' => ' ' =?> 'f'
# 0, 264, 0.06386468559503555, 'en quoifs and stomachers,↵For' => 'r' =?> ' '
# 0, 265, 0.06387005746364594, 'CUS:↵I can bear my part; you ' => 's' =?> 'm'
# 0, 266, 0.06385508924722672, 'ann'd↵snow that's bolted↵By t' => ' ' =?> 'h'
# 0, 267, 0.06380216777324677, ', my heart!↵↵POLIXENES:↵I'll ' => 'o' =?> 'h'
# 0, 268, 0.06384922564029694, 'sees or↵The close earth wombs' => 'a' =?> ' '
# 0, 269, 0.06383425742387772, 'visitation shall I↵Hold up be' => ' ' =?> 'f'
# 0, 270, 0.06387936323881149, 'scared my choughs from the ch' => 'r' =?> 'a'
# 0, 271, 0.06380558013916016, 'and none of your flesh and bl' => 'i' =?> 'o'
# 0, 272, 0.06381820887327194, ' thy labour.↵↵Shepherd:↵Why, ' => ' ' =?> 's'
# 0, 273, 0.06376869231462479, 'I will trust you. Walk before' => 'a' =?> ' '
# 0, 274, 0.06389722228050232, 'essor↵Was like to be the best' => 'o' =?> '.'
# 0, 275, 0.06380093842744827, 'love her, that she is a woman' => 'e' =?> '
# '
# 0, 276, 0.06392873078584671, '↵Such goodly things as you!↵↵' => ' ' =?> 'L'
# 0, 277, 0.06385911256074905, 'ntleman:↵I make a broken deli' => 'r' =?> 'v'
# 0, 278, 0.0637989267706871, 'of the shepherd: so that all ' => 'i' =?> 't'
# 0, 279, 0.06386946886777878, 'ay you see them not and↵think' => 's' =?> ' '
# 0, 280, 0.06384677439928055, 'shows off↵Your wonder: but ye' => 'i' =?> 't'
# 0, 281, 0.06389736384153366, 'Quit presently the chapel, or' => 't' =?> ' '
# 0, 282, 0.06387639045715332, 'a,↵Lead us from hence, where ' => 'a' =?> 'w'
# 0, 283, 0.06375772505998611, 'r hand:↵I'll privily away. I ' => 'a' =?> 'l'
# 0, 284, 0.06393582373857498, ' as one would say, healthy; b' => 'o' =?> 'u'
# 0, 285, 0.0638388842344284, 'es this restraint?↵↵CLAUDIO:↵' => ' ' =?> 'F'
# 0, 286, 0.06381005048751831, 'hat thought;↵Believe not that' => 'i' =?> ' '
# 0, 287, 0.06378228962421417, ' not speak.↵He calls again; I' => 's' =?> ' '
# 0, 288, 0.06382270902395248, 'hen they weep and kneel,↵All ' => ' ' =?> 't'
# 0, 289, 0.06385030597448349, 'el-bawd; one that↵serves a ba' => 's' =?> 'd'
# 0, 290, 0.0637989267706871, 'om and good for winter.↵↵POMP' => 'o' =?> 'E'
# 0, 291, 0.063894122838974, ' not have you acquainted with' => 'o' =?> '
# '
# 0, 292, 0.06394428014755249, 'ESCALUS:↵To my house. Fare yo' => ' ' =?> 'u'
# 0, 293, 0.06384152173995972, 'o speak a word.↵May call it b' => 'a' =?> 'a'
# 0, 294, 0.0638134554028511, 'Great men may jest with saint' => 'i' =?> 's'
# 0, 295, 0.06389614194631577, 'mine,↵Who, falling in the fla' => 'o' =?> 'w'
# 0, 296, 0.06385184824466705, '↵Even so. Heaven keep your ho' => 'r' =?> 'n'
# 0, 297, 0.06390060484409332, 'dy up to shame.↵↵ANGELO:↵Then' => 'z' =?> ' '
# 0, 298, 0.06391125172376633, 'ths,↵That bear in them one an' => 'n' =?> 'd'
# 0, 299, 0.06386375427246094, ' please.↵↵DUKE VINCENTIO:↵Bri' => 'G' =?> 'n'
# 0, 300, 0.06384583562612534, 'go we know not where;↵To lie ' => 's' =?> 'i'
# 0, 301, 0.06380125135183334, 'h conveyed to my understandin' => 'a' =?> 'g'
# 0, 302, 0.06380078941583633, 'ur stay with him may↵not be l' => ' ' =?> 'o'
# 0, 303, 0.06389614194631577, 'mfort; I cry bail. Here's a g' => 'i' =?> 'e'
# 0, 304, 0.06380803138017654, ' water his urine is↵congealed' => 'e' =?> ' '
# 0, 305, 0.06381820887327194, 'e duke↵yet would have dark de' => 'i' =?> 'e'
# 0, 306, 0.06383425742387772, ' VINCENTIO:↵He professes to h' => ' ' =?> 'a'
# 0, 307, 0.06384554505348206, 'ction all of precept, he did ' => 'e' =?> 's'
# 0, 308, 0.06383072584867477, '↵Go to, sir; you weigh equall' => 'r' =?> 'y'
# 0, 309, 0.06382298469543457, 'st, as it is,↵You shall hear ' => 'i' =?> 'm'
# 0, 310, 0.06381481885910034, ' you know the course is commo' => 'z' =?> 'n'
# 0, 311, 0.06387979537248611, 'to him, and fetch him out.↵↵P' => ' ' =?> 'O'
# 0, 312, 0.06385479867458344, 'VINCENTIO:↵Convenient is it. ' => 'q' =?> 'M'
# 0, 313, 0.0638304278254509, 'IO:↵You have told me too many' => 'i' =?> ' '
# 0, 314, 0.06384336203336716, 'ot think it strange; for 'tis' => 'o' =?> ' '
# 0, 315, 0.0638546496629715, 've, as just, as absolute↵As A' => 'r' =?> 'n'
# 0, 316, 0.06389844417572021, 'e evil which is here wrapt up' => 'n' =?> '
# '
# 0, 317, 0.06394658982753754, 'I have known my husband; yet ' => 'r' =?> 'm'
# 0, 318, 0.06389599293470383, 'nstantly.↵And you, my noble a' => 'o' =?> 'n'
# 0, 319, 0.06383597105741501, 'Away with him to prison!↵↵ANG' => 'e' =?> 'E'
# 0, 320, 0.06385833024978638, ' of his death,↵Which I did th' => ' ' =?> 'i'
# 0, 321, 0.06393855810165405, 'ENTIO:↵Had you a special warr' => 'o' =?> 'a'
# 0, 322, 0.06382177025079727, 's yours and what is yours is ' => 'i' =?> 'm'
# 0, 323, 0.06389785557985306, 'pastime passing excellent,↵If' => 'e' =?> ' '
# 0, 324, 0.06383302807807922, ' them; haply my presence↵May ' => 's' =?> 'w'
# 0, 325, 0.06383641809225082, 'ady far more beautiful↵Than a' => ' ' =?> 'n'
# 0, 326, 0.06384985893964767, 'Seeing too much sadness hath ' => 'd' =?> 'c'
# 0, 327, 0.06393162161111832, ' need to fear:↵I wis it is no' => 'i' =?> 't'
# 0, 328, 0.06379877030849457, ' with all faults, and money e' => 'n' =?> 'n'
# 0, 329, 0.06380803138017654, 'adua here Vincentio's son,↵Ke' => 'e' =?> 'e'
# 0, 330, 0.06384554505348206, 'u here, sir?↵↵PETRUCHIO:↵Vill' => 'a' =?> 'a'
# 0, 331, 0.06382963806390762, 'ou flatly what his↵mind is: W' => 's' =?> 'h'
# 0, 332, 0.06386604905128479, '↵All books of love, see that ' => 'N' =?> 'a'
# 0, 333, 0.06388116627931595, 'e contributors↵And bear his c' => 's' =?> 'h'
# 1, 0, 0.0637827217578888, 'First Citizen:↵Before we proc' => 'n' =?> 'e'
# 1, 1, 0.0638112723827362, 'ever↵Appear in your impedimen' => 'n' =?> 't'
# 1, 2, 0.06376560032367706, 'eart, to the seat o' the brai' => 's' =?> 'n'
# 1, 3, 0.06383209675550461, 'usands of these quarter'd sla' => 'a' =?> 'v'
# 1, 4, 0.06387900561094284, 'eads on at noon: but I do won' => 'o' =?> 'd'
# 1, 5, 0.06390632688999176, 'ould not↵sell him an hour fro' => ' ' =?> 'm'
# 1, 6, 0.063943050801754, '↵↵VIRGILIA:↵Indeed, no, by yo' => 'i' =?> 'u'
# 1, 7, 0.06381575763225555, 'ow put your shields before yo' => 's' =?> 'u'
# 1, 8, 0.06379768997430801, ':↵Thy friend no less↵Than tho' => 'a' =?> 's'
# 1, 9, 0.063852459192276, 'de to endure friends, that yo' => 'o' =?> 'u'
# 1, 10, 0.06382377445697784, ' charter to extol her blood,↵' => 'h' =?> 'W'
# 1, 11, 0.06383179873228073, 'is yours. What is't?↵↵CORIOLA' => 'o' =?> 'N'
# 1, 12, 0.06386388838291168, 'do you?↵↵Both:↵Why, how are w' => '?' =?> 'e'
# 1, 13, 0.0638800859451294, 'ging of your beards; and your' => 'n' =?> ' '
# 1, 14, 0.06394398957490921, 'IUS:↵Now it's twenty-seven: e' => 'n' =?> 'v'
# 1, 15, 0.06383411586284637, 'ort his honours↵From where he' => 'o' =?> ' '
# 1, 16, 0.06381018459796906, 'ixt doing them neither↵good n' => 'e' =?> 'o'
# 1, 17, 0.06381604820489883, 'venture all his limbs for hon' => 'e' =?> 'o'
# 1, 18, 0.06380787491798401, ' from the people.↵↵BRUTUS:↵Ma' => 'i' =?> 'r'
# 1, 19, 0.06385867297649384, '↵CORIOLANUS:↵What must I say?' => 'w' =?> '
# '
# 1, 20, 0.06382392346858978, ' appear,↵Their needless vouch' => 't' =?> 'e'
# 1, 21, 0.06384922564029694, 'pake against↵Your liberties a' => 'n' =?> 'n'
# 1, 22, 0.06394752115011215, 'ide well in his person wrough' => ' ' =?> 't'
# 1, 23, 0.06391528248786926, 'ss.↵↵CORIOLANUS:↵Why, this wa' => 'e' =?> 's'
# 1, 24, 0.06379754841327667, 'e himself!↵It makes the consu' => 'a' =?> 'l'
# 1, 25, 0.06396820396184921, 'e dust.↵↵BRUTUS:↵Manifest tre' => 'e' =?> 'a'
# 1, 26, 0.06384985893964767, ' house;↵Leave us to cure this' => 'o' =?> ' '
# 1, 27, 0.06387406587600708, 'at has he done to Rome that's' => '-' =?> ' '
# 1, 28, 0.06384105235338211, 'hing↵too rough;↵You must retu' => 'a' =?> 'r'
# 1, 29, 0.06385911256074905, ' they have pardons, being ask' => 'n' =?> '''
# 1, 30, 0.06386388838291168, 'dile:↵With old Menenius, and ' => 'a' =?> 't'
# 1, 31, 0.06389505416154861, 'n the people!↵Call me their t' => 'i' =?> 'r'
# 1, 32, 0.063936248421669, ':↵There is a world elsewhere.' => 'H' =?> '
# '
# 1, 33, 0.06385400146245956, 'ods,↵I'ld with thee every foo' => 'e' =?> 't'
# 1, 34, 0.06383874267339706, ''s the↵news in Rome? I have a' => 'o' =?> ' '
# 1, 35, 0.06393934041261673, 'love's upon↵This enemy town. ' => 'r' =?> 'I'
# 1, 36, 0.06381960958242416, '↵Great hurt and mischief; the' => 'i' =?> 'r'
# 1, 37, 0.06388131529092789, 'lf.↵↵CORIOLANUS:↵You bless me' => 's' =?> ','
# 1, 38, 0.06382052600383759, 'nd but one half of what he wa' => 't' =?> 's'
# 1, 39, 0.06385030597448349, 'neighbours: we wish'd Coriola' => 'e' =?> 'n'
# 1, 40, 0.06385016441345215, 'ow, your news?↵You have made ' => 'e' =?> 'f'
# 1, 41, 0.06380772590637207, 'ue which they so seem to fear' => ' ' =?> '.'
# 1, 42, 0.06388981640338898, ' was sometime his general; wh' => 'n' =?> 'o'
# 1, 43, 0.06381590664386749, ''d me↵Thus, with his speechle' => 'e' =?> 's'
# 1, 44, 0.06385821104049683, '↵I let forth your half-pint o' => 'n' =?> 'f'
# 1, 45, 0.06387083977460861, 'e, indeed. Their latest refug' => 'e' =?> 'e'
# 1, 46, 0.06382623314857483, 'tors to you.↵↵CORIOLANUS:↵I b' => 'i' =?> 'e'
# 1, 47, 0.0638321042060852, 'a name,↵Whose repetition will' => 't' =?> ' '
# 1, 48, 0.06382622569799423, 'ible for you to displace it w' => 'n' =?> 'i'
# 1, 49, 0.06385724246501923, 'ods,↵And make triumphant fire' => 'n' =?> 's'
# 1, 50, 0.06385818123817444, 'ords.↵↵All The Lords:↵You are' => 's' =?> ' '
# 1, 51, 0.0639166533946991, 'peace!↵The man is noble and h' => '3' =?> 'i'
# 1, 52, 0.06378597021102905, 'am subtle, false and treacher' => 'n' =?> 'o'
# 1, 53, 0.0638800784945488, 'ur grace to pardon me, and wi' => 't' =?> 't'
# 1, 54, 0.06385371088981628, 'r Anne,↵Wife to thy Edward, t' => 'r' =?> 'o'
# 1, 55, 0.06393472850322723, 'ul, when angels are so angry.' => 'a' =?> '
# '
# 1, 56, 0.06390322744846344, ' would I were, to be revenged' => ' ' =?> ' '
# 1, 57, 0.06385789066553116, 'Well, well, put up your sword' => 'a' =?> '.'
# 1, 58, 0.063765749335289, 'him worse:↵Therefore, for God' => 'a' =?> '''
# 1, 59, 0.06384091079235077, 'ward actions shows itself↵Aga' => 't' =?> 'i'
# 1, 60, 0.06384692341089249, 're now, and what you are;↵Wit' => 'e' =?> 'h'
# 1, 61, 0.06384706497192383, 'ses pierce the clouds and ent' => 'i' =?> 'e'
# 1, 62, 0.06383302807807922, 'urrent.↵O, that your young no' => 's' =?> 'b'
# 1, 63, 0.0638878121972084, ' and you, my noble lords.↵↵QU' => 'i' =?> 'E'
# 1, 64, 0.06385015696287155, 'tom of the deep,↵And mock'd t' => 'a' =?> 'h'
# 1, 65, 0.06386203318834305, '↵Second Murderer:↵What, shall' => 'u' =?> ' '
# 1, 66, 0.06391927599906921, 'rderer:↵My voice is now the k' => 'i' =?> 'i'
# 1, 67, 0.0638078823685646, 'ates you.↵↵CLARENCE:↵O, no, h' => ';' =?> 'e'
# 1, 68, 0.0638512372970581, 'EDWARD IV:↵Take heed you dall' => 'e' =?> 'y'
# 1, 69, 0.06385309994220734, 'o him injury to scorn his cor' => 'n' =?> 's'
# 1, 70, 0.06385602802038193, 'call us wretches, orphans, ca' => 'o' =?> 's'
# 1, 71, 0.06385818123817444, 'ar lord Clarence!↵↵DUCHESS OF' => ' ' =?> ' '
# 1, 72, 0.06380541622638702, 'ould fetch the prince.↵↵HASTI' => 'a' =?> 'N'
# 1, 73, 0.06391405314207077, 'cond Citizen:↵Marry, we were ' => ' ' =?> 's'
# 1, 74, 0.06386620551347733, ' down my sons were toss'd,↵Fo' => ':' =?> 'r'
# 1, 75, 0.06394658982753754, 'To those whose dealings have ' => ' ' =?> 'd'
# 1, 76, 0.06391096115112305, 'ich is no grief to give.↵↵GLO' => 's' =?> 'U'
# 1, 77, 0.06388501822948456, 'yself shalt highly be employ'' => ' ' =?> 'd'
# 1, 78, 0.0638478547334671, 'TESBY:↵Ay, on my life; and ho' => 'i' =?> 'p'
# 1, 79, 0.06383302807807922, 'all my heart.↵I am in your de' => 'e' =?> 'b'
# 1, 80, 0.06384090334177017, ' come upon your cue, my lord↵' => 'o' =?> 'W'
# 1, 81, 0.06383086740970612, 're triumphing at mine enemies' => 'i' =?> ','
# 1, 82, 0.06383997201919556, ' never look'd for better at h' => 'i' =?> 'i'
# 1, 83, 0.0638091042637825, 'l as long a-doing:↵And yet wi' => 's' =?> 't'
# 1, 84, 0.06383135169744492, 'th entreat your grace;↵To vis' => 'n' =?> 'i'
# 1, 85, 0.06383317708969116, '↵And almost shoulder'd in the' => ' ' =?> ' '
# 1, 86, 0.06382392346858978, 'Mayor:↵Do, good my lord, your' => 'r' =?> ' '
# 1, 87, 0.06383688002824783, 'trary.↵↵QUEEN ELIZABETH:↵The ' => ';' =?> 'k'
# 1, 88, 0.06394506990909576, 'curse,↵Which ever since hath ' => 'r' =?> 'k'
# 1, 89, 0.06387422978878021, ' parts beyond the sea↵Where h' => 'r' =?> 'e'
# 1, 90, 0.06388117372989655, 'ed me.↵↵KING RICHARD III:↵Wel' => 'o' =?> 'l'
# 1, 91, 0.06385616958141327, 'to dull delay;↵Delay leads im' => ' ' =?> 'p'
# 1, 92, 0.06388811022043228, 'QUEEN MARGARET:↵Bear with me;' => 'o' =?> ' '
# 1, 93, 0.06384893506765366, 'UCHESS OF YORK:↵Why should ca' => 't' =?> 'l'
# 1, 94, 0.063883475959301, 'll perish↵And never look upon' => 'r' =?> ' '
# 1, 95, 0.06385940313339233, ' what dignity, what honour,↵C' => 'r' =?> 'a'
# 1, 96, 0.06390387564897537, 'ge.↵The loss you have is but ' => 'e' =?> 'a'
# 1, 97, 0.06391002237796783, ', by my George, my garter, an' => 'a' =?> 'd'
# 1, 98, 0.06381712853908539, 'in my daughter to thy will?↵↵' => 's' =?> 'K'
# 1, 99, 0.06384336203336716, 'reign:↵Please it your majesty' => ' ' =?> ' '
# 1, 100, 0.06378179043531418, ' Blunt,↵And Rice ap Thomas wi' => 's' =?> 't'
# 1, 101, 0.06386419385671616, 'gracious liege.↵↵KING RICHARD' => 'e' =?> ' '
# 1, 102, 0.0638580322265625, 'from troop to troop↵Went thro' => 't' =?> 'u'
# 1, 103, 0.06382885575294495, 'peak well: fool, do not flatt' => 'i' =?> 'e'
# 1, 104, 0.06381805986166, 'you do fight in safeguard of ' => ' ' =?> 'y'
# 1, 105, 0.06385833024978638, 'And I will stand the hazard o' => 'o' =?> 'f'
# 1, 106, 0.06379783898591995, ' liege!↵↵THOMAS MOWBRAY:↵Each' => 'o' =?> ' '
# 1, 107, 0.06375401467084885, 's↵In name of lendings for you' => 'e' =?> 'r'
# 1, 108, 0.06380801647901535, 'd.↵Good uncle, let this end w' => 'r' =?> 'h'
# 1, 109, 0.06389505416154861, 'l full of Edward's sacred blo' => 'e' =?> 'o'
# 1, 110, 0.0638822466135025, 's arrival here in arms:↵Ask h' => 'e' =?> 'i'
# 1, 111, 0.06386266648769379, 'furbish new the name of John ' => 'e' =?> 'a'
# 1, 112, 0.06390495598316193, ' the stranger paths of banish' => 'a' =?> 'm'
# 1, 113, 0.0638686865568161, 'ozen winter spent,↵Return wit' => 't' =?> 'h'
# 1, 114, 0.06384105235338211, 'ut that I was a journeyman to' => ' ' =?> ' '
# 1, 115, 0.06384105235338211, 'o an oyster-wench;↵A brace of' => 'e' =?> ' '
# 1, 116, 0.06384213268756866, ' last,↵For violent fires soon' => 'q' =?> ' '
# 1, 117, 0.06384090334177017, ' thy anointed body to the cur' => 'a' =?> 'e'
# 1, 118, 0.06383997201919556, 'ent? ah, how long↵Shall tende' => 'i' =?> 'r'
# 1, 119, 0.06384705752134323, 'speak thy mind; and let him n' => 'u' =?> 'e'
# 1, 120, 0.06377854198217392, ''d crown,↵Wipe off the dust t' => ' ' =?> 'h'
# 1, 121, 0.06385710090398788, 'oke his staff, resign'd his s' => 'i' =?> 't'
# 1, 122, 0.06387113779783249, 'g commons: for their love↵Lie' => 'e' =?> 's'
# 1, 123, 0.06385724246501923, ' approved service and desert.' => 'r' =?> '
# '
# 1, 124, 0.06383410841226578, 'KE OF YORK:↵Even in condition' => 'e' =?> ' '
# 1, 125, 0.06383302807807922, 'e will disperse ourselves: fa' => 'a' =?> 'r'
# 1, 126, 0.06379399448633194, 'MERLE:↵Yea, my lord. How broo' => 'P' =?> 'k'
# 1, 127, 0.06387422978878021, ' lord,↵Hath clouded all thy h' => 'n' =?> 'a'
# 1, 128, 0.06391927599906921, ' heart!↵Three Judases, each o' => 'n' =?> 'n'
# 1, 129, 0.06386512517929077, ' by my dull and heavy eye,↵My' => 't' =?> ' '
# 1, 130, 0.06383287906646729, 's of blood↵Rain'd from the wo' => 'n' =?> 'u'
# 1, 131, 0.06381251662969589, 'her hath no further scope↵Tha' => 'D' =?> 'n'
# 1, 132, 0.06384105235338211, 'g Phaethon,↵Wanting the manag' => 'r' =?> 'e'
# 1, 133, 0.06383967399597168, 'in our commonwealth:↵All must' => ' ' =?> ' '
# 1, 134, 0.06379877030849457, 'plants thou graft'st may neve' => 'a' =?> 'r'
# 1, 135, 0.0638248547911644, 'heaven, I'll throw at all:↵I ' => 'r' =?> 'h'
# 1, 136, 0.06384120136499405, 't Richard's subject?↵Thieves ' => ' ' =?> 'a'
# 1, 137, 0.06387314945459366, 'KE:↵I thought you had been wi' => 'o' =?> 'l'
# 1, 138, 0.06389505416154861, 'iven me at the font,↵But 'tis' => ' ' =?> ' '
# 1, 139, 0.06387192010879517, 'me; the children yet unborn.↵' => 'i' =?> 'S'
# 1, 140, 0.06383874267339706, 'roke ascends my throne,↵The t' => 'i' =?> 'i'
# 1, 141, 0.06387005001306534, 'e thee! welcome, Bolingbroke!' => 'a' =?> '''
# 1, 142, 0.06392809003591537, 'ine honour, by my life, by my' => 'o' =?> ' '
# 1, 143, 0.06383302807807922, ', that he stares and looks↵So' => 'i' =?> ' '
# 1, 144, 0.06389027833938599, 'NRY BOLINGBROKE:↵Rise up, goo' => ' ' =?> 'd'
# 1, 145, 0.0637606680393219, 'r, did he not?↵↵Servant:↵He d' => 'o' =?> 'i'
# 1, 146, 0.0638788640499115, ' his heart that gives it me!↵' => ' ' =?> 'F'
# 1, 147, 0.06392838060855865, 'r taking may appear↵At large ' => 'i' =?> 'd'
# 1, 148, 0.0638657659292221, 's, and cut off their heads.↵↵' => 'r' =?> 'G'
# 1, 149, 0.06388811767101288, 'For this time, all the rest d' => 'n' =?> 'e'
# 1, 150, 0.06382716447114944, '↵↵ROMEO:↵Out--↵↵BENVOLIO:↵Of ' => 's' =?> 'l'
# 1, 151, 0.06380881369113922, 'ir;↵He that is strucken blind' => ' ' =?> ' '
# 1, 152, 0.06390199810266495, ' you have learned it without ' => 'e' =?> 'b'
# 1, 153, 0.063849076628685, '-I never shall forget it,--↵O' => ' ' =?> 'f'
# 1, 154, 0.06383997201919556, 'y's eyes doth share the glory' => 'r' =?> ','
# 1, 155, 0.0637827217578888, 'ight.↵↵MERCUTIO:↵And so did I' => 'z' =?> '.'
# 1, 156, 0.06392192840576172, ' manners shall lie all in one' => 'q' =?> ' '
# 1, 157, 0.06386727839708328, ' take no note of him:↵It is m' => 'o' =?> 'y'
# 1, 158, 0.0638248547911644, ' of love it is to me,↵That I ' => 'n' =?> 'm'
# 1, 159, 0.06379739940166473, 'air than she:↵Be not her maid' => 'o' =?> ','
# 1, 160, 0.06386296451091766, 'from their sight;↵And but tho' => ' ' =?> 'u'
# 1, 161, 0.06378719210624695, ' a dream,↵Too flattering-swee' => 'i' =?> 't'
# 1, 162, 0.06382730603218079, 'e qualities:↵For nought so vi' => 's' =?> 'l'
# 1, 163, 0.06389012932777405, 'ing, pupil mine.↵↵ROMEO:↵And ' => 'd' =?> 'b'
# 1, 164, 0.06383349001407623, 'MERCUTIO:↵That's as much as t' => 'n' =?> 'o'
# 1, 165, 0.06381604820489883, 'OLIO:↵She will indite him to ' => 'a' =?> 's'
# 1, 166, 0.06379985809326172, 'lady--Lord,↵Lord! when 'twas ' => 'N' =?> 'a'
# 1, 167, 0.0638158991932869, ' what a head have I!↵It beats' => 'p' =?> ' '
# 1, 168, 0.06383875012397766, 'stay alone↵Till holy church i' => 'g' =?> 'n'
# 1, 169, 0.06380557268857956, ' such a greeting: villain am ' => 'M' =?> 'I'
# 1, 170, 0.06382948905229568, 'didst consort him here,↵Shalt' => 't' =?> ' '
# 1, 171, 0.06381899118423462, ' and attend our will:↵Mercy b' => 't' =?> 'u'
# 1, 172, 0.06388811767101288, ' and my dearer lord?↵Then, dr' => 'o' =?> 'e'
# 1, 173, 0.06387901306152344, 'and I; for Romeo is exiled:↵H' => 't' =?> 'e'
# 1, 174, 0.06381064653396606, ':↵Yet 'banished'? Hang up phi' => 't' =?> 'l'
# 1, 175, 0.06374955177307129, 'll,↵And usest none in that tr' => 'Z' =?> 'u'
# 1, 176, 0.06379089504480362, 'love;↵And bid her, mark you m' => 'i' =?> 'e'
# 1, 177, 0.06395554542541504, 'greetings, love, to thee.↵↵JU' => ' ' =?> 'L'
# 1, 178, 0.06384460628032684, ' Saint Peter's Church and Pet' => 'o' =?> 'e'
# 1, 179, 0.06377578526735306, ' demesnes, youthful, and nobl' => 'r' =?> 'y'
# 1, 180, 0.06388332694768906, 'ps for Tybalt's death,↵And th' => 't' =?> 'e'
# 1, 181, 0.06382623314857483, 'undertake↵A thing like death ' => 'T' =?> 't'
# 1, 182, 0.06381604820489883, 'h merry look.↵↵CAPULET:↵How n' => ' ' =?> 'o'
# 1, 183, 0.06391298025846481, 'omeo comes?↵Or, if I live, is' => 'r' =?> ' '
# 1, 184, 0.06380201876163483, 'l-a-day, that ever I was born' => 'r' =?> '!'
# 1, 185, 0.06391513347625732, 'ay bear her to church:↵For th' => 'r' =?> 'o'
# 1, 186, 0.06379585713148117, 'And breathed such life with k' => 's' =?> 'i'
# 1, 187, 0.06381575018167496, ' poverty, and not thy will.↵↵' => 'o' =?> 'A'
# 1, 188, 0.0638236328959465, 'o behold my lady's face;↵But ' => 'n' =?> 'c'
# 1, 189, 0.0638367310166359, 'o sunder his that was thine e' => 'o' =?> 'n'
# 1, 190, 0.06383425742387772, 'estorative.↵Thy lips are warm' => 's' =?> '.'
# 1, 191, 0.06384676694869995, 'd, was husband to that Juliet' => ' ' =?> ';'
# 1, 192, 0.06382190436124802, ' while Verona by that name is' => 'r' =?> ' '
# 1, 193, 0.06388933956623077, 'thy father.↵And thine, Lord C' => 't' =?> 'l'
# 1, 194, 0.06392621994018555, 'n from the usurper's head.↵↵E' => 'o' =?> 'D'
# 1, 195, 0.06385385990142822, 'ast thou injured both thyself' => 'e' =?> ' '
# 1, 196, 0.063883475959301, ' safe? such safety finds↵The ' => 't' =?> 't'
# 1, 197, 0.06384460628032684, '? I cannot rest↵Until the whi' => 'e' =?> 't'
# 1, 198, 0.06382191926240921, 'r's blood open it again:↵He i' => 'i' =?> 's'
# 1, 199, 0.06381251662969589, 'FORD:↵So cowards fight when t' => 't' =?> 'h'
# 1, 200, 0.06377146393060684, 'ory,↵And rob his temples of t' => 'e' =?> 'h'
# 1, 201, 0.06385695934295654, 'not for my life but weep with' => 'n' =?> ' '
# 1, 202, 0.06386297196149826, 'r'd oak.↵By many hands your f' => 's' =?> 'a'
# 1, 203, 0.06383795291185379, 'ides fiercely fought:↵But whe' => 's' =?> 't'
# 1, 204, 0.063908651471138, ',' if Warwick bid him stay.↵↵' => 'r' =?> 'E'
# 1, 205, 0.0638270154595375, '↵But, Clifford, tell me, dids' => ' ' =?> 't'
# 1, 206, 0.06376466155052185, 'e.↵↵NORTHUMBERLAND:↵No, nor y' => 'o' =?> 'o'
# 1, 207, 0.06385184079408646, ' any longer conference,↵Since' => 'r' =?> ' '
# 1, 208, 0.06382068246603012, 'tland; both bound to revenge,' => 'r' =?> '
# '
# 1, 209, 0.06373149156570435, 'an doth me.↵Who's this? O God' => 'K' =?> '!'
# 1, 210, 0.06383519619703293, 'bull:↵Away! for death doth ho' => 'i' =?> 'l'
# 1, 211, 0.06393010169267654, 'rk fetch down the head,↵Your ' => 'r' =?> 'f'
# 1, 212, 0.06384090334177017, 'ill, so both may shoot.↵↵Firs' => 'i' =?> 't'
# 1, 213, 0.06385616958141327, ' go along with us; for as we ' => 'i' =?> 't'
# 1, 214, 0.06389613449573517, '↵↵LADY GREY:↵Therefore I came' => 't' =?> ' '
# 1, 215, 0.06381820887327194, '↵↵KING EDWARD IV:↵Brothers, y' => 't' =?> 'o'
# 1, 216, 0.0638899877667427, ',↵That rends the thorns and i' => 'c' =?> 's'
# 1, 217, 0.06381496787071228, 'proacheth boldly to our prese' => 'n' =?> 'n'
# 1, 218, 0.06388411670923233, '↵To link with him that were n' => 'a' =?> 'o'
# 1, 219, 0.06386511772871017, ' protest, in sight of heaven,' => 'i' =?> '
# '
# 1, 220, 0.06386034190654755, 'y hand, thy faith irrevocable' => 'a' =?> ','
# 1, 221, 0.06388332694768906, 'nd ourselves;↵In them and in ' => 'U' =?> 'o'
# 1, 222, 0.06387422978878021, ' me that he hath done me wron' => ' ' =?> 'g'
# 1, 223, 0.06389614194631577, 'n our way in silent sort:↵For' => 'k' =?> ' '
# 1, 224, 0.06380895525217056, 'o;↵To free King Henry from im' => 's' =?> 'p'
# 1, 225, 0.06380078941583633, 'ou go along?↵↵Huntsman:↵Bette' => 'o' =?> 'r'
# 1, 226, 0.06377779692411423, 'peed;↵For, till I see them he' => 'n' =?> 'r'
# 1, 227, 0.0639243796467781, 'll content with that alone.↵↵' => 't' =?> 'G'
# 1, 228, 0.06385494023561478, 't not of large pay.↵3 KING HE' => ' ' =?> 'N'
# 1, 229, 0.0639120414853096, 'ors, march amain towards Cove' => 's' =?> 'n'
# 1, 230, 0.0638631135225296, 'r Lancaster!↵↵GLOUCESTER:↵The' => 'i' =?> ' '
# 1, 231, 0.06392484903335571, 'he conquest to my foe.↵Thus y' => ' ' =?> 'i'
# 1, 232, 0.06383194774389267, ' HENRY VI↵↵QUEEN MARGARET:↵Gr' => 'o' =?> 'e'
# 1, 233, 0.06396545469760895, 'attle; hence we will not budg' => ' ' =?> 'e'
# 1, 234, 0.06392129510641098, 'GLOUCESTER:↵Why should she li' => 'i' =?> 'v'
# 1, 235, 0.06388009339570999, 'ings misdoubteth every bush;↵' => 'o' =?> 'A'
# 1, 236, 0.0638720691204071, 'er;↵And this word 'love,' whi' => 'a' =?> 'c'
# 1, 237, 0.06375156342983246, 'what to say. We will give you' => 't' =?> ' '
# 1, 238, 0.06386527419090271, 'him not to stay. You, sir,↵Ch' => 'a' =?> 'a'
# 1, 239, 0.06385616958141327, 'ters a thousand waiting upon ' => 't' =?> 't'
# 1, 240, 0.06382068246603012, 'n, all:↵He makes a July's day' => 'a' =?> ' '
# 1, 241, 0.06383967399597168, 'es↵Of our most gracious mistr' => 's' =?> 'e'
# 1, 242, 0.0638158991932869, 's; you lie, you lie:↵I say th' => 'n' =?> 'o'
# 1, 243, 0.06393010169267654, 'd day, Camillo.↵↵CAMILLO:↵Hai' => 't' =?> 'l'
# 1, 244, 0.06380895525217056, ' of his body.↵↵POLIXENES:↵How' => 'a' =?> ' '
# 1, 245, 0.06385494023561478, 'e was a man--↵↵HERMIONE:↵Nay,' => 's' =?> ' '
# 1, 246, 0.06386034190654755, ' bold'st titles, ay, and priv' => 'i' =?> 'y'
# 1, 247, 0.06382949650287628, 'ck I credit?↵↵First Lord:↵I h' => 'n' =?> 'a'
# 1, 248, 0.06384104490280151, 'prisoner,↵I am innocent as yo' => 'n' =?> 'u'
# 1, 249, 0.06397359818220139, 'ueen's life? a gracious innoc' => 'r' =?> 'e'
# 1, 250, 0.06381374597549438, 'ES:↵A callat↵Of boundless ton' => 'i' =?> 'g'
# 1, 251, 0.06381669640541077, 'll me father? better burn it ' => 'r' =?> 'n'
# 1, 252, 0.06384922564029694, 's worth the use on't.↵↵CLEOME' => 'S' =?> 'N'
# 1, 253, 0.06385292112827301, ',↵I know not how it tastes; t' => 's' =?> 'h'
# 1, 254, 0.06382623314857483, 'on, with mere conceit and fea' => 'o' =?> 'r'
# 1, 255, 0.06386080384254456, 'othing but despair. A thousan' => 'w' =?> 'd'
# 1, 256, 0.06378751248121262, 'a,↵I prithee, call't. For thi' => 'a' =?> 's'
# 1, 257, 0.06382623314857483, 'e↵sea mocked them; and how th' => 'o' =?> 'e'
# 1, 258, 0.06385122984647751, 'If never, yet that Time himse' => 'i' =?> 'l'
# 1, 259, 0.06386605650186539, 'sweet birds, O, how they sing' => 't' =?> '!'
# 1, 260, 0.06383209675550461, 'weet sir; no, I beseech you, ' => ' ' =?> 's'
# 1, 261, 0.06378179043531418, 't,↵Should pass this way as yo' => 'n' =?> 'u'
# 1, 262, 0.06389397382736206, 'hat nature makes. You see, sw' => 'r' =?> 'e'
# 1, 263, 0.06388549506664276, 'he does or seems↵But smacks o' => 'a' =?> 'f'
# 1, 264, 0.06386468559503555, 'en quoifs and stomachers,↵For' => 'n' =?> ' '
# 1, 265, 0.06387005001306534, 'CUS:↵I can bear my part; you ' => 'i' =?> 'm'
# 1, 266, 0.06385508924722672, 'ann'd↵snow that's bolted↵By t' => 'r' =?> 'h'
# 1, 267, 0.06380216032266617, ', my heart!↵↵POLIXENES:↵I'll ' => 'o' =?> 'h'
# 1, 268, 0.06384922564029694, 'sees or↵The close earth wombs' => ' ' =?> ' '
# 1, 269, 0.06383424997329712, 'visitation shall I↵Hold up be' => 'e' =?> 'f'
# 1, 270, 0.06387936323881149, 'scared my choughs from the ch' => 't' =?> 'a'
# 1, 271, 0.06380557268857956, 'and none of your flesh and bl' => 'e' =?> 'o'
# 1, 272, 0.06381820887327194, ' thy labour.↵↵Shepherd:↵Why, ' => 't' =?> 's'
# 1, 273, 0.06376869231462479, 'I will trust you. Walk before' => 'r' =?> ' '
# 1, 274, 0.06389721482992172, 'essor↵Was like to be the best' => 'e' =?> '.'
# 1, 275, 0.06380093842744827, 'love her, that she is a woman' => 'S' =?> '
# '
# 1, 276, 0.06392873078584671, '↵Such goodly things as you!↵↵' => 'N' =?> 'L'
# 1, 277, 0.06385911256074905, 'ntleman:↵I make a broken deli' => 't' =?> 'v'
# 1, 278, 0.0637989193201065, 'of the shepherd: so that all ' => 't' =?> 't'
# 1, 279, 0.06386946886777878, 'ay you see them not and↵think' => 'o' =?> ' '
# 1, 280, 0.06384677439928055, 'shows off↵Your wonder: but ye' => 'L' =?> 't'
# 1, 281, 0.06389736384153366, 'Quit presently the chapel, or' => 'o' =?> ' '
# 1, 282, 0.06387639045715332, 'a,↵Lead us from hence, where ' => 'i' =?> 'w'
# 1, 283, 0.06375772505998611, 'r hand:↵I'll privily away. I ' => 'A' =?> 'l'
# 1, 284, 0.06393581628799438, ' as one would say, healthy; b' => 'a' =?> 'u'
# 1, 285, 0.0638388842344284, 'es this restraint?↵↵CLAUDIO:↵' => 's' =?> 'F'
# 1, 286, 0.06381004303693771, 'hat thought;↵Believe not that' => 'r' =?> ' '
# 1, 287, 0.06378228962421417, ' not speak.↵He calls again; I' => 's' =?> ' '
# 1, 288, 0.06382269412279129, 'hen they weep and kneel,↵All ' => ' ' =?> 't'
# 1, 289, 0.06385030597448349, 'el-bawd; one that↵serves a ba' => 'e' =?> 'd'
# 1, 290, 0.0637989193201065, 'om and good for winter.↵↵POMP' => 'e' =?> 'E'
# 1, 291, 0.063894122838974, ' not have you acquainted with' => ' ' =?> '
# '
# 1, 292, 0.06394428014755249, 'ESCALUS:↵To my house. Fare yo' => 'e' =?> 'u'
# 1, 293, 0.06384152173995972, 'o speak a word.↵May call it b' => 'o' =?> 'a'
# 1, 294, 0.0638134554028511, 'Great men may jest with saint' => 't' =?> 's'
# 1, 295, 0.06389613449573517, 'mine,↵Who, falling in the fla' => 'o' =?> 'w'
# 1, 296, 0.06385184079408646, '↵Even so. Heaven keep your ho' => 'a' =?> 'n'
# 1, 297, 0.06390060484409332, 'dy up to shame.↵↵ANGELO:↵Then' => 't' =?> ' '
# 1, 298, 0.06391125172376633, 'ths,↵That bear in them one an' => 'a' =?> 'd'
# 1, 299, 0.06386374682188034, ' please.↵↵DUKE VINCENTIO:↵Bri' => 's' =?> 'n'
# 1, 300, 0.06384583562612534, 'go we know not where;↵To lie ' => '?' =?> 'i'
# ...
# 18, 64, 0.06385014951229095, 'tom of the deep,↵And mock'd t' => 'a' =?> 'h'
# 18, 65, 0.06386201828718185, '↵Second Murderer:↵What, shall' => 's' =?> ' '
# 18, 66, 0.06391927599906921, 'rderer:↵My voice is now the k' => ' ' =?> 'i'
# 18, 67, 0.0638078823685646, 'ates you.↵↵CLARENCE:↵O, no, h' => 'e' =?> 'e'
# 18, 68, 0.06385122984647751, 'EDWARD IV:↵Take heed you dall' => 'n' =?> 'y'
# 18, 69, 0.06385309249162674, 'o him injury to scorn his cor' => 'a' =?> 's'
# 18, 70, 0.06385602056980133, 'call us wretches, orphans, ca' => 'e' =?> 's'
# 18, 71, 0.06385818123817444, 'ar lord Clarence!↵↵DUCHESS OF' => 't' =?> ' '
# 18, 72, 0.06380541622638702, 'ould fetch the prince.↵↵HASTI' => 'E' =?> 'N'
# 18, 73, 0.06391405314207077, 'cond Citizen:↵Marry, we were ' => 'i' =?> 's'
# 18, 74, 0.06386619806289673, ' down my sons were toss'd,↵Fo' => 't' =?> 'r'
# 18, 75, 0.06394658237695694, 'To those whose dealings have ' => 'r' =?> 'd'
# 18, 76, 0.06391095370054245, 'ich is no grief to give.↵↵GLO' => 'a' =?> 'U'
# 18, 77, 0.06388501822948456, 'yself shalt highly be employ'' => 'i' =?> 'd'
# 18, 78, 0.06384783983230591, 'TESBY:↵Ay, on my life; and ho' => 's' =?> 'p'
# 18, 79, 0.06383302807807922, 'all my heart.↵I am in your de' => ':' =?> 'b'
# 18, 80, 0.06384090334177017, ' come upon your cue, my lord↵' => 'o' =?> 'W'
# 18, 81, 0.06383086740970612, 're triumphing at mine enemies' => 'o' =?> ','
# 18, 82, 0.06383997201919556, ' never look'd for better at h' => 's' =?> 'i'
# 18, 83, 0.0638090968132019, 'l as long a-doing:↵And yet wi' => 'o' =?> 't'
# 18, 84, 0.06383135169744492, 'th entreat your grace;↵To vis' => 'n' =?> 'i'
# 18, 85, 0.06383316963911057, '↵And almost shoulder'd in the' => 'n' =?> ' '
# 18, 86, 0.06382392346858978, 'Mayor:↵Do, good my lord, your' => ' ' =?> ' '
# 18, 87, 0.06383687257766724, 'trary.↵↵QUEEN ELIZABETH:↵The ' => 'o' =?> 'k'
# 18, 88, 0.06394506990909576, 'curse,↵Which ever since hath ' => 's' =?> 'k'
# 18, 89, 0.06387422978878021, ' parts beyond the sea↵Where h' => 'a' =?> 'e'
# 18, 90, 0.06388116627931595, 'ed me.↵↵KING RICHARD III:↵Wel' => 'a' =?> 'l'
# 18, 91, 0.06385616213083267, 'to dull delay;↵Delay leads im' => 's' =?> 'p'
# 18, 92, 0.06388811022043228, 'QUEEN MARGARET:↵Bear with me;' => 'a' =?> ' '
# 18, 93, 0.06384893506765366, 'UCHESS OF YORK:↵Why should ca' => 'n' =?> 'l'
# 18, 94, 0.063883475959301, 'll perish↵And never look upon' => 's' =?> ' '
# 18, 95, 0.06385940313339233, ' what dignity, what honour,↵C' => 'a' =?> 'a'
# 18, 96, 0.06390386819839478, 'ge.↵The loss you have is but ' => 'C' =?> 'a'
# 18, 97, 0.06391002237796783, ', by my George, my garter, an' => 'r' =?> 'd'
# 18, 98, 0.06381712853908539, 'in my daughter to thy will?↵↵' => 'a' =?> 'K'
# 18, 99, 0.06384335458278656, 'reign:↵Please it your majesty' => 's' =?> ' '
# 18, 100, 0.06378179043531418, ' Blunt,↵And Rice ap Thomas wi' => 'i' =?> 't'
# 18, 101, 0.06386418640613556, 'gracious liege.↵↵KING RICHARD' => 's' =?> ' '
# 18, 102, 0.0638580322265625, 'from troop to troop↵Went thro' => 's' =?> 'u'
# 18, 103, 0.06382884830236435, 'peak well: fool, do not flatt' => 'i' =?> 'e'
# 18, 104, 0.06381805986166, 'you do fight in safeguard of ' => 'i' =?> 'y'
# 18, 105, 0.06385832279920578, 'And I will stand the hazard o' => 't' =?> 'f'
# 18, 106, 0.06379783153533936, ' liege!↵↵THOMAS MOWBRAY:↵Each' => 'a' =?> ' '
# 18, 107, 0.06375400722026825, 's↵In name of lendings for you' => 'n' =?> 'r'
# 18, 108, 0.06380801647901535, 'd.↵Good uncle, let this end w' => 'i' =?> 'h'
# 18, 109, 0.06389505416154861, 'l full of Edward's sacred blo' => 'o' =?> 'o'
# 18, 110, 0.0638822466135025, 's arrival here in arms:↵Ask h' => 'o' =?> 'i'
# 18, 111, 0.06386266648769379, 'furbish new the name of John ' => 'e' =?> 'a'
# 18, 112, 0.06390494108200073, ' the stranger paths of banish' => 'e' =?> 'm'
# 18, 113, 0.06386867165565491, 'ozen winter spent,↵Return wit' => ' ' =?> 'h'
# 18, 114, 0.06384105235338211, 'ut that I was a journeyman to' => 'e' =?> ' '
# 18, 115, 0.06384105235338211, 'o an oyster-wench;↵A brace of' => ' ' =?> ' '
# 18, 116, 0.06384213268756866, ' last,↵For violent fires soon' => 'e' =?> ' '
# 18, 117, 0.06384090334177017, ' thy anointed body to the cur' => 'a' =?> 'e'
# 18, 118, 0.06383997201919556, 'ent? ah, how long↵Shall tende' => 'e' =?> 'r'
# 18, 119, 0.06384705752134323, 'speak thy mind; and let him n' => 't' =?> 'e'
# 18, 120, 0.06377854198217392, ''d crown,↵Wipe off the dust t' => 'i' =?> 'h'
# 18, 121, 0.06385709345340729, 'oke his staff, resign'd his s' => 'o' =?> 't'
# 18, 122, 0.06387113034725189, 'g commons: for their love↵Lie' => 'r' =?> 's'
# 18, 123, 0.06385724246501923, ' approved service and desert.' => 'r' =?> '
# '
# 18, 124, 0.06383410841226578, 'KE OF YORK:↵Even in condition' => 'e' =?> ' '
# 18, 125, 0.06383302807807922, 'e will disperse ourselves: fa' => 'h' =?> 'r'
# 18, 126, 0.06379397958517075, 'MERLE:↵Yea, my lord. How broo' => 's' =?> 'k'
# 18, 127, 0.06387422233819962, ' lord,↵Hath clouded all thy h' => 'e' =?> 'a'
# 18, 128, 0.06391927599906921, ' heart!↵Three Judases, each o' => 'T' =?> 'n'
# 18, 129, 0.06386511772871017, ' by my dull and heavy eye,↵My' => 's' =?> ' '
# 18, 130, 0.06383287161588669, 's of blood↵Rain'd from the wo' => 'o' =?> 'u'
# 18, 131, 0.0638125091791153, 'her hath no further scope↵Tha' => 'r' =?> 'n'
# 18, 132, 0.06384105235338211, 'g Phaethon,↵Wanting the manag' => 'e' =?> 'e'
# 18, 133, 0.06383967399597168, 'in our commonwealth:↵All must' => ',' =?> ' '
# 18, 134, 0.06379877030849457, 'plants thou graft'st may neve' => 'N' =?> 'r'
# 18, 135, 0.0638248547911644, 'heaven, I'll throw at all:↵I ' => 't' =?> 'h'
# 18, 136, 0.06384119391441345, 't Richard's subject?↵Thieves ' => 'i' =?> 'a'
# 18, 137, 0.06387314200401306, 'KE:↵I thought you had been wi' => 's' =?> 'l'
# 18, 138, 0.06389505416154861, 'iven me at the font,↵But 'tis' => 'U' =?> ' '
# 18, 139, 0.06387191265821457, 'me; the children yet unborn.↵' => 'o' =?> 'S'
# 18, 140, 0.06383874267339706, 'roke ascends my throne,↵The t' => 's' =?> 'i'
# 18, 141, 0.06387005001306534, 'e thee! welcome, Bolingbroke!' => ' ' =?> '''
# 18, 142, 0.06392808258533478, 'ine honour, by my life, by my' => 'o' =?> ' '
# 18, 143, 0.06383302807807922, ', that he stares and looks↵So' => 'i' =?> ' '
# 18, 144, 0.06389027833938599, 'NRY BOLINGBROKE:↵Rise up, goo' => 't' =?> 'd'
# 18, 145, 0.0637606680393219, 'r, did he not?↵↵Servant:↵He d' => 's' =?> 'i'
# 18, 146, 0.0638788640499115, ' his heart that gives it me!↵' => 'E' =?> 'F'
# 18, 147, 0.06392837315797806, 'r taking may appear↵At large ' => 'l' =?> 'd'
# 18, 148, 0.06386575847864151, 's, and cut off their heads.↵↵' => 'n' =?> 'G'
# 18, 149, 0.06388811022043228, 'For this time, all the rest d' => 'e' =?> 'e'
# 18, 150, 0.06382716447114944, '↵↵ROMEO:↵Out--↵↵BENVOLIO:↵Of ' => 'n' =?> 'l'
# 18, 151, 0.06380880624055862, 'ir;↵He that is strucken blind' => ' ' =?> ' '
# 18, 152, 0.06390199810266495, ' you have learned it without ' => ' ' =?> 'b'
# 18, 153, 0.063849076628685, '-I never shall forget it,--↵O' => ' ' =?> 'f'
# 18, 154, 0.06383996456861496, 'y's eyes doth share the glory' => 'r' =?> ','
# 18, 155, 0.0637827217578888, 'ight.↵↵MERCUTIO:↵And so did I' => 'i' =?> '.'
# 18, 156, 0.06392192840576172, ' manners shall lie all in one' => 'o' =?> ' '
# 18, 157, 0.06386727839708328, ' take no note of him:↵It is m' => 'a' =?> 'y'
# 18, 158, 0.0638248547911644, ' of love it is to me,↵That I ' => 'i' =?> 'm'
# 18, 159, 0.06379739195108414, 'air than she:↵Be not her maid' => 'i' =?> ','
# 18, 160, 0.06386296451091766, 'from their sight;↵And but tho' => 'r' =?> 'u'
# 18, 161, 0.06378718465566635, ' a dream,↵Too flattering-swee' => ' ' =?> 't'
# 18, 162, 0.06382730603218079, 'e qualities:↵For nought so vi' => 'n' =?> 'l'
# 18, 163, 0.06389012932777405, 'ing, pupil mine.↵↵ROMEO:↵And ' => 'e' =?> 'b'
# 18, 164, 0.06383348256349564, 'MERCUTIO:↵That's as much as t' => 'J' =?> 'o'
# 18, 165, 0.06381604820489883, 'OLIO:↵She will indite him to ' => 'M' =?> 's'
# 18, 166, 0.06379985064268112, 'lady--Lord,↵Lord! when 'twas ' => 'i' =?> 'a'
# 18, 167, 0.0638158991932869, ' what a head have I!↵It beats' => ' ' =?> ' '
# 18, 168, 0.06383874267339706, 'stay alone↵Till holy church i' => ' ' =?> 'n'
# 18, 169, 0.06380556523799896, ' such a greeting: villain am ' => 'r' =?> 'I'
# 18, 170, 0.06382948905229568, 'didst consort him here,↵Shalt' => 'i' =?> ' '
# 18, 171, 0.06381898373365402, ' and attend our will:↵Mercy b' => 'm' =?> 'u'
# 18, 172, 0.06388811022043228, ' and my dearer lord?↵Then, dr' => 's' =?> 'e'
# 18, 173, 0.06387900561094284, 'and I; for Romeo is exiled:↵H' => 'a' =?> 'e'
# 18, 174, 0.06381063908338547, ':↵Yet 'banished'? Hang up phi' => ' ' =?> 'l'
# 18, 175, 0.0637495368719101, 'll,↵And usest none in that tr' => 'r' =?> 'u'
# 18, 176, 0.06379089504480362, 'love;↵And bid her, mark you m' => '3' =?> 'e'
# 18, 177, 0.06395554542541504, 'greetings, love, to thee.↵↵JU' => 'o' =?> 'L'
# 18, 178, 0.06384460628032684, ' Saint Peter's Church and Pet' => 'n' =?> 'e'
# 18, 179, 0.06377577781677246, ' demesnes, youthful, and nobl' => 'r' =?> 'y'
# 18, 180, 0.06388332694768906, 'ps for Tybalt's death,↵And th' => 'o' =?> 'e'
# 18, 181, 0.06382623314857483, 'undertake↵A thing like death ' => 'a' =?> 't'
# 18, 182, 0.06381604075431824, 'h merry look.↵↵CAPULET:↵How n' => 's' =?> 'o'
# 18, 183, 0.06391297280788422, 'omeo comes?↵Or, if I live, is' => 'n' =?> ' '
# 18, 184, 0.06380201131105423, 'l-a-day, that ever I was born' => 'L' =?> '!'
# 18, 185, 0.06391513347625732, 'ay bear her to church:↵For th' => 't' =?> 'o'
# 18, 186, 0.06379584968090057, 'And breathed such life with k' => 'a' =?> 'i'
# 18, 187, 0.06381575018167496, ' poverty, and not thy will.↵↵' => 's' =?> 'A'
# 18, 188, 0.0638236328959465, 'o behold my lady's face;↵But ' => 'r' =?> 'c'
# 18, 189, 0.0638367235660553, 'o sunder his that was thine e' => 's' =?> 'n'
# 18, 190, 0.06383425742387772, 'estorative.↵Thy lips are warm' => 'r' =?> '.'
# 18, 191, 0.06384676694869995, 'd, was husband to that Juliet' => 'r' =?> ';'
# 18, 192, 0.06382190436124802, ' while Verona by that name is' => 'n' =?> ' '
# 18, 193, 0.06388933956623077, 'thy father.↵And thine, Lord C' => ' ' =?> 'l'
# 18, 194, 0.06392621994018555, 'n from the usurper's head.↵↵E' => 'a' =?> 'D'
# 18, 195, 0.06385385990142822, 'ast thou injured both thyself' => 'o' =?> ' '
# 18, 196, 0.063883475959301, ' safe? such safety finds↵The ' => ' ' =?> 't'
# 18, 197, 0.06384460628032684, '? I cannot rest↵Until the whi' => 'a' =?> 't'
# 18, 198, 0.06382190436124802, 'r's blood open it again:↵He i' => ' ' =?> 's'
# 18, 199, 0.06381251662969589, 'FORD:↵So cowards fight when t' => 'n' =?> 'h'
# 18, 200, 0.06377145648002625, 'ory,↵And rob his temples of t' => 'a' =?> 'h'
# 18, 201, 0.06385695934295654, 'not for my life but weep with' => 'n' =?> ' '
# 18, 202, 0.06386296451091766, 'r'd oak.↵By many hands your f' => 'm' =?> 'a'
# 18, 203, 0.06383795291185379, 'ides fiercely fought:↵But whe' => 'e' =?> 't'
# 18, 204, 0.0639086440205574, ',' if Warwick bid him stay.↵↵' => 'i' =?> 'E'
# 18, 205, 0.0638270154595375, '↵But, Clifford, tell me, dids' => 't' =?> 't'
# 18, 206, 0.06376466155052185, 'e.↵↵NORTHUMBERLAND:↵No, nor y' => 'e' =?> 'o'
# 18, 207, 0.06385184079408646, ' any longer conference,↵Since' => ' ' =?> ' '
# 18, 208, 0.06382067501544952, 'tland; both bound to revenge,' => 'a' =?> '
# '
# 18, 209, 0.06373148411512375, 'an doth me.↵Who's this? O God' => 'i' =?> '!'
# 18, 210, 0.06383518874645233, 'bull:↵Away! for death doth ho' => ' ' =?> 'l'
# 18, 211, 0.06393010169267654, 'rk fetch down the head,↵Your ' => 'a' =?> 'f'
# 18, 212, 0.06384090334177017, 'ill, so both may shoot.↵↵Firs' => 'n' =?> 't'
# 18, 213, 0.06385616213083267, ' go along with us; for as we ' => 'i' =?> 't'
# 18, 214, 0.06389613449573517, '↵↵LADY GREY:↵Therefore I came' => 'U' =?> ' '
# 18, 215, 0.06381820142269135, '↵↵KING EDWARD IV:↵Brothers, y' => 'a' =?> 'o'
# 18, 216, 0.0638899877667427, ',↵That rends the thorns and i' => 'M' =?> 's'
# 18, 217, 0.06381496042013168, 'proacheth boldly to our prese' => 't' =?> 'n'
# 18, 218, 0.06388411670923233, '↵To link with him that were n' => 't' =?> 'o'
# 18, 219, 0.06386511772871017, ' protest, in sight of heaven,' => 'n' =?> '
# '
# 18, 220, 0.06386034190654755, 'y hand, thy faith irrevocable' => 'n' =?> ','
# 18, 221, 0.06388332694768906, 'nd ourselves;↵In them and in ' => 'n' =?> 'o'
# 18, 222, 0.06387422978878021, ' me that he hath done me wron' => 'd' =?> 'g'
# 18, 223, 0.06389613449573517, 'n our way in silent sort:↵For' => 'e' =?> ' '
# 18, 224, 0.06380894780158997, 'o;↵To free King Henry from im' => 'S' =?> 'p'
# 18, 225, 0.06380078196525574, 'ou go along?↵↵Huntsman:↵Bette' => 'e' =?> 'r'
# 18, 226, 0.06377779692411423, 'peed;↵For, till I see them he' => 'i' =?> 'r'
# 18, 227, 0.0639243796467781, 'll content with that alone.↵↵' => 'i' =?> 'G'
# 18, 228, 0.06385494023561478, 't not of large pay.↵3 KING HE' => 'n' =?> 'N'
# 18, 229, 0.0639120414853096, 'ors, march amain towards Cove' => 'a' =?> 'n'
# 18, 230, 0.06386309862136841, 'r Lancaster!↵↵GLOUCESTER:↵The' => 's' =?> ' '
# 18, 231, 0.06392484158277512, 'he conquest to my foe.↵Thus y' => 'n' =?> 'i'
# 18, 232, 0.06383194774389267, ' HENRY VI↵↵QUEEN MARGARET:↵Gr' => 's' =?> 'e'
# 18, 233, 0.06396545469760895, 'attle; hence we will not budg' => 'i' =?> 'e'
# 18, 234, 0.06392128765583038, 'GLOUCESTER:↵Why should she li' => 'r' =?> 'v'
# 18, 235, 0.0638800859451294, 'ings misdoubteth every bush;↵' => 'n' =?> 'A'
# 18, 236, 0.06387206166982651, 'er;↵And this word 'love,' whi' => ' ' =?> 'c'
# 18, 237, 0.06375156342983246, 'what to say. We will give you' => 'i' =?> ' '
# 18, 238, 0.06386526674032211, 'him not to stay. You, sir,↵Ch' => 'f' =?> 'a'
# 18, 239, 0.06385616213083267, 'ters a thousand waiting upon ' => 'n' =?> 't'
# 18, 240, 0.06382067501544952, 'n, all:↵He makes a July's day' => 'r' =?> ' '
# 18, 241, 0.06383967399597168, 'es↵Of our most gracious mistr' => 's' =?> 'e'
# 18, 242, 0.0638158991932869, 's; you lie, you lie:↵I say th' => 'i' =?> 'o'
# 18, 243, 0.06393010169267654, 'd day, Camillo.↵↵CAMILLO:↵Hai' => 's' =?> 'l'
# 18, 244, 0.06380895525217056, ' of his body.↵↵POLIXENES:↵How' => ' ' =?> ' '
# 18, 245, 0.06385494023561478, 'e was a man--↵↵HERMIONE:↵Nay,' => 'n' =?> ' '
# 18, 246, 0.06386034190654755, ' bold'st titles, ay, and priv' => 'e' =?> 'y'
# 18, 247, 0.06382949650287628, 'ck I credit?↵↵First Lord:↵I h' => 's' =?> 'a'
# 18, 248, 0.06384104490280151, 'prisoner,↵I am innocent as yo' => 'i' =?> 'u'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 12
#       9 yhat = inference(inference_key, model_params, xBT, d_k)
#      10 model_params, opt_state, loss, grads = train_step(model_params, xBT, yB, d_k, opt_state, optimizer)
# ---> 12 in_chars = decode(xBT[0]).replace('\n', '↵')
#      13 target_char = decode(jnp.array([yB[0]]))
#      14 pred_char = decode(jnp.array([yhat]))
#
# Cell In[2], line 22, in <lambda>(tokens)
#      19 char_to_token_dict = (dict([(b, a) for a, b in token_to_char_dict.items()]))
#      21 encode = lambda word: jnp.array([char_to_token_dict[c] for c in word])
# ---> 22 decode = lambda tokens: "".join([token_to_char_dict[t] for t in tokens.tolist()])
#      24 test_word = "lmaoooo"
#      25 print(test_word, encode(test_word), decode(encode(test_word)))
#
# File ~/Desktop/ai_gym/.venv/lib/python3.10/site-packages/jax/_src/array.py:324, in ArrayImpl.tolist(self)
#     323 def tolist(self):
# --> 324   return self._value.tolist()
#
# File ~/Desktop/ai_gym/.venv/lib/python3.10/site-packages/jax/_src/profiler.py:333, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     330 @wraps(func)
#     331 def wrapper(*args, **kwargs):
#     332   with TraceAnnotation(name, **decorator_kwargs):
# --> 333     return func(*args, **kwargs)
#     334   return wrapper
#
# File ~/Desktop/ai_gym/.venv/lib/python3.10/site-packages/jax/_src/array.py:628, in ArrayImpl._value(self)
#     626 if self._npy_value is None:
#     627   if self.is_fully_replicated:
# --> 628     self._npy_value = self._single_device_array_to_np_array()
#     629     self._npy_value.flags.writeable = False
#     630     return cast(np.ndarray, self._npy_value)
#
# KeyboardInterrupt:

# %%
def get_completion(key, prompt, d_k=d_k):
  # this is LSTM style, not true transformer style.
  xBT = encode(prompt)[None, :] # fake batch
  yhat = inference(key, model_params, xBT, d_k) # will be messed up bc argmax instead of choosing probs
  return decode(jnp.array([yhat]))

import time
key = jrand.PRNGKey(int(time.time()*100))

prompt = "First Citizen:\nBefore we proc"
print(prompt, end='')
for i in range(100):
  next_char = get_completion(key, prompt[-max_sequence_length:])
  prompt += next_char
  print(next_char, end='')
# Out:
# First Citizen:
# Before we procaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa

# %%
print(xBT.shape, yB.shape)
jax.tree_util.tree_map(jnp.linalg.norm, grads)
# Out:
# (100, 29) (100,)
# [{'attention_params': [{'Wk': Array(5.439577e-09, dtype=float32),
#     'Wout': Array(1.7552958e-08, dtype=float32),
#     'Wq': Array(6.0527805e-09, dtype=float32),
#     'Wv': Array(2.0876437e-08, dtype=float32)},
#    {'Wk': Array(1.5989373e-09, dtype=float32),
#     'Wout': Array(1.8074301e-08, dtype=float32),
#     'Wq': Array(1.6908579e-09, dtype=float32),
#     'Wv': Array(1.9549228e-08, dtype=float32)},
#    {'Wk': Array(3.5835377e-09, dtype=float32),
#     'Wout': Array(1.9075788e-08, dtype=float32),
#     'Wq': Array(3.8867554e-09, dtype=float32),
#     'Wv': Array(1.7926924e-08, dtype=float32)},
#    {'Wk': Array(1.5083843e-09, dtype=float32),
#     'Wout': Array(1.5769741e-08, dtype=float32),
#     'Wq': Array(2.5607705e-09, dtype=float32),
#     'Wv': Array(1.6212404e-08, dtype=float32)},
#    {'Wk': Array(3.6827823e-09, dtype=float32),
#     'Wout': Array(1.5018214e-08, dtype=float32),
#     'Wq': Array(4.1164774e-09, dtype=float32),
#     'Wv': Array(1.6350812e-08, dtype=float32)},
#    {'Wk': Array(8.429604e-10, dtype=float32),
#     'Wout': Array(1.834376e-08, dtype=float32),
#     'Wq': Array(8.0196183e-10, dtype=float32),
#     'Wv': Array(2.1382363e-08, dtype=float32)},
#    {'Wk': Array(3.0312752e-09, dtype=float32),
#     'Wout': Array(1.9808873e-08, dtype=float32),
#     'Wq': Array(2.8642733e-09, dtype=float32),
#     'Wv': Array(2.0768713e-08, dtype=float32)},
#    {'Wk': Array(4.520902e-09, dtype=float32),
#     'Wout': Array(1.8116888e-08, dtype=float32),
#     'Wq': Array(5.6204468e-09, dtype=float32),
#     'Wv': Array(1.7514294e-08, dtype=float32)}],
#   'embedding_table_params': [{'W': Array(3.539022e-08, dtype=float32),
#     'b': Array(3.4295503e-08, dtype=float32)},
#    {'W': Array(2.873652e-08, dtype=float32),
#     'b': Array(1.4441202e-08, dtype=float32)},
#    {'W': Array(2.9520093e-08, dtype=float32),
#     'b': Array(7.937653e-09, dtype=float32)},
#    {'W': Array(4.7641006e-08, dtype=float32),
#     'b': Array(5.879964e-09, dtype=float32)}],
#   'forward_mlp_params': [{'W': Array(2.5190386e-07, dtype=float32),
#     'b': Array(4.1437502e-09, dtype=float32)},
#    {'W': Array(2.2207169e-07, dtype=float32),
#     'b': Array(5.428048e-09, dtype=float32)},
#    {'W': Array(2.6309831e-07, dtype=float32),
#     'b': Array(7.035346e-09, dtype=float32)},
#    {'W': Array(2.3250249e-07, dtype=float32),
#     'b': Array(1.8248119e-09, dtype=float32)}]},
#  {'attention_params': [{'Wk': Array(1.7742928e-09, dtype=float32),
#     'Wout': Array(5.0119526e-09, dtype=float32),
#     'Wq': Array(2.0306499e-09, dtype=float32),
#     'Wv': Array(8.519988e-09, dtype=float32)},
#    {'Wk': Array(2.0290414e-10, dtype=float32),
#     'Wout': Array(1.9117106e-09, dtype=float32),
#     'Wq': Array(2.2940434e-10, dtype=float32),
#     'Wv': Array(2.483024e-09, dtype=float32)},
#    {'Wk': Array(2.6717781e-09, dtype=float32),
#     'Wout': Array(5.0192717e-09, dtype=float32),
#     'Wq': Array(2.6222289e-09, dtype=float32),
#     'Wv': Array(9.0313605e-09, dtype=float32)},
#    {'Wk': Array(8.7439815e-09, dtype=float32),
#     'Wout': Array(4.1377057e-09, dtype=float32),
#     'Wq': Array(8.880516e-09, dtype=float32),
#     'Wv': Array(7.2981066e-09, dtype=float32)},
#    {'Wk': Array(2.2553979e-09, dtype=float32),
#     'Wout': Array(3.847612e-09, dtype=float32),
#     'Wq': Array(2.59726e-09, dtype=float32),
#     'Wv': Array(7.275276e-09, dtype=float32)},
#    {'Wk': Array(1.1974589e-09, dtype=float32),
#     'Wout': Array(6.081801e-09, dtype=float32),
#     'Wq': Array(1.1739091e-09, dtype=float32),
#     'Wv': Array(1.08477245e-08, dtype=float32)},
#    {'Wk': Array(3.763098e-09, dtype=float32),
#     'Wout': Array(4.6276205e-09, dtype=float32),
#     'Wq': Array(4.835353e-09, dtype=float32),
#     'Wv': Array(8.8105745e-09, dtype=float32)},
#    {'Wk': Array(4.882598e-09, dtype=float32),
#     'Wout': Array(2.9279497e-09, dtype=float32),
#     'Wq': Array(4.3956105e-09, dtype=float32),
#     'Wv': Array(5.4823754e-09, dtype=float32)}],
#   'forward_mlp_params': [{'W': Array(3.7961804e-08, dtype=float32),
#     'b': Array(4.2321238e-10, dtype=float32)},
#    {'W': Array(2.6224669e-08, dtype=float32),
#     'b': Array(7.680484e-10, dtype=float32)},
#    {'W': Array(2.8699528e-08, dtype=float32),
#     'b': Array(9.459011e-10, dtype=float32)},
#    {'W': Array(4.46236e-08, dtype=float32),
#     'b': Array(6.731023e-10, dtype=float32)}],
#   'output_mlp_params': [{'W': Array(1.8069045e-07, dtype=float32),
#     'b': Array(4.267338e-09, dtype=float32)},
#    {'W': Array(1.3432796e-07, dtype=float32),
#     'b': Array(5.5290186e-09, dtype=float32)},
#    {'W': Array(1.7584831e-07, dtype=float32),
#     'b': Array(7.705868e-09, dtype=float32)},
#    {'W': Array(3.5900828e-07, dtype=float32),
#     'b': Array(1.3413328e-08, dtype=float32)}]}]
